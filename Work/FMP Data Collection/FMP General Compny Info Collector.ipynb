# %% [markdown]
# # Using Financial Modeling Prep to Collect General & Financial Information

# %% [markdown]
# ## Setup Local Environment

# %%
import time
from platform import python_version
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
import csv 
try:
    from urllib.request import urlopen
except ImportError:
    from urllib2 import urlopen
import certifi
from tqdm import tqdm

# %%
print(python_version())
print(pd.__version__)
# Out:
# 3.10.4
# 1.4.2

# %%
#check the local address
cover = open('TestData.csv','w', newline='', encoding='UTF-8')
writing = csv.writer(cover)
writing.writerow(['name','name_eng','description_short','description','founded_date','product','homepage','employee_cnt','revenue','ceo_name','email','tel','fax','address1','address2','post_code','facebook','youtube','logo','hash_tag','nation_id','industry_id','is_active','created_at','updated_at'])
# Out:
# 232

# %% [markdown]
# ## Setup API Environment

# %%
def get_jsonparsed_data(url):
    """
    Receive the content of ``url``, parse it as JSON and return the object.

    Parameters
    ----------
    url : str

    Returns
    -------
    dict
    """
    response = urlopen(url, cafile=certifi.where())
    data = response.read().decode("utf-8")
    return json.loads(data)

# %%
url = ("https://financialmodelingprep.com/api/v3/financial-statement-symbol-lists?apikey=33d67d9c5e5ed94ff134e9bf93f9d818")
Symbols = get_jsonparsed_data(url)
# Out:
# C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3606349989.py:13: DeprecationWarning: cafile, capath and cadefault are deprecated, use a custom context instead.
#   response = urlopen(url, cafile=certifi.where())

# %% [markdown]
# ## Check Availability

# %%
Symbols
# Out:
# ['ETH',
#  'GOGN',
#  '000540.SZ',
#  '603931.SS',
#  'JMG.L',
#  '067900.KS',
#  'BSP.AX',
#  'ERM.L',
#  'LVCLY',
#  'SBFMW',
#  'CPAH',
#  'JGLE.JK',
#  'SMWN.DE',
#  '0729.HK',
#  'CYBN',
#  'PLUGD',
#  '0440.HK',
#  'FVTID',
#  '1930.HK',
#  'CDTI',
#  'PRCX',
#  '688133.SS',
#  'SCRM',
#  'SHALPAINTS.NS',
#  'ATZ.TO',
#  '8187.HK',
#  '1210.HK',
#  'AMST',
#  '603023.SS',
#  'VRSN',
#  'DFRG',
#  'EMHTF',
#  'ALO',
#  'MEC',
#  'CTAQU',
#  'WFT.TO',
#  'NFG',
#  '300050.SZ',
#  'BT-A.L',
#  '8395.HK',
#  'KLTR',
#  '1815.T',
#  'VSVS.L',
#  '0771.HK',
#  'LEAT',
#  'PRO',
#  'GZF.DE',
#  'BDXA',
#  'HRB',
#  '002042.SZ',
#  'AURCU',
#  'AHNR',
#  'TCT.ST',
#  '7816.T',
#  'GUL.AX',
#  'UIHCU',
#  'SRTS',
#  'AQ',
#  'ALAQU.PA',
#  'THYCY',
#  'GRX',
#  'AUC.AX',
#  'EC.PA',
#  'BCI.TO',
#  'MARUY',
#  'TPVG',
#  'MLIA.JK',
#  'ORIA',
#  '688767.SS',
#  'BAYERCROP.NS',
#  '002123.SZ',
#  'WSR',
#  'BWCXP',
#  'XAM.AX',
#  '601877.SS',
#  'SRBANK.OL',
#  'FFHL',
#  'PRU.TO',
#  'OBTC',
#  'CLN.SW',
#  'SLT.DE',
#  'VLD',
#  'EMR.AX',
#  'CAP.PA',
#  'QRMLF',
#  'ZEV-WT',
#  'LSYN',
#  'VWAPY',
#  'RVLV',
#  '4100.T',
#  '3924.T',
#  '7606.T',
#  'AXAC-RI',
#  'GE.SW',
#  'MIGI',
#  'EQT.AX',
#  'ARIES.NS',
#  'DHCNL',
#  'BLUECHIP.NS',
#  '8616.T',
#  'VII',
#  '000972.SZ',
#  'BONAS.ST',
#  '600486.SS',
#  'ADDERA.ST',
#  'SYX',
#  'TRVN',
#  'DBL.NS',
#  '1201.SR',
#  'FRONW',
#  'WINT',
#  'CHI',
#  '3032.TW',
#  'ATC.AX',
#  'CLBR',
#  '6506.T',
#  'CGEM',
#  'NM',
#  'SPG',
#  'AI.TO',
#  '603444.SS',
#  'KYN',
#  '2220.SR',
#  '603363.SS',
#  'MANAPPURAM.NS',
#  '5363.T',
#  'LTHM.L',
#  'ASPO.HE',
#  'TCRI',
#  'LGACW',
#  '0067.HK',
#  'CNV.PA',
#  'CAZ.AX',
#  'GRPAQ',
#  '6908.T',
#  'NTRSP',
#  'STRC',
#  'ISSDY',
#  'BEI.DE',
#  'ACT.L',
#  'GRCY',
#  'AEF',
#  'FULO',
#  '9067.T',
#  'TZPS',
#  '300073.SZ',
#  'GBRGR',
#  '1775.HK',
#  'SWN.DE',
#  'CII',
#  'KND',
#  'IVDN',
#  'PFX',
#  'CBKCQ',
#  '2155.HK',
#  'SIMP.JK',
#  '603896.SS',
#  'VPRB',
#  'IDZ.AX',
#  'MRM',
#  '2231.TW',
#  'WORK',
#  '6196.HK',
#  'LSI.WA',
#  'BOSCHLTD.NS',
#  'HTWS.L',
#  '4722.TW',
#  'KSL.NS',
#  'ACBA',
#  '603319.SS',
#  '2802.T',
#  'GET&D.NS',
#  'QVE.AX',
#  '4725.T',
#  'SLAC-WT',
#  'KMEZ.ME',
#  '002674.SZ',
#  'FERGY',
#  '3052.TW',
#  'HKHHY',
#  'PSA-PN',
#  '8135.HK',
#  'EVEPQ',
#  'A7A.DE',
#  'IGM.TO',
#  'KIRIINDUS.NS',
#  'DONKEY.CO',
#  'MCM.AX',
#  'NESTLEIND.NS',
#  'HON.L',
#  'MXL',
#  '051910.KS',
#  'VLX.L',
#  '0184.HK',
#  '002208.SZ',
#  'NS-PA',
#  '6633.KL',
#  '7100.KL',
#  'RMYHY',
#  'CRWS',
#  'SHIVATEX.NS',
#  '172580.KS',
#  'OPG.L',
#  'DRMAW',
#  'FGNV',
#  'ZMI.AX',
#  'PERI',
#  'RBG.L',
#  'ENDUR.OL',
#  'KINGFA.NS',
#  'VTNA',
#  'KAYS',
#  'SREINFRA.NS',
#  'FRGE',
#  '7532.T',
#  'BML.WA',
#  '4540.TW',
#  'HP3A.DE',
#  'MAGLE.ST',
#  'INAF.JK',
#  'CHWY',
#  'PACE-UN',
#  'CGI.L',
#  '1227.HK',
#  'CTU',
#  '5243.TW',
#  'GKOS',
#  'DYAN.JK',
#  'HMST',
#  'MAXD',
#  'ASB-PD',
#  '601868.SS',
#  'POAHY',
#  '688687.SS',
#  '3447.T',
#  'EJPRY',
#  '4336.HK',
#  'BAC-PN',
#  '0277.HK',
#  'RVIV',
#  '8406.TWO',
#  'FDX.DE',
#  'ASB-PC',
#  'MDEX',
#  'AGI',
#  '4553.T',
#  '6787.T',
#  '7201.SR',
#  'UNIT',
#  'KYK.AX',
#  '0581.HK',
#  '1776.TW',
#  'APLAPOLLO.NS',
#  'AIB',
#  'CVEO',
#  'MUTHOOTFIN.NS',
#  'TTB.AX',
#  '002022.SZ',
#  'FTSV',
#  'TIRT.JK',
#  'PGRE',
#  'VMX.AX',
#  'TYM.L',
#  'MYC',
#  '6178.T',
#  '3MINDIA.NS',
#  'FIX',
#  '000803.SZ',
#  'BZFDW',
#  'ELEC',
#  '4280.SR',
#  'PCF.WA',
#  'MGG.AX',
#  'CTP2.DE',
#  '2723.TW',
#  'FCRM.L',
#  'DLTA.PA',
#  '207940.KS',
#  'BMPG.L',
#  'GWH-WT',
#  '2120.T',
#  '600278.SS',
#  '001620.KS',
#  '688269.SS',
#  'HEAD.ST',
#  'GHY',
#  'MYL',
#  'SPR.L',
#  'SDIP-PREF.ST',
#  'AJX.TO',
#  'EXPCU',
#  'LZRFY',
#  'GMCR',
#  'ZEEL.NS',
#  '000011.SZ',
#  'NMM',
#  'DRVN',
#  'EVFM',
#  '300223.SZ',
#  '4476.T',
#  'BSN.DE',
#  'PIAI-UN',
#  'NDP',
#  'GFN.AX',
#  'EIX',
#  'AWX',
#  'ORGN',
#  'MLHR',
#  'ABEOW',
#  'TAKE.NS',
#  'INR.DE',
#  'IONI',
#  '0889.HK',
#  'IIIV',
#  '000721.SZ',
#  'ENZ',
#  'CU.TO',
#  'REACH.OL',
#  '2012.TW',
#  'JELD',
#  'EDC.AX',
#  'HTAQ-UN',
#  'RAMCOCEM.NS',
#  '2482.TW',
#  'SKIN.SW',
#  'CAMS.NS',
#  'GHH.L',
#  'EXF.TO',
#  '4011.SR',
#  'CEA',
#  'MLECO.PA',
#  'TREAY',
#  'ARIA',
#  'IMU.DE',
#  '000809.SZ',
#  'LUNG',
#  'BKY.AX',
#  'ANGO',
#  '7480.T',
#  '605116.SS',
#  'INGERRAND.NS',
#  'CLRMW',
#  'HNST',
#  'FNOX.ST',
#  'EMKR',
#  'ODY.AX',
#  '4746.T',
#  'ALPC',
#  'NBST',
#  'FSI.AX',
#  'FMTX',
#  '002837.SZ',
#  '600285.SS',
#  'VOLV-B.ST',
#  'CPTK',
#  'SHH.L',
#  'LFAC',
#  'AGRPY',
#  'ACR-PD',
#  'FEET.L',
#  'DEH-WT',
#  'CLA-B.ST',
#  'TSTL.L',
#  'BVA.L',
#  'ECII.JK',
#  '5099.KL',
#  'NTIC',
#  'BELFB',
#  'ALL.WA',
#  '0918.HK',
#  '023000.KS',
#  '000561.SZ',
#  'TJX',
#  'CLNY-PH',
#  'ORISSAMINE.NS',
#  'TWNK',
#  'TETC',
#  '7943.T',
#  'DTG.L',
#  'VTH.AX',
#  'YAKG.ME',
#  'WATT',
#  'OMINFRAL.NS',
#  '2225.HK',
#  'ALB.MC',
#  'RMX.AX',
#  'IGAS.L',
#  'PZS.DE',
#  'IBSU.L',
#  'PCN',
#  '600054.SS',
#  'ALTM',
#  'EXPE',
#  'YALA',
#  'CAA.AX',
#  'WE',
#  'ALOG',
#  'KCGI-WT',
#  'ATER',
#  'ASM.AX',
#  'DVL.NS',
#  'HXG.AX',
#  '3464.T',
#  '688793.SS',
#  'SWBI',
#  'IFIN-UN',
#  'ADALU',
#  'JOUL.L',
#  'FWONK',
#  'GRL.L',
#  '0434.HK',
#  'GTYHU',
#  '600260.SS',
#  '600731.SS',
#  'QTM.AX',
#  'MODN',
#  'ADVI.PA',
#  'HAVELLS.NS',
#  '4390.T',
#  'RVLP',
#  'BFUTILITIE.NS',
#  '601279.SS',
#  '0326.HK',
#  'TMPMW',
#  'TLKM.JK',
#  'HELIO.ST',
#  'ILU.DE',
#  'INDSWFTLTD.NS',
#  'PFND',
#  'AIB.AX',
#  'ALNN6.PA',
#  'IMAHF',
#  'GECCN',
#  '002977.SZ',
#  'EL',
#  '003075.KS',
#  'SHA.DE',
#  '8306.T',
#  '7277.T',
#  '600708.SS',
#  'UDG.L',
#  'KMT',
#  'EXPN.L',
#  'GRPN',
#  '5347.TWO',
#  'TIK',
#  '002170.SZ',
#  'PGR',
#  'PINE',
#  'ROC',
#  'IGNYU',
#  'UEEC',
#  'UVSP',
#  '2936.TW',
#  'AINC',
#  'MCT.L',
#  'PGLI.JK',
#  '600501.SS',
#  'EGL',
#  '1445.TW',
#  'NUM.L',
#  'RDW.L',
#  'VR1.AX',
#  'VISAKAIND.NS',
#  '002745.SZ',
#  'DBREALTY.NS',
#  'GSAQW',
#  'TDHOY',
#  'UCBJY',
#  '688561.SS',
#  'MGCI.L',
#  '000838.SZ',
#  'ORIENTELEC.NS',
#  'BROOKS.NS',
#  '9988.HK',
#  '1129.HK',
#  '1833.T',
#  'BORORENEW.NS',
#  '0295.HK',
#  '600273.SS',
#  'PMBC',
#  'JHY',
#  'BBZA.DE',
#  'BWF.AX',
#  '605289.SS',
#  'JFKKW',
#  'PBHC',
#  '002851.SZ',
#  'SECO',
#  'CSGS',
#  '9999.HK',
#  'ODA.AX',
#  '2098.HK',
#  'VUZ',
#  '003000.KS',
#  'FXCOW',
#  'SQZ',
#  'SKHSY',
#  '3004.SR',
#  'ARGO-PA',
#  '002803.SZ',
#  'RFX.AX',
#  'WHLM',
#  'JAGX',
#  '688707.SS',
#  '1722.TW',
#  'ZINGW',
#  'TEF',
#  'NORBTEAEXP.NS',
#  'TGP-PB',
#  '8137.HK',
#  'IGNYW',
#  '2889.TW',
#  'ELO.AX',
#  '688108.SS',
#  'HFUS',
#  'HHV.L',
#  '6358.T',
#  'AEVA-WT',
#  'GSCLCEMENT.NS',
#  'ALTIA.HE',
#  '3053.T',
#  'WKSP',
#  'SGKN.SW',
#  'FDML',
#  'PRPB-WT',
#  'CREATIVEYE.NS',
#  '002776.SZ',
#  'MORF',
#  'AESANDES.SN',
#  'DVD',
#  'CA.PA',
#  '1593.HK',
#  '2888.TW',
#  'OPN.PA',
#  'ARMP',
#  'AZIHY',
#  '0232.HK',
#  'IDEX.OL',
#  'ASTEC.NS',
#  '8310.HK',
#  '000820.SZ',
#  '2820.T',
#  '002984.SZ',
#  '002485.SZ',
#  'KMPR',
#  'JNP',
#  '1062.HK',
#  '002405.SZ',
#  '4137.TW',
#  'HYQ.DE',
#  'AFG.OL',
#  'HEINY',
#  'LYTWW',
#  'CHMT',
#  'GLIZ.L',
#  'APEN',
#  'CTCM',
#  'ETY.DE',
#  '002489.SZ',
#  'RIB.DE',
#  'BVS',
#  '011170.KS',
#  'FSEN',
#  'RSWM.NS',
#  '3419.TW',
#  '2343.HK',
#  'ETCK',
#  'LFTPP',
#  '1305.HK',
#  '603535.SS',
#  'PGND',
#  '6932.T',
#  '688333.SS',
#  'AURIONPRO.NS',
#  'FWRG',
#  'PRG',
#  'DMYS-UN',
#  '0659.HK',
#  'ALKT',
#  'VER',
#  'MON',
#  'NORBIT.OL',
#  'PCG.AX',
#  '1210.SR',
#  '1413.TW',
#  'LUMN',
#  '300636.SZ',
#  '4681.T',
#  'THCPU',
#  '600939.SS',
#  'SLB.PA',
#  'PUNJLLOYD.NS',
#  '000050.SZ',
#  'GHM',
#  'ECC',
#  'AUTO.V',
#  'SREDY',
#  'HLIO',
#  'PRLB',
#  'CEADW',
#  'GTCH',
#  '4674.T',
#  '8112.HK',
#  'WSI.AX',
#  'APCA',
#  'NSSC',
#  'PXEN.L',
#  'MFT.MI',
#  '300720.KS',
#  'VMAC',
#  '688308.SS',
#  '0769.HK',
#  'HLFFF',
#  'GOODP',
#  '4155.TW',
#  'RLS.ST',
#  '600123.SS',
#  'BAD.TO',
#  'MORE.L',
#  'DAMODARIND.NS',
#  'HEPA',
#  'CTZ.V',
#  '0496.HK',
#  'MCMJW',
#  'NEIK',
#  'VLVLY',
#  'ENGI.PA',
#  'HBSL.NS',
#  '002175.SZ',
#  '1455.TW',
#  'LEA',
#  'AP-WT',
#  'SLC.AX',
#  '688317.SS',
#  '002326.SZ',
#  'PRGO',
#  '603357.SS',
#  'DHCAU',
#  'GLOP',
#  'STRO',
#  '3421.T',
#  '8166.T',
#  '688006.SS',
#  'IDXX',
#  'DPA.AS',
#  'QTRX',
#  'USL',
#  'BROS',
#  'GVC.L',
#  '3316.HK',
#  'NAKD',
#  'CVM',
#  'VIV.PA',
#  'JBGS',
#  'NEW.AX',
#  'PFSI',
#  'MTAL-WT',
#  'CAY.AX',
#  '603722.SS',
#  'UCBIO',
#  '6328.T',
#  'NSI.L',
#  'ABST.TO',
#  'TGA',
#  'MKP.TO',
#  'OSE.PA',
#  '5521.TW',
#  'TCBS',
#  'B4B.SW',
#  'SCIN.L',
#  'PSH.L',
#  'ZSL',
#  'GMBLZ',
#  'PPP.L',
#  'FIACW',
#  '4496.T',
#  '002859.SZ',
#  'HONY.L',
#  '3031.TW',
#  '302440.KS',
#  '603926.SS',
#  'LMG.AX',
#  'MITT-PC',
#  'FJHLD',
#  '950130.KS',
#  '5464.T',
#  '2334.T',
#  '0305.HK',
#  'DRH-PA',
#  '001430.KS',
#  '4064.T',
#  '4762.T',
#  'CIXX',
#  'TIETO.HE',
#  'WELX',
#  'SOLV.BR',
#  'TMRR',
#  'TD.MI',
#  'RELIGARE.NS',
#  'MRRTY',
#  '153360.KS',
#  'MCF',
#  'AKUS',
#  'KO',
#  '6324.T',
#  'IFF.PA',
#  'CMS',
#  '300359.SZ',
#  'WBMD',
#  'GDL',
#  'HNIB.DE',
#  'MIXT',
#  'AZ2.DE',
#  'ASG.AX',
#  'IFNY',
#  'PEB-PD',
#  'QB7.DE',
#  '8361.T',
#  '5352.T',
#  'RGEN',
#  'GPORQ',
#  'MAU.AX',
#  'OMK.SI',
#  '5533.TW',
#  'MC.SW',
#  '0632.HK',
#  '8830.T',
#  'CTICD',
#  '1655.HK',
#  'DOLE',
#  'MAZDA.NS',
#  '002438.SZ',
#  '3275.T',
#  '7315.T',
#  '3923.T',
#  'TMRVL.NS',
#  'TST',
#  'NBB',
#  '002249.SZ',
#  'SOG.PA',
#  'CSSEP',
#  '600644.SS',
#  'CRTN',
#  '600426.SS',
#  '084695.KS',
#  '5484.TW',
#  '2210.SR',
#  'NEX',
#  'VNO',
#  'AC',
#  '2294.T',
#  '688309.SS',
#  'ITAQW',
#  '600551.SS',
#  '1907.HK',
#  '2266.T',
#  '001210.KS',
#  'VCISY',
#  'LB.TO',
#  'SCHP.SW',
#  '192080.KS',
#  '2636.TW',
#  'OXF.L',
#  'CMPO',
#  'MDLZ',
#  'GRBK',
#  '6473.T',
#  '002870.SZ',
#  'MRACU',
#  '9059.KL',
#  'DDD',
#  'DNMR',
#  '5226.KL',
#  'SUPRIYA.NS',
#  'ZEELEARN.NS',
#  'LGEN.L',
#  '600235.SS',
#  'XESP',
#  'LNKD',
#  'LOAK-WT',
#  'D13.AX',
#  '6616.T',
#  'MEND.CN',
#  'GSAQ',
#  '016360.KS',
#  '1260.HK',
#  'CLIG.L',
#  'WALDU',
#  'FEXD',
#  'FMAC-UN',
#  '03473K.KS',
#  'CAPMAN.HE',
#  'VTEX',
#  'DQ5.IR',
#  '6196.T',
#  'DCOM',
#  '601126.SS',
#  'ENI.DE',
#  '688663.SS',
#  'GGE.AX',
#  'OTEL',
#  'DRAY',
#  'WFC.SW',
#  '2867.TW',
#  '6176.TW',
#  '4440.T',
#  'APXI',
#  'ALKEM.PA',
#  '002349.SZ',
#  '003560.KS',
#  '688668.SS',
#  '004140.KS',
#  'FLEXM.ST',
#  'FRU.TO',
#  '603786.SS',
#  'EQE.AX',
#  '4536.TW',
#  'DBRG-PH',
#  '3853.T',
#  'OTGLY',
#  'RAM.LS',
#  '002439.SZ',
#  'ARTNB',
#  '4519.T',
#  '002789.SZ',
#  'GAZ.DE',
#  'MLFMV.LS',
#  'YEXT',
#  '3446.T',
#  '002386.SZ',
#  'NDVN',
#  'WHLR',
#  'TLIS',
#  'MPLS.L',
#  'CDFF.L',
#  'WELL.TO',
#  '0336.HK',
#  'AUDC',
#  'ANIOY',
#  'DQ7A.IR',
#  'PSA-PL',
#  '059090.KS',
#  'SST',
#  'PHOR.ME',
#  'BLUWU',
#  'MOSY',
#  'WPF-WT',
#  'RMAX',
#  '9045.T',
#  'ASHOKLEY.NS',
#  'TOT.TO',
#  'BG',
#  'VINE',
#  'LOGI-B.ST',
#  'ASGLY',
#  '3050.SR',
#  'RGP',
#  'ECHO',
#  'UNITECH.NS',
#  '688055.SS',
#  'NAVA.OL',
#  'N7G.DE',
#  'PWP',
#  'IQNT',
#  'SECARE.ST',
#  'RILY',
#  'WFTLF',
#  'PWOD',
#  'OUST',
#  'BIOS.ST',
#  'JINDALPOLY.NS',
#  'LENB',
#  '4030.SR',
#  'GPRO',
#  'EXO.MI',
#  'OTLK',
#  'KONI.JK',
#  'ALYA',
#  'BTQ.DE',
#  '600186.SS',
#  '0408.HK',
#  'LUMAXTECH.NS',
#  '9J4.F',
#  'GNRC',
#  'CNTWW',
#  'PSTVZ',
#  '002492.SZ',
#  'GROW',
#  'PPH.L',
#  '2169.T',
#  'OBE.TO',
#  'GSAT',
#  'BFC.AX',
#  'GFOR',
#  'GUID',
#  'JZCP.L',
#  '6387.T',
#  'VRNL.PA',
#  'SIVBP',
#  'TIBRU',
#  'NGACU',
#  '0116.HK',
#  'ATHM',
#  'UNVR',
#  'SWGAY',
#  'YCQH',
#  '1875.HK',
#  'SCL.TO',
#  'RUSI.ME',
#  '9992.HK',
#  'LPPS.JK',
#  'PREMIER.NS',
#  'AMOT',
#  '007110.KS',
#  'GUI.PA',
#  'AF.PA',
#  'FYI.AX',
#  'CLBR-UN',
#  'GLBLW',
#  '0011.HK',
#  'ETI-P',
#  'RWT',
#  'TNGNQ',
#  '8104.T',
#  'LBTYK',
#  'ACF.AX',
#  '002172.SZ',
#  '8351.HK',
#  '8061.T',
#  'ASHOKA.NS',
#  'FENC',
#  '002404.SZ',
#  '4488.T',
#  'TRLC',
#  '900140.KS',
#  '8219.HK',
#  'CPINV.BR',
#  '3296.TW',
#  'OTB.L',
#  '600676.SS',
#  'ARRW',
#  'BFIIW',
#  'ARGX.BR',
#  'STYLAMIND.NS',
#  'BTPS.JK',
#  'EXP',
#  'NOAV',
#  'EEP',
#  '603360.SS',
#  'ARTW',
#  'SUNS',
#  'AUUD',
#  'GLJ.DE',
#  'CASN.SW',
#  'PTICW',
#  'KWR.AX',
#  'KIRLOSENG.NS',
#  'HITECH.NS',
#  '600176.SS',
#  'CAS',
#  'GAMCU',
#  'NYMTO',
#  'ESI.TO',
#  'PHIL',
#  '4491.T',
#  'INFOMEDIA.NS',
#  'BHVN',
#  'DORM',
#  'SUNDARMFIN.NS',
#  'ESTER.NS',
#  '085620.KS',
#  'EFOI',
#  '002369.SZ',
#  'AIZN',
#  'BSP.DE',
#  'KRG',
#  '0833.HK',
#  'FBPRO',
#  'COY.AX',
#  'CCOI',
#  'TORO.L',
#  '3308.TW',
#  '6165.TW',
#  '9926.HK',
#  'MDXL',
#  '5192.T',
#  '7378.T',
#  'BXLT',
#  'MCRAA',
#  '002880.SZ',
#  '000885.SZ',
#  'ACKB.BR',
#  '6833.HK',
#  'CIT',
#  'GNTA',
#  '002561.SZ',
#  'VEDL',
#  '2208.TW',
#  '0558.HK',
#  ...]

# %%
US_symbols = []          # 
Canada_symbols = []      #TO
France_symbols = []      #PA ? 
Germany_symbols = []     #DE
India_symbols = []       #NS
London_symbols = []      #L
Hongkong_symbols = []    #HK
Japan_symbols = []       #T
Swiss_symbols = []       #SW
Korea_symbols = []       #KR
Netherlands_symbols = []

for Symbol in Symbols : 
    if ".TO" in Symbol : 
        Canada_symbols.append(Symbol) 
    elif ".PA" in Symbol : 
        France_symbols.append(Symbol) 
    elif ".DE" in Symbol : 
        Germany_symbols.append(Symbol) 
    elif ".NS" in Symbol : 
        India_symbols.append(Symbol) 
    elif ".L" in Symbol : 
        London_symbols.append(Symbol) 
    elif ".HK" in Symbol : 
        Hongkong_symbols.append(Symbol) 
    elif ".T" in Symbol : 
        Japan_symbols.append(Symbol) 
    elif ".SW" in Symbol : 
        Swiss_symbols.append(Symbol) 
    elif ".KS" in Symbol :
        Korea_symbols.append(Symbol)
    elif "." not in Symbol :
        US_symbols.append(Symbol) 
    elif ".EU" in Symbol : 
        Netherlands_symbols.append(Symbol)

# %%
# 국가별 재무정보 추출 기업 수 
print(f"US에서 뽑아낼 수 있는 상장기업 수 : {len(US_symbols)}")
print(f"Canada에서 뽑아낼 수 있는 상장기업 수 : {len(Canada_symbols)}")
print(f"France에서 뽑아낼 수 있는 상장기업 수 : {len(France_symbols)}")
print(f"Germany에서 뽑아낼 수 있는 상장기업 수 : {len(Germany_symbols)}")
print(f"India에서 뽑아낼 수 있는 상장기업 수 : {len(India_symbols)}")
print(f"London에서 뽑아낼 수 있는 상장기업 수 : {len(London_symbols)}")
print(f"Hongkong에서 뽑아낼 수 있는 상장기업 수 : {len(Hongkong_symbols)}")
print(f"Japan에서 뽑아낼 수 있는 상장기업 수 : {len(Japan_symbols)}")
print(f"Swiss에서 뽑아낼 수 있는 상장기업 수 : {len(Swiss_symbols)}")
print(f"Korea에서 뽑아낼 수 있는 상장기업 수 : {len(Korea_symbols)}")
# Out:
# US에서 뽑아낼 수 있는 상장기업 수 : 14959
# Canada에서 뽑아낼 수 있는 상장기업 수 : 845
# France에서 뽑아낼 수 있는 상장기업 수 : 711
# Germany에서 뽑아낼 수 있는 상장기업 수 : 957
# India에서 뽑아낼 수 있는 상장기업 수 : 1836
# London에서 뽑아낼 수 있는 상장기업 수 : 2068
# Hongkong에서 뽑아낼 수 있는 상장기업 수 : 2579
# Japan에서 뽑아낼 수 있는 상장기업 수 : 3513
# Swiss에서 뽑아낼 수 있는 상장기업 수 : 407
# Korea에서 뽑아낼 수 있는 상장기업 수 : 990

# %% [markdown]
# ## Function Setup

# %%
def extractor(url) : 
    try:
        from pandas import json_normalize
    except ImportError:
        from pandas.io.json import json_normalize
    # 데이터 갖고오기
    req=requests.get(url)
    # json load
    data = json.loads(req.text)
    # json to pandas
    preprocessed = json_normalize(data)
    return preprocessed

# %%
def url_generator(target_Symbol, filing_type, limit,period='quarter') : 
    base_url = 'https://financialmodelingprep.com/api/v3/income-statement/RY.TO?limit=5&period=quarter&apikey=89d4891348727c3950b79b9067127c3f'
    if period == 'annual' : 
        base_url = base_url.replace('&period=quarter','')
    
    is_url = base_url.replace('RY.TO', target_Symbol)
    is_url = is_url.replace('=5', '='+str(limit))
    bs_url = is_url.replace('income-statement','balance-sheet-statement')
    cf_url = is_url.replace('income-statement','cash-flow-statement')
    
    if filing_type == 'is' : 
        return is_url
    elif filing_type == 'bs' : 
        return bs_url
    elif filing_type == 'cf' : 
        return cf_url 
    else :
        return "Please input proper filing_type"

# %%
# 손익계산서에서 추출할 핵심정보 
is_cols = ['revenue','costOfRevenue','sellingGeneralAndAdministrativeExpenses','operatingIncome','interestIncome','interestExpense',
          'incomeBeforeTax','netIncome','operatingIncomeRatio'] 
# 대차대조표에서 추출할 핵심정보 
bs_cols = ['fillingDate','totalCurrentAssets','totalNonCurrentAssets','totalAssets', 'totalCurrentLiabilities','totalNonCurrentLiabilities',
           'totalLiabilities','totalEquity','totalLiabilitiesAndTotalEquity']
# 현금흐름표에서 추출할 핵심정보 
cf_cols = ['netCashProvidedByOperatingActivities','netCashUsedForInvestingActivites','netCashUsedProvidedByFinancingActivities',
          'cashAtBeginningOfPeriod','cashAtEndOfPeriod']

# %%
def url_generator(target_Symbol, filing_type, limit,period='quarter') : 
    base_url = 'https://financialmodelingprep.com/api/v3/income-statement/RY.TO?limit=5&period=quarter&apikey=89d4891348727c3950b79b9067127c3f'
    if period == 'annual' : 
        base_url = base_url.replace('&period=quarter','')
    
    is_url = base_url.replace('RY.TO', target_Symbol)
    is_url = is_url.replace('=5', '='+str(limit))
    bs_url = is_url.replace('income-statement','balance-sheet-statement')
    cf_url = is_url.replace('income-statement','cash-flow-statement')
    
    if filing_type == 'is' : 
        return is_url
    elif filing_type == 'bs' : 
        return bs_url
    elif filing_type == 'cf' : 
        return cf_url 
    else :
        return "Please input proper filing_type"

# %% [markdown]
# ## Testing

# %%
    # 기업별 URL 생성 
    is_url = url_generator(target_Symbol, 'is', 2, 'annual')
    bs_url = url_generator(target_Symbol, 'bs', 2, 'annual')
    cf_url = url_generator(target_Symbol, 'cf', 2, 'annual')
    
    # extractor 함수를 이용하여 API를 통한 데이터를 판다스 데이터프레임으로 갖고옴. 
    df_is = extractor(is_url)
    df_bs = extractor(bs_url)
    df_cf = extractor(cf_url)
    
    
    #revenue 만 받는 방법
    print(df_is['revenue'][0])
# Out:
# 827205000

# %% [markdown]
# ## Main Code for Collection

# %%
company_df_list = []
for target_Symbol in tqdm(US_symbols[0:10000]) :  
    
    # 기업별 URL 생성 
    is_url = url_generator(target_Symbol, 'is', 2, 'annual')
    
    # extractor 함수를 이용하여 API를 통한 데이터를 판다스 데이터프레임으로 갖고옴. 
    df_is = extractor(is_url)

    # 오류 회피 
    # 간혹가다 손익 계산서, 대차대조표는 있는데 현금흐름표가 없는등의 문제가 있다. 
    # 모든 경우에 대한 오류 회피 
    # try : 만약 추출해 올 열들에 대한 정보가 존재한다면 불러온다
    # except : 만약 추출 해 올 열들에 대한 정보가 있으면, core_is()
      
        
    #company_df = pd.merge(company_df, df_cf)
    column_names = ['name','name_eng','description_short','description','founded_date','product','homepage','employee_cnt','revenue','ceo_name','email','tel','fax','address1','address2','post_code','facebook','youtube','logo','hash_tag','nation_id','industry_id','is_active','created_at','updated_at']
    df = pd.DataFrame(columns = column_names)
    
    # 숫자 데이터 이외에 필요한 기업 일반정보들을 추가한다. 
    # Financil Modeling Prep의 Company profile API를 이용한다. 
    base_url = 'https://financialmodelingprep.com/api/v3/profile/RY.TO?apikey=89d4891348727c3950b79b9067127c3f'
    target_url = base_url.replace('RY.TO', target_Symbol)
    
    # request로 데이터 갖고오기 
    req = requests.get(target_url)
    data = json.loads(req.text)
    
    # 데이터 명세서에 근거하여 필요한 일반정보 칼럼들만 추출하여 company_df에 추가한다. 
    
    try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
    except :df['name'] = "NA"
    try : df['name_eng'] = data[0]['companyName'] 
    except :df['name_eng'] = "NA"
    try : df['description_short'] = data[0]['description']
    except :df['description_short'] = "NA"
    try : df['description'] =data[0]['description']
    except : df['description'] = "NA"
    try : df['founded_date'] =data[0]['ipoDate']
    except : df['founded_date'] = "NA"
    try : df['product'] =data[0]['industry']
    except : df['product'] = "NA"
    try : df['homepage'] =data[0]['website']
    except : df['homepage'] = "NA"
    try : df['employee_cnt'] =data[0]['fullTimeEmployees']
    except : df['employee_cnt'] = "NA"
    try : 
        df['revenue'] = df_is['revenue'][0]
    except : df['revenue'] = "NA"
    try : 
        df['ceo_name'] = data[0]['ceo']
        if data[0]['ceo'] == "" or data[0]['ceo'] == None or data[0]['ceo'] == "NaN" :
            df['ceo_name'] = "NA"
    except : df['ceo_name'] = "NA"
    try : 
        df['email'] = data[0]['email']
        if data[0]['email'] == "" or data[0]['email'] == None or data[0]['fax'] == "email" :
            df['email'] = "NA"
    except : df['email'] = "NA"
    try : df['tel'] =data[0]['phone']
    except : df['tel'] = "NA"
    try :
        df['fax'] = data[0]['fax']
        if data[0]['fax'] == "" or data[0]['fax'] == None or data[0]['fax'] == "NaN" :
            df['fax'] ="NA"
    except : df['fax'] = "NA"
    try : df['address1'] =data[0]['address']
    except : df['address1'] = "NA"
    try : df['address2'] = data[0]['city'] + ", " + data[0]['state'] + ", " + data[0]['country']
    except : df['address2'] = "NA"
    try : 
        df['post_code'] = data[0]['zip']
        if data[0]['zip'] == "" or data[0]['zip'] == None or data[0]['zip'] == "NaN" :
            df['post_code'] = "NA"
    except : df['post_code'] = "NA"
    try : df['facebook'] = data[0]['website']
    except : df['facebook'] = "NA"
    try : df['youtube'] =data[0]['website']
    except : df['youtube'] = "NA"
    try : df['logo'] =data[0]['image']
    except : df['logo'] = "NA"    
    try : df['hash_tag'] = "#"+ data[0]['companyName'] + ", #" + data[0]['industry'] + ", #" + data[0]['sector']
    except : df['hash_tag'] = "NA"
    try : df['nation_id'] = "17"
    except : df['nation_id'] = "NA"
    try : df['industry_id'] = 1
    except : df['industry_id'] = "NA"
    try : df['is_active'] =data[0]['isActivelyTrading']
    except : df['is_active'] = "NA"
    try : df['created_at'] = '2022-05-23'
    except : df['created_at'] = "NA"
    try : df['updated_at'] = '2022-05-23'
    except : df['updated_at'] = "NA"
    
    company_df_list.append(df)
# Out:
#   0%|                                                                                        | 0/10000 [00:00<?, ?it/s]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|                                                                              | 1/10000 [00:02<6:22:46,  2.30s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|                                                                              | 2/10000 [00:03<5:20:56,  1.93s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|                                                                              | 3/10000 [00:05<4:59:10,  1.80s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|                                                                              | 5/10000 [00:08<4:44:30,  1.71s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|                                                                              | 8/10000 [00:13<4:37:48,  1.67s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|                                                                              | 9/10000 [00:15<4:38:21,  1.67s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|                                                                             | 10/10000 [00:17<4:39:14,  1.68s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|                                                                             | 11/10000 [00:18<4:41:00,  1.69s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|                                                                             | 12/10000 [00:20<4:39:37,  1.68s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|                                                                             | 14/10000 [00:24<4:43:40,  1.70s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|                                                                             | 16/10000 [00:27<4:44:52,  1.71s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|▏                                                                            | 17/10000 [00:29<4:45:08,  1.71s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|▏                                                                            | 18/10000 [00:30<4:45:55,  1.72s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|▏                                                                            | 19/10000 [00:32<4:49:03,  1.74s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|▏                                                                            | 20/10000 [00:34<4:47:54,  1.73s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|▏                                                                            | 21/10000 [00:36<4:49:07,  1.74s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|▏                                                                            | 23/10000 [00:39<4:41:09,  1.69s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|▏                                                                            | 24/10000 [00:41<4:38:38,  1.68s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|▏                                                                            | 25/10000 [00:42<4:42:04,  1.70s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|▏                                                                            | 27/10000 [00:46<4:37:08,  1.67s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|▏                                                                            | 29/10000 [00:49<4:39:30,  1.68s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|▏                                                                            | 30/10000 [00:51<4:38:56,  1.68s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|▏                                                                            | 31/10000 [00:52<4:38:15,  1.67s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|▏                                                                            | 32/10000 [00:54<4:39:04,  1.68s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|▎                                                                            | 33/10000 [00:56<4:37:25,  1.67s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|▎                                                                            | 34/10000 [00:57<4:34:42,  1.65s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|▎                                                                            | 36/10000 [01:01<4:35:53,  1.66s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|▎                                                                            | 38/10000 [01:04<4:31:54,  1.64s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|▎                                                                            | 39/10000 [01:06<4:34:24,  1.65s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|▎                                                                            | 41/10000 [01:09<4:40:51,  1.69s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|▎                                                                            | 42/10000 [01:11<4:38:23,  1.68s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|▎                                                                            | 43/10000 [01:12<4:37:06,  1.67s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|▎                                                                            | 45/10000 [01:16<4:34:59,  1.66s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|▎                                                                            | 46/10000 [01:17<4:38:13,  1.68s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|▎                                                                            | 47/10000 [01:19<4:39:21,  1.68s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|▎                                                                            | 48/10000 [01:21<4:39:14,  1.68s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|▍                                                                            | 49/10000 [01:22<4:37:55,  1.68s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   0%|▍                                                                            | 50/10000 [01:24<4:37:19,  1.67s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▍                                                                            | 51/10000 [01:26<4:38:05,  1.68s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▍                                                                            | 52/10000 [01:27<4:36:35,  1.67s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▍                                                                            | 53/10000 [01:29<4:37:04,  1.67s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▍                                                                            | 54/10000 [01:31<4:41:53,  1.70s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▍                                                                            | 55/10000 [01:33<4:41:02,  1.70s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▍                                                                            | 56/10000 [01:34<4:40:47,  1.69s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▍                                                                            | 57/10000 [01:36<4:40:30,  1.69s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▍                                                                            | 58/10000 [01:37<4:35:15,  1.66s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▍                                                                            | 59/10000 [01:39<4:40:34,  1.69s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▍                                                                            | 60/10000 [01:41<4:39:26,  1.69s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▍                                                                            | 62/10000 [01:44<4:33:55,  1.65s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▍                                                                            | 63/10000 [01:46<4:36:10,  1.67s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▍                                                                            | 64/10000 [01:48<4:37:38,  1.68s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▌                                                                            | 65/10000 [01:49<4:35:45,  1.67s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▌                                                                            | 66/10000 [01:51<4:37:14,  1.67s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▌                                                                            | 67/10000 [01:53<4:42:38,  1.71s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▌                                                                            | 68/10000 [01:54<4:45:46,  1.73s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▌                                                                            | 69/10000 [01:56<4:50:29,  1.76s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▌                                                                            | 71/10000 [02:00<4:47:16,  1.74s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▌                                                                            | 72/10000 [02:01<4:44:46,  1.72s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▌                                                                            | 73/10000 [02:03<4:46:04,  1.73s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▌                                                                            | 74/10000 [02:05<4:47:50,  1.74s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▌                                                                            | 75/10000 [02:07<4:45:43,  1.73s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▌                                                                            | 76/10000 [02:08<4:44:29,  1.72s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▌                                                                            | 77/10000 [02:10<4:44:33,  1.72s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▌                                                                            | 80/10000 [02:15<4:41:42,  1.70s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▌                                                                            | 81/10000 [02:17<4:42:10,  1.71s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▋                                                                            | 83/10000 [02:20<4:39:03,  1.69s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▋                                                                            | 85/10000 [02:24<4:38:46,  1.69s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▋                                                                            | 86/10000 [02:25<4:38:56,  1.69s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▋                                                                            | 87/10000 [02:27<4:38:05,  1.68s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▋                                                                            | 88/10000 [02:29<4:38:26,  1.69s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▋                                                                            | 89/10000 [02:30<4:35:41,  1.67s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▋                                                                            | 90/10000 [02:32<4:35:19,  1.67s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▋                                                                            | 91/10000 [02:34<4:36:25,  1.67s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▋                                                                            | 92/10000 [02:35<4:34:58,  1.67s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▋                                                                            | 93/10000 [02:37<4:35:36,  1.67s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▋                                                                            | 94/10000 [02:39<4:33:17,  1.66s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▋                                                                            | 96/10000 [02:42<4:29:53,  1.64s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▋                                                                            | 97/10000 [02:44<4:37:39,  1.68s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▊                                                                            | 98/10000 [02:45<4:40:54,  1.70s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▊                                                                           | 100/10000 [02:49<4:43:50,  1.72s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▊                                                                           | 101/10000 [02:51<4:43:57,  1.72s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▊                                                                           | 102/10000 [02:52<4:47:57,  1.75s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▊                                                                           | 103/10000 [02:54<4:51:35,  1.77s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▊                                                                           | 105/10000 [02:58<4:48:25,  1.75s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▊                                                                           | 106/10000 [02:59<4:48:21,  1.75s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▊                                                                           | 107/10000 [03:01<4:48:12,  1.75s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▊                                                                           | 108/10000 [03:03<4:45:02,  1.73s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▊                                                                           | 109/10000 [03:05<4:45:17,  1.73s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▊                                                                           | 111/10000 [03:08<4:45:29,  1.73s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▊                                                                           | 112/10000 [03:10<4:47:31,  1.74s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▊                                                                           | 113/10000 [03:12<4:47:09,  1.74s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▉                                                                           | 117/10000 [03:18<4:43:41,  1.72s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▉                                                                           | 120/10000 [03:24<4:42:33,  1.72s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▉                                                                           | 122/10000 [03:27<4:46:28,  1.74s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▉                                                                           | 123/10000 [03:29<4:46:08,  1.74s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▉                                                                           | 124/10000 [03:31<4:45:44,  1.74s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▉                                                                           | 125/10000 [03:32<4:41:19,  1.71s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▉                                                                           | 126/10000 [03:34<4:44:05,  1.73s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▉                                                                           | 127/10000 [03:36<4:44:00,  1.73s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▉                                                                           | 128/10000 [03:37<4:43:50,  1.73s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▉                                                                           | 129/10000 [03:39<4:43:48,  1.73s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|▉                                                                           | 130/10000 [03:41<4:41:33,  1.71s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|█                                                                           | 132/10000 [03:44<4:44:09,  1.73s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|█                                                                           | 133/10000 [03:46<4:51:34,  1.77s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|█                                                                           | 134/10000 [03:48<4:54:59,  1.79s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|█                                                                           | 135/10000 [03:50<4:49:40,  1.76s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|█                                                                           | 137/10000 [03:53<4:45:55,  1.74s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|█                                                                           | 138/10000 [03:55<4:44:57,  1.73s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|█                                                                           | 140/10000 [03:58<4:49:28,  1.76s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|█                                                                           | 141/10000 [04:00<4:51:12,  1.77s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|█                                                                           | 142/10000 [04:02<4:53:38,  1.79s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|█                                                                           | 143/10000 [04:04<4:55:30,  1.80s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|█                                                                           | 144/10000 [04:06<4:55:32,  1.80s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|█                                                                           | 145/10000 [04:07<4:54:29,  1.79s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|█                                                                           | 146/10000 [04:09<4:57:19,  1.81s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|█                                                                           | 147/10000 [04:11<4:52:23,  1.78s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   1%|█▏                                                                          | 149/10000 [04:15<4:52:46,  1.78s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   2%|█▏                                                                          | 150/10000 [04:16<4:49:35,  1.76s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   2%|█▏                                                                          | 151/10000 [04:18<4:50:06,  1.77s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   2%|█▏                                                                          | 153/10000 [04:21<4:42:21,  1.72s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   2%|█▏                                                                          | 154/10000 [04:23<4:40:46,  1.71s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
# ...
#  11%|████████▍                                                                  | 1125/10000 [32:30<4:17:16,  1.74s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  11%|████████▍                                                                  | 1126/10000 [32:32<4:19:04,  1.75s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  11%|████████▍                                                                  | 1128/10000 [32:35<4:15:44,  1.73s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  11%|████████▍                                                                  | 1129/10000 [32:37<4:13:28,  1.71s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  11%|████████▍                                                                  | 1130/10000 [32:39<4:16:10,  1.73s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  11%|████████▍                                                                  | 1132/10000 [32:42<4:19:07,  1.75s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  11%|████████▍                                                                  | 1133/10000 [32:44<4:23:35,  1.78s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  11%|████████▌                                                                  | 1135/10000 [32:47<4:16:19,  1.73s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  11%|████████▌                                                                  | 1136/10000 [32:49<4:20:11,  1.76s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  11%|████████▌                                                                  | 1137/10000 [32:51<4:19:13,  1.75s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  11%|████████▌                                                                  | 1138/10000 [32:53<4:17:10,  1.74s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  11%|████████▌                                                                  | 1141/10000 [32:58<4:16:32,  1.74s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  11%|████████▌                                                                  | 1144/10000 [33:03<4:14:30,  1.72s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  11%|████████▌                                                                  | 1145/10000 [33:05<4:15:15,  1.73s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  11%|████████▌                                                                  | 1147/10000 [33:08<4:15:25,  1.73s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  11%|████████▌                                                                  | 1149/10000 [33:12<4:12:20,  1.71s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  12%|████████▋                                                                  | 1150/10000 [33:13<4:11:58,  1.71s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  12%|████████▋                                                                  | 1151/10000 [33:15<4:12:01,  1.71s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  12%|████████▋                                                                  | 1157/10000 [33:26<4:16:17,  1.74s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  12%|████████▋                                                                  | 1158/10000 [33:27<4:13:53,  1.72s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  12%|████████▋                                                                  | 1159/10000 [33:29<4:16:53,  1.74s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  12%|████████▋                                                                  | 1160/10000 [33:31<4:14:11,  1.73s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  12%|████████▋                                                                  | 1161/10000 [33:32<4:12:51,  1.72s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_1484\3510095088.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  12%|████████▋                                                                  | 1163/10000 [33:38<4:15:35,  1.74s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [13], in <cell line: 2>()
#      24 target_url = base_url.replace('RY.TO', target_Symbol)
#      26 # request로 데이터 갖고오기
# ---> 27 req = requests.get(target_url)
#      28 data = json.loads(req.text)
#      30 # 데이터 명세서에 근거하여 필요한 일반정보 칼럼들만 추출하여 company_df에 추가한다.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     438 try:
#     439     if not chunked:
# --> 440         resp = conn.urlopen(
#     441             method=request.method,
#     442             url=url,
#     443             body=request.body,
#     444             headers=request.headers,
#     445             redirect=False,
#     446             assert_same_host=False,
#     447             preload_content=False,
#     448             decode_content=False,
#     449             retries=self.max_retries,
#     450             timeout=timeout
#     451         )
#     453     # Send the request.
#     454     else:
#     455         if hasattr(conn, 'proxy_pool'):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1269     if flags != 0:
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#    1275     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1127 try:
#    1128     if buffer is not None:
# -> 1129         return self._sslobj.read(len, buffer)
#    1130     else:
#    1131         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # Summary and Visualization

# %%
#Sum up
master_df = pd.concat(company_df_list, ignore_index = True)

# %%
#Visualization
master_df
# Out:
#                                  name                          name_eng  \
# 0          Ethan Allen Interiors Inc.        Ethan Allen Interiors Inc.
# 1     GoGreen Investments Corporation   GoGreen Investments Corporation
# 2    Living Cell Technologies Limited  Living Cell Technologies Limited
# 3            Sunshine Biopharma, Inc.          Sunshine Biopharma, Inc.
# 4                          Cybin Inc.                        Cybin Inc.
# ..                                ...                               ...
# 875             Banco Santander, S.A.             Banco Santander, S.A.
# 876    Reinvent Technology Partners Y    Reinvent Technology Partners Y
# 877    Industrial Human Capital, Inc.    Industrial Human Capital, Inc.
# 878      Broadscale Acquisition Corp.      Broadscale Acquisition Corp.
# 879                    Bloomios, Inc.                    Bloomios, Inc.
#
#                                      description_short  \
# 0    Ethan Allen Interiors Inc. operates as an inte...
# 1    GoGreen Investments Corporation does not have ...
# 2    Living Cell Technologies Limited, a biotechnol...
# 3    Sunshine Biopharma, Inc., a pharmaceutical and...
# 4    Cybin Inc., a biopharmaceutical company, focus...
# ..                                                 ...
# 875  Banco Santander, S.A. provides various retail ...
# 876  Reinvent Technology Partners Y, a blank check ...
# 877  Industrial Human Capital, Inc. does not have s...
# 878  Broadscale Acquisition Corp. does not have sig...
# 879  Bloomios, Inc. manufactures, markets, and dist...
#
#                                            description founded_date  \
# 0    Ethan Allen Interiors Inc. operates as an inte...   1993-03-16
# 1    GoGreen Investments Corporation does not have ...
# 2    Living Cell Technologies Limited, a biotechnol...   2007-07-17
# 3    Sunshine Biopharma, Inc., a pharmaceutical and...
# 4    Cybin Inc., a biopharmaceutical company, focus...   2020-11-11
# ..                                                 ...          ...
# 875  Banco Santander, S.A. provides various retail ...   1987-07-30
# 876  Reinvent Technology Partners Y, a blank check ...   2022-01-31
# 877  Industrial Human Capital, Inc. does not have s...   2005-05-26
# 878  Broadscale Acquisition Corp. does not have sig...   2021-02-12
# 879  Bloomios, Inc. manufactures, markets, and dist...   2003-04-22
#
#                                     product  \
# 0        Furnishings, Fixtures & Appliances
# 1                           Shell Companies
# 2                             Biotechnology
# 3    Drug Manufacturers—Specialty & Generic
# 4                             Biotechnology
# ..                                      ...
# 875                       Banks—Diversified
# 876                         Shell Companies
# 877                         Shell Companies
# 878                         Shell Companies
# 879                         Shell Companies
#
#                                           homepage employee_cnt      revenue  \
# 0                        http://www.ethanallen.com         3369    685169000
# 1               https://www.gogreeninvestments.com                       0.0
# 2                        https://www.lctglobal.com                       0.0
# 3                https://www.sunshinebiopharma.com            3     228426.0
# 4                            https://www.cybin.com           38     864000.0
# ..                                             ...          ...          ...
# 875                      https://www.santander.com       198204  48448000000
# 876  http://y.reinventtechnologypartners.com/about                        NA
# 877            https://www.industrialhuman.capital                       0.0
# 878                     https://broadscalespac.com                       0.0
# 879                       https://www.bloomios.com                 8491651.0
#
#                              ceo_name  ... post_code  \
# 0                 Mr. Farooq Kathwari  ...     06811
# 1                                  NA  ...     77002
# 2                                  NA  ...      2000
# 3                                  NA  ...   H9R 0A5
# 4                                  NA  ...   M5X 1C9
# ..                                ...  ...       ...
# 875  Mr. Jose Antonio Alvarez Alvarez  ...     28660
# 876                                NA  ...     10003
# 877                                NA  ...     33131
# 878                                NA  ...     19103
# 879                                NA  ...     93101
#
#                                           facebook  \
# 0                        http://www.ethanallen.com
# 1               https://www.gogreeninvestments.com
# 2                        https://www.lctglobal.com
# 3                https://www.sunshinebiopharma.com
# 4                            https://www.cybin.com
# ..                                             ...
# 875                      https://www.santander.com
# 876  http://y.reinventtechnologypartners.com/about
# 877            https://www.industrialhuman.capital
# 878                     https://broadscalespac.com
# 879                       https://www.bloomios.com
#
#                                            youtube  \
# 0                        http://www.ethanallen.com
# 1               https://www.gogreeninvestments.com
# 2                        https://www.lctglobal.com
# 3                https://www.sunshinebiopharma.com
# 4                            https://www.cybin.com
# ..                                             ...
# 875                      https://www.santander.com
# 876  http://y.reinventtechnologypartners.com/about
# 877            https://www.industrialhuman.capital
# 878                     https://broadscalespac.com
# 879                       https://www.bloomios.com
#
#                                                   logo  \
# 0    https://financialmodelingprep.com/image-stock/...
# 1    https://financialmodelingprep.com/image-stock/...
# 2    https://financialmodelingprep.com/image-stock/...
# 3    https://financialmodelingprep.com/image-stock/...
# 4    https://financialmodelingprep.com/image-stock/...
# ..                                                 ...
# 875  https://financialmodelingprep.com/image-stock/...
# 876  https://financialmodelingprep.com/image-stock/...
# 877  https://financialmodelingprep.com/image-stock/...
# 878  https://financialmodelingprep.com/image-stock/...
# 879  https://financialmodelingprep.com/image-stock/...
#
#                                               hash_tag nation_id industry_id  \
# 0    #Ethan Allen Interiors Inc., #Furnishings, Fix...        17           1
# 1    #GoGreen Investments Corporation, #Shell Compa...        17           1
# 2    #Living Cell Technologies Limited, #Biotechnol...        17           1
# 3    #Sunshine Biopharma, Inc., #Drug Manufacturers...        17           1
# 4             #Cybin Inc., #Biotechnology, #Healthcare        17           1
# ..                                                 ...       ...         ...
# 875  #Banco Santander, S.A., #Banks—Diversified, #F...        17           1
# 876  #Reinvent Technology Partners Y, #Shell Compan...        17           1
# 877  #Industrial Human Capital, Inc., #Shell Compan...        17           1
# 878  #Broadscale Acquisition Corp., #Shell Companie...        17           1
# 879  #Bloomios, Inc., #Shell Companies, #Financial ...        17           1
#
#     is_active  created_at  updated_at
# 0       False  2022-05-23  2022-05-23
# 1        True  2022-05-23  2022-05-23
# 2        True  2022-05-23  2022-05-23
# 3        True  2022-05-23  2022-05-23
# 4        True  2022-05-23  2022-05-23
# ..        ...         ...         ...
# 875      True  2022-05-23  2022-05-23
# 876     False  2022-05-23  2022-05-23
# 877      True  2022-05-23  2022-05-23
# 878      True  2022-05-23  2022-05-23
# 879      True  2022-05-23  2022-05-23
#
# [880 rows x 25 columns]

# %%
#Visualization2
company_df_list
# Out:
# [                         name                    name_eng  \
#  0  Ethan Allen Interiors Inc.  Ethan Allen Interiors Inc.
#
#                                     description_short  \
#  0  Ethan Allen Interiors Inc. operates as an inte...
#
#                                           description founded_date  \
#  0  Ethan Allen Interiors Inc. operates as an inte...   1993-03-16
#
#                                product                   homepage employee_cnt  \
#  0  Furnishings, Fixtures & Appliances  http://www.ethanallen.com         3369
#
#       revenue             ceo_name  ... post_code                   facebook  \
#  0  685169000  Mr. Farooq Kathwari  ...     06811  http://www.ethanallen.com
#
#                       youtube  \
#  0  http://www.ethanallen.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Ethan Allen Interiors Inc., #Furnishings, Fix...        17           1
#
#    is_active  created_at  updated_at
#  0     False  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                                name                         name_eng  \
#  0  GoGreen Investments Corporation  GoGreen Investments Corporation
#
#                                     description_short  \
#  0  GoGreen Investments Corporation does not have ...
#
#                                           description founded_date  \
#  0  GoGreen Investments Corporation does not have ...
#
#             product                            homepage employee_cnt  revenue  \
#  0  Shell Companies  https://www.gogreeninvestments.com                   0.0
#
#    ceo_name  ... post_code                            facebook  \
#  0       NA  ...     77002  https://www.gogreeninvestments.com
#
#                                youtube  \
#  0  https://www.gogreeninvestments.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #GoGreen Investments Corporation, #Shell Compa...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                                 name                          name_eng  \
#  0  Living Cell Technologies Limited  Living Cell Technologies Limited
#
#                                     description_short  \
#  0  Living Cell Technologies Limited, a biotechnol...
#
#                                           description founded_date  \
#  0  Living Cell Technologies Limited, a biotechnol...   2007-07-17
#
#           product                   homepage employee_cnt  revenue ceo_name  \
#  0  Biotechnology  https://www.lctglobal.com                   0.0       NA
#
#     ... post_code                   facebook                    youtube  \
#  0  ...      2000  https://www.lctglobal.com  https://www.lctglobal.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Living Cell Technologies Limited, #Biotechnol...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                         name                  name_eng  \
#  0  Sunshine Biopharma, Inc.  Sunshine Biopharma, Inc.
#
#                                     description_short  \
#  0  Sunshine Biopharma, Inc., a pharmaceutical and...
#
#                                           description founded_date  \
#  0  Sunshine Biopharma, Inc., a pharmaceutical and...
#
#                                    product                           homepage  \
#  0  Drug Manufacturers—Specialty & Generic  https://www.sunshinebiopharma.com
#
#    employee_cnt   revenue ceo_name  ... post_code  \
#  0            3  228426.0       NA  ...   H9R 0A5
#
#                              facebook                            youtube  \
#  0  https://www.sunshinebiopharma.com  https://www.sunshinebiopharma.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Sunshine Biopharma, Inc., #Drug Manufacturers...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#  Empty DataFrame
#  Columns: [name, name_eng, description_short, description, founded_date, product, homepage, employee_cnt, revenue, ceo_name, email, tel, fax, address1, address2, post_code, facebook, youtube, logo, hash_tag, nation_id, industry_id, is_active, created_at, updated_at]
#  Index: []
#
#  [0 rows x 25 columns],
#           name    name_eng                                  description_short  \
#  0  Cybin Inc.  Cybin Inc.  Cybin Inc., a biopharmaceutical company, focus...
#
#                                           description founded_date  \
#  0  Cybin Inc., a biopharmaceutical company, focus...   2020-11-11
#
#           product               homepage employee_cnt   revenue ceo_name  ...  \
#  0  Biotechnology  https://www.cybin.com           38  864000.0       NA  ...
#
#    post_code               facebook                youtube  \
#  0   M5X 1C9  https://www.cybin.com  https://www.cybin.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                     hash_tag nation_id industry_id is_active  \
#  0  #Cybin Inc., #Biotechnology, #Healthcare        17           1      True
#
#     created_at  updated_at
#  0  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#  Empty DataFrame
#  Columns: [name, name_eng, description_short, description, founded_date, product, homepage, employee_cnt, revenue, ceo_name, email, tel, fax, address1, address2, post_code, facebook, youtube, logo, hash_tag, nation_id, industry_id, is_active, created_at, updated_at]
#  Index: []
#
#  [0 rows x 25 columns],
#  Empty DataFrame
#  Columns: [name, name_eng, description_short, description, founded_date, product, homepage, employee_cnt, revenue, ceo_name, email, tel, fax, address1, address2, post_code, facebook, youtube, logo, hash_tag, nation_id, industry_id, is_active, created_at, updated_at]
#  Index: []
#
#  [0 rows x 25 columns],
#                              name                       name_eng  \
#  0  CDTi Advanced Materials, Inc.  CDTi Advanced Materials, Inc.
#
#                                     description_short  \
#  0  CDTi Advanced Materials, Inc. provides technol...
#
#                                           description founded_date     product  \
#  0  CDTi Advanced Materials, Inc. provides technol...   1995-12-26  Auto Parts
#
#                 homepage employee_cnt   revenue           ceo_name  ...  \
#  0  https://www.cdti.com           46  28353000  Mr. Matthew Beale  ...
#
#    post_code              facebook               youtube  \
#  0     93033  https://www.cdti.com  https://www.cdti.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #CDTi Advanced Materials, Inc., #Auto Parts, #...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                         name                  name_eng  \
#  0  Phoenix Rising Companies  Phoenix Rising Companies
#
#                                     description_short  \
#  0  Phoenix Rising Companies, through its subsidia...
#
#                                           description founded_date  \
#  0  Phoenix Rising Companies, through its subsidia...   2021-06-25
#
#              product                     homepage employee_cnt   revenue  \
#  0  Asset Management  https://www.phoenix-cos.com           20  13430991
#
#    ceo_name  ... post_code                     facebook  \
#  0       NA  ...     30125  https://www.phoenix-cos.com
#
#                         youtube  \
#  0  https://www.phoenix-cos.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Phoenix Rising Companies, #Asset Management, ...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                                  name                           name_eng  \
#  0  Screaming Eagle Acquisition Corp.  Screaming Eagle Acquisition Corp.
#
#                                     description_short  \
#  0  Screaming Eagle Acquisition Corp. focuses on e...
#
#                                           description founded_date  \
#  0  Screaming Eagle Acquisition Corp. focuses on e...   2022-02-28
#
#             product homepage employee_cnt  revenue ceo_name  ... post_code  \
#  0  Shell Companies                            0.0       NA  ...     10075
#
#    facebook youtube                                               logo  \
#  0                   https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Screaming Eagle Acquisition Corp., #Shell Com...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#             name      name_eng  \
#  0  Amesite Inc.  Amesite Inc.
#
#                                     description_short  \
#  0  Amesite Inc., an artificial intelligence drive...
#
#                                           description founded_date  \
#  0  Amesite Inc., an artificial intelligence drive...   2020-09-25
#
#                  product                 homepage employee_cnt   revenue  \
#  0  Software—Application  https://www.amesite.com           22  674580.0
#
#                       ceo_name  ... post_code                 facebook  \
#  0  Dr. Ann Marie Sastry Ph.D.  ...     48226  https://www.amesite.com
#
#                     youtube                                               logo  \
#  0  https://www.amesite.com  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Amesite Inc., #Software—Application, #Technology        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#               name        name_eng  \
#  0  VeriSign, Inc.  VeriSign, Inc.
#
#                                     description_short  \
#  0  VeriSign, Inc., together with its subsidiaries...
#
#                                           description founded_date  \
#  0  VeriSign, Inc., together with its subsidiaries...   1998-01-29
#
#                     product                  homepage employee_cnt     revenue  \
#  0  Software—Infrastructure  https://www.verisign.com          902  1327576000
#
#          ceo_name  ... post_code                  facebook  \
#  0  Mr. D. Bidzos  ...     20190  https://www.verisign.com
#
#                      youtube  \
#  0  https://www.verisign.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #VeriSign, Inc., #Software—Infrastructure, #Te...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#  Empty DataFrame
#  Columns: [name, name_eng, description_short, description, founded_date, product, homepage, employee_cnt, revenue, ceo_name, email, tel, fax, address1, address2, post_code, facebook, youtube, logo, hash_tag, nation_id, industry_id, is_active, created_at, updated_at]
#  Index: []
#
#  [0 rows x 25 columns],
#                                  name                           name_eng  \
#  0  Emerald Health Therapeutics, Inc.  Emerald Health Therapeutics, Inc.
#
#                                     description_short  \
#  0  Emerald Health Therapeutics, Inc., together wi...
#
#                                           description founded_date  \
#  0  Emerald Health Therapeutics, Inc., together wi...   2015-01-02
#
#                                    product                  homepage  \
#  0  Drug Manufacturers—Specialty & Generic  https://emeraldhealth.ca
#
#    employee_cnt   revenue ceo_name  ... post_code                  facebook  \
#  0          110  11740000       NA  ...   V6C 1J8  https://emeraldhealth.ca
#
#                      youtube  \
#  0  https://emeraldhealth.ca
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Emerald Health Therapeutics, Inc., #Drug Manu...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#  Empty DataFrame
#  Columns: [name, name_eng, description_short, description, founded_date, product, homepage, employee_cnt, revenue, ceo_name, email, tel, fax, address1, address2, post_code, facebook, youtube, logo, hash_tag, nation_id, industry_id, is_active, created_at, updated_at]
#  Index: []
#
#  [0 rows x 25 columns],
#                                   name                            name_eng  \
#  0  Mayville Engineering Company, Inc.  Mayville Engineering Company, Inc.
#
#                                     description_short  \
#  0  Mayville Engineering Company, Inc., together w...
#
#                                           description founded_date  \
#  0  Mayville Engineering Company, Inc., together w...   2019-05-09
#
#               product                homepage employee_cnt    revenue  \
#  0  Metal Fabrication  https://www.mecinc.com         2200  454826000
#
#                   ceo_name  ... post_code                facebook  \
#  0  Mr. Robert D. Kamphuis  ...     53050  https://www.mecinc.com
#
#                    youtube                                               logo  \
#  0  https://www.mecinc.com  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Mayville Engineering Company, Inc., #Metal Fa...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                                       name  \
#  0  Carney Technology Acquisition Corp. II
#
#                                   name_eng  \
#  0  Carney Technology Acquisition Corp. II
#
#                                     description_short  \
#  0  Carney Technology Acquisition Corp. II does no...
#
#                                           description founded_date  \
#  0  Carney Technology Acquisition Corp. II does no...   2020-12-10
#
#             product homepage employee_cnt  revenue ceo_name  ... post_code  \
#  0  Shell Companies                            0.0       NA  ...     94301
#
#    facebook youtube                                               logo  \
#  0                   https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Carney Technology Acquisition Corp. II, #Shel...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                          name                   name_eng  \
#  0  National Fuel Gas Company  National Fuel Gas Company
#
#                                     description_short  \
#  0  National Fuel Gas Company operates as a divers...
#
#                                           description founded_date  \
#  0  National Fuel Gas Company operates as a divers...   1955-07-25
#
#                  product                      homepage employee_cnt  \
#  0  Oil & Gas Integrated  https://www.nationalfuel.com         2188
#
#        revenue         ceo_name  ... post_code                      facebook  \
#  0  1742659000  Mr. David Bauer  ...     14221  https://www.nationalfuel.com
#
#                          youtube  \
#  0  https://www.nationalfuel.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #National Fuel Gas Company, #Oil & Gas Integra...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#              name       name_eng  \
#  0  Kaltura, Inc.  Kaltura, Inc.
#
#                                     description_short  \
#  0  Kaltura, Inc. provides various Software-as-a-S...
#
#                                           description founded_date  \
#  0  Kaltura, Inc. provides various Software-as-a-S...   2021-07-21
#
#                     product                 homepage employee_cnt    revenue  \
#  0  Software—Infrastructure  https://www.kaltura.com          758  165016000
#
#    ceo_name  ... post_code                 facebook                  youtube  \
#  0       NA  ...     10003  https://www.kaltura.com  https://www.kaltura.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Kaltura, Inc., #Software—Infrastructure, #Tec...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                  name           name_eng  \
#  0  Leatt Corporation  Leatt Corporation
#
#                                     description_short  \
#  0  Leatt Corporation designs, develops, markets, ...
#
#                                           description founded_date     product  \
#  0  Leatt Corporation designs, develops, markets, ...   2005-08-10  Auto Parts
#
#                  homepage employee_cnt   revenue                     ceo_name  \
#  0  https://www.leatt.com           57  72475813  Dr. Christopher James Leatt
#
#     ... post_code               facebook                youtube  \
#  0  ...      7550  https://www.leatt.com  https://www.leatt.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Leatt Corporation, #Auto Parts, #Consumer Cyc...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                    name             name_eng  \
#  0  PROS Holdings, Inc.  PROS Holdings, Inc.
#
#                                     description_short  \
#  0  PROS Holdings, Inc. provides solutions that op...
#
#                                           description founded_date  \
#  0  PROS Holdings, Inc. provides solutions that op...   2007-06-28
#
#                  product              homepage employee_cnt    revenue  \
#  0  Software—Application  https://www.pros.com         1545  251423000
#
#              ceo_name  ... post_code              facebook  \
#  0  Mr. Andres Reiner  ...     77098  https://www.pros.com
#
#                  youtube                                               logo  \
#  0  https://www.pros.com  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #PROS Holdings, Inc., #Software—Application, #...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#  Empty DataFrame
#  Columns: [name, name_eng, description_short, description, founded_date, product, homepage, employee_cnt, revenue, ceo_name, email, tel, fax, address1, address2, post_code, facebook, youtube, logo, hash_tag, nation_id, industry_id, is_active, created_at, updated_at]
#  Index: []
#
#  [0 rows x 25 columns],
#                name         name_eng  \
#  0  H&R Block, Inc.  H&R Block, Inc.
#
#                                     description_short  \
#  0  H&R Block, Inc., through its subsidiaries, pro...
#
#                                           description founded_date  \
#  0  H&R Block, Inc., through its subsidiaries, pro...   1969-10-13
#
#               product                 homepage employee_cnt     revenue  \
#  0  Personal Services  https://www.hrblock.com         3600  3413987000
#
#              ceo_name  ... post_code                 facebook  \
#  0  Mr. Jeffrey Jones  ...     64105  https://www.hrblock.com
#
#                     youtube                                               logo  \
#  0  https://www.hrblock.com  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #H&R Block, Inc., #Personal Services, #Consume...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                         name                  name_eng  \
#  0  Aurora Acquisition Corp.  Aurora Acquisition Corp.
#
#                                     description_short  \
#  0  Aurora Acquisition Corp. does not have signifi...
#
#                                           description founded_date  \
#  0  Aurora Acquisition Corp. does not have signifi...   2021-03-02
#
#             product                        homepage employee_cnt  revenue  \
#  0  Shell Companies  https://aurora-acquisition.com                   0.0
#
#                 ceo_name  ... post_code                        facebook  \
#  0  Mr. Arnaud  Massenet  ...   W1K 6LX  https://aurora-acquisition.com
#
#                            youtube  \
#  0  https://aurora-acquisition.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Aurora Acquisition Corp., #Shell Companies, #...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                        name                 name_eng  \
#  0  Athena Gold Corporation  Athena Gold Corporation
#
#                                     description_short  \
#  0  Athena Gold Corporation, an exploration stage ...
#
#                                           description founded_date  \
#  0  Athena Gold Corporation, an exploration stage ...   2006-12-08
#
#                            product                    homepage employee_cnt  \
#  0  Other Precious Metals & Mining  https://athenagoldcorp.com
#
#     revenue           ceo_name  ... post_code                    facebook  \
#  0      0.0  Mr. John C. Power  ...     95687  https://athenagoldcorp.com
#
#                        youtube  \
#  0  https://athenagoldcorp.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Athena Gold Corporation, #Other Precious Meta...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#  Empty DataFrame
#  Columns: [name, name_eng, description_short, description, founded_date, product, homepage, employee_cnt, revenue, ceo_name, email, tel, fax, address1, address2, post_code, facebook, youtube, logo, hash_tag, nation_id, industry_id, is_active, created_at, updated_at]
#  Index: []
#
#  [0 rows x 25 columns],
#                        name                 name_eng  \
#  0  Sensus Healthcare, Inc.  Sensus Healthcare, Inc.
#
#                                     description_short  \
#  0  Sensus Healthcare, Inc., a medical device comp...
#
#                                           description founded_date  \
#  0  Sensus Healthcare, Inc., a medical device comp...   2016-06-03
#
#             product                          homepage employee_cnt     revenue  \
#  0  Medical Devices  https://www.sensushealthcare.com           37  27042000.0
#
#               ceo_name  ... post_code                          facebook  \
#  0  Mr. Joseph Sardano  ...     33487  https://www.sensushealthcare.com
#
#                              youtube  \
#  0  https://www.sensushealthcare.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Sensus Healthcare, Inc., #Medical Devices, #H...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#  Empty DataFrame
#  Columns: [name, name_eng, description_short, description, founded_date, product, homepage, employee_cnt, revenue, ceo_name, email, tel, fax, address1, address2, post_code, facebook, youtube, logo, hash_tag, nation_id, industry_id, is_active, created_at, updated_at]
#  Index: []
#
#  [0 rows x 25 columns],
#                            name                     name_eng  \
#  0  Taiheiyo Cement Corporation  Taiheiyo Cement Corporation
#
#                                     description_short  \
#  0  Taiheiyo Cement Corporation engages in the cem...
#
#                                           description founded_date  \
#  0  Taiheiyo Cement Corporation engages in the cem...   2009-04-22
#
#                product                           homepage employee_cnt  \
#  0  Building Materials  https://www.taiheiyo-cement.co.jp        12586
#
#          revenue ceo_name  ... post_code                           facebook  \
#  0  863903000000       NA  ...  112-8503  https://www.taiheiyo-cement.co.jp
#
#                               youtube  \
#  0  https://www.taiheiyo-cement.co.jp
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Taiheiyo Cement Corporation, #Building Materi...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                                        name  \
#  0  The Gabelli Healthcare & Wellness Trust
#
#                                    name_eng  \
#  0  The Gabelli Healthcare & Wellness Trust
#
#                                     description_short  \
#  0  The Gabelli Healthcare and Wellness Trust is a...
#
#                                           description founded_date  \
#  0  The Gabelli Healthcare and Wellness Trust is a...   2007-06-19
#
#              product                                           homepage  \
#  0  Asset Management  https://www.gabelli.com/Template/fundinfo.cfm?...
#
#    employee_cnt   revenue ceo_name  ...   post_code  \
#  0               25005729       NA  ...  10580-1422
#
#                                              facebook  \
#  0  https://www.gabelli.com/Template/fundinfo.cfm?...
#
#                                               youtube  \
#  0  https://www.gabelli.com/Template/fundinfo.cfm?...
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #The Gabelli Healthcare & Wellness Trust, #Ass...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                     name              name_eng  \
#  0  Marubeni Corporation  Marubeni Corporation
#
#                                     description_short  \
#  0  Marubeni Corporation engages in various busine...
#
#                                           description founded_date  \
#  0  Marubeni Corporation engages in various busine...   2010-01-20
#
#           product                  homepage employee_cnt        revenue  \
#  0  Conglomerates  https://www.marubeni.com               6332414000000
#
#    ceo_name  ... post_code                  facebook                   youtube  \
#  0       NA  ...  100-8088  https://www.marubeni.com  https://www.marubeni.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Marubeni Corporation, #Conglomerates, #Indust...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                                     name                              name_eng  \
#  0  TriplePoint Venture Growth BDC Corp.  TriplePoint Venture Growth BDC Corp.
#
#                                     description_short  \
#  0  TriplePoint Venture Growth BDC Corp. is a busi...
#
#                                           description founded_date  \
#  0  TriplePoint Venture Growth BDC Corp. is a busi...   2014-03-06
#
#              product              homepage employee_cnt   revenue  \
#  0  Asset Management  https://www.tpvg.com               87392000
#
#           ceo_name  ... post_code              facebook               youtube  \
#  0  Mr. James Labe  ...     94025  https://www.tpvg.com  https://www.tpvg.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #TriplePoint Venture Growth BDC Corp., #Asset ...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                                  name                           name_eng  \
#  0  Orion Biotech Opportunities Corp.  Orion Biotech Opportunities Corp.
#
#                                     description_short  \
#  0  Orion Biotech Opportunities Corp., a blank che...
#
#                                           description founded_date  \
#  0  Orion Biotech Opportunities Corp., a blank che...   2021-07-02
#
#             product                               homepage employee_cnt  \
#  0  Shell Companies  https://orionbiotechopportunities.com
#
#     revenue ceo_name  ... post_code                               facebook  \
#  0      0.0       NA  ...     10022  https://orionbiotechopportunities.com
#
#                                   youtube  \
#  0  https://orionbiotechopportunities.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Orion Biotech Opportunities Corp., #Shell Com...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                name         name_eng  \
#  0  Whitestone REIT  Whitestone REIT
#
#                                     description_short  \
#  0  Whitestone is a community-centered shopping ce...
#
#                                           description founded_date  \
#  0  Whitestone is a community-centered shopping ce...   2010-08-26
#
#         product                        homepage employee_cnt    revenue  \
#  0  REIT—Retail  https://www.whitestonereit.com           86  125365000
#
#                 ceo_name  ... post_code                        facebook  \
#  0  Mr. James Mastandrea  ...     77063  https://www.whitestonereit.com
#
#                            youtube  \
#  0  https://www.whitestonereit.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                         hash_tag nation_id industry_id  \
#  0  #Whitestone REIT, #REIT—Retail, #Real Estate        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#  Empty DataFrame
#  Columns: [name, name_eng, description_short, description, founded_date, product, homepage, employee_cnt, revenue, ceo_name, email, tel, fax, address1, address2, post_code, facebook, youtube, logo, hash_tag, nation_id, industry_id, is_active, created_at, updated_at]
#  Index: []
#
#  [0 rows x 25 columns],
#                                 name                          name_eng  \
#  0  Fuwei Films (Holdings) Co., Ltd.  Fuwei Films (Holdings) Co., Ltd.
#
#                                     description_short  \
#  0  Fuwei Films (Holdings) Co., Ltd., through its ...
#
#                                           description founded_date  \
#  0  Fuwei Films (Holdings) Co., Ltd., through its ...   2006-11-24
#
#                    product                       homepage employee_cnt  \
#  0  Packaging & Containers  https://www.fuweiholdings.com          208
#
#       revenue           ceo_name  ... post_code                       facebook  \
#  0  396799000  Mr. Zengyong Wang  ...    261061  https://www.fuweiholdings.com
#
#                           youtube  \
#  0  https://www.fuweiholdings.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Fuwei Films (Holdings) Co., Ltd., #Packaging ...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#  Empty DataFrame
#  Columns: [name, name_eng, description_short, description, founded_date, product, homepage, employee_cnt, revenue, ceo_name, email, tel, fax, address1, address2, post_code, facebook, youtube, logo, hash_tag, nation_id, industry_id, is_active, created_at, updated_at]
#  Index: []
#
#  [0 rows x 25 columns],
#             name      name_eng  \
#  0  Velo3D, Inc.  Velo3D, Inc.
#
#                                     description_short  \
#  0  Velo3D, Inc. produces metal additive three dim...
#
#                                           description founded_date  \
#  0  Velo3D, Inc. produces metal additive three dim...   2021-09-24
#
#               product                homepage employee_cnt   revenue ceo_name  \
#  0  Computer Hardware  https://www.velo3d.com          193  27439000       NA
#
#     ... post_code                facebook                 youtube  \
#  0  ...     95008  https://www.velo3d.com  https://www.velo3d.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                           hash_tag nation_id industry_id  \
#  0  #Velo3D, Inc., #Computer Hardware, #Technology        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                         name                  name_eng  \
#  0  Quest Rare Minerals Ltd.  Quest Rare Minerals Ltd.
#
#                                     description_short  \
#  0  Quest Rare Minerals Ltd. focuses on the explor...
#
#                                           description founded_date  \
#  0  Quest Rare Minerals Ltd. focuses on the explor...   2022-01-31
#
#                              product                          homepage  \
#  0  Other Industrial Metals & Mining  http://www.questrareminerals.com
#
#    employee_cnt  revenue ceo_name  ... post_code  \
#  0                   0.0       NA  ...        NA
#
#                             facebook                           youtube  \
#  0  http://www.questrareminerals.com  http://www.questrareminerals.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Quest Rare Minerals Ltd., #Other Industrial M...        17           1
#
#    is_active  created_at  updated_at
#  0     False  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#  Empty DataFrame
#  Columns: [name, name_eng, description_short, description, founded_date, product, homepage, employee_cnt, revenue, ceo_name, email, tel, fax, address1, address2, post_code, facebook, youtube, logo, hash_tag, nation_id, industry_id, is_active, created_at, updated_at]
#  Index: []
#
#  [0 rows x 25 columns],
#                           name                    name_eng  \
#  0  Liberated Syndication Inc.  Liberated Syndication Inc.
#
#                                     description_short  \
#  0  Liberated Syndication Inc. provides podcast an...
#
#                                           description founded_date  \
#  0  Liberated Syndication Inc. provides podcast an...   2016-08-02
#
#                     product            homepage employee_cnt   revenue  \
#  0  Software—Infrastructure  https://libsyn.com           87  24201629
#
#               ceo_name  ... post_code            facebook             youtube  \
#  0  Ms. Laurie A. Sims  ...     15213  https://libsyn.com  https://libsyn.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Liberated Syndication Inc., #Software—Infrast...        17           1
#
#    is_active  created_at  updated_at
#  0     False  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#              name       name_eng  \
#  0  Volkswagen AG  Volkswagen AG
#
#                                     description_short  \
#  0  Volkswagen AG manufactures and sells automobil...
#
#                                           description founded_date  \
#  0  Volkswagen AG manufactures and sells automobil...   2018-11-30
#
#                product                      homepage employee_cnt  \
#  0  Auto Manufacturers  https://www.volkswagenag.com       668294
#
#          revenue ceo_name  ... post_code                      facebook  \
#  0  250199000000       NA  ...     38440  https://www.volkswagenag.com
#
#                          youtube  \
#  0  https://www.volkswagenag.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Volkswagen AG, #Auto Manufacturers, #Consumer...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                    name             name_eng  \
#  0  Revolve Group, Inc.  Revolve Group, Inc.
#
#                                     description_short  \
#  0  Revolve Group, Inc. operates as an online fash...
#
#                                           description founded_date  \
#  0  Revolve Group, Inc. operates as an online fash...   2019-06-07
#
#             product                 homepage employee_cnt    revenue  \
#  0  Internet Retail  https://www.revolve.com         1078  891390000
#
#                    ceo_name  ... post_code                 facebook  \
#  0  Mr. Michael Karanikolas  ...     90703  https://www.revolve.com
#
#                     youtube                                               logo  \
#  0  https://www.revolve.com  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Revolve Group, Inc., #Internet Retail, #Consu...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#  Empty DataFrame
#  Columns: [name, name_eng, description_short, description, founded_date, product, homepage, employee_cnt, revenue, ceo_name, email, tel, fax, address1, address2, post_code, facebook, youtube, logo, hash_tag, nation_id, industry_id, is_active, created_at, updated_at]
#  Index: []
#
#  [0 rows x 25 columns],
#                                  name                           name_eng  \
#  0  Mawson Infrastructure Group, Inc.  Mawson Infrastructure Group, Inc.
#
#                                     description_short  \
#  0  Mawson Infrastructure Group Inc., a digital in...
#
#                                           description founded_date  \
#  0  Mawson Infrastructure Group Inc., a digital in...   2021-06-21
#
#             product                   homepage employee_cnt    revenue  \
#  0  Capital Markets  https://www.mawsoninc.com           40  43862.656
#
#    ceo_name  ... post_code                   facebook  \
#  0       NA  ...      2060  https://www.mawsoninc.com
#
#                       youtube  \
#  0  https://www.mawsoninc.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Mawson Infrastructure Group, Inc., #Capital M...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                             name                      name_eng  \
#  0  Diversified Healthcare Trust  Diversified Healthcare Trust
#
#                                     description_short  \
#  0  DHC is a real estate investment trust, or REIT...
#
#                                           description founded_date product  \
#  0  DHC is a real estate investment trust, or REIT...   2020-01-02    None
#
#                   homepage employee_cnt     revenue ceo_name  ... post_code  \
#  0  http://www.dhcreit.com         None  1383212000       NA  ...        NA
#
#                   facebook                 youtube  \
#  0  http://www.dhcreit.com  http://www.dhcreit.com
#
#                                                  logo hash_tag nation_id  \
#  0  https://financialmodelingprep.com/image-stock/...       NA        17
#
#    industry_id is_active  created_at  updated_at
#  0           1      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                        name                 name_eng  \
#  0  7GC & Co. Holdings Inc.  7GC & Co. Holdings Inc.
#
#                                     description_short  \
#  0  7GC & Co. Holdings Inc. does not have signific...
#
#                                           description founded_date  \
#  0  7GC & Co. Holdings Inc. does not have signific...   2021-02-12
#
#             product                  homepage employee_cnt  revenue ceo_name  \
#  0  Shell Companies  https://www.7gc.holdings         None      0.0     None
#
#     ... post_code                  facebook                   youtube  \
#  0  ...     94111  https://www.7gc.holdings  https://www.7gc.holdings
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #7GC & Co. Holdings Inc., #Shell Companies, #F...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#              name       name_eng  \
#  0  Systemax Inc.  Systemax Inc.
#
#                                     description_short  \
#  0  Systemax Inc., through its subsidiaries, opera...
#
#                                           description founded_date  \
#  0  Systemax Inc., through its subsidiaries, opera...   1995-06-27
#
#                     product                 homepage employee_cnt     revenue  \
#  0  Industrial Distribution  http://www.systemax.com         1480  1029000000
#
#             ceo_name  ... post_code                 facebook  \
#  0  Mr. Barry Litwin  ...     11050  http://www.systemax.com
#
#                     youtube                                               logo  \
#  0  http://www.systemax.com  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Systemax Inc., #Industrial Distribution, #Ind...        17           1
#
#    is_active  created_at  updated_at
#  0     False  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#              name       name_eng  \
#  0  Trevena, Inc.  Trevena, Inc.
#
#                                     description_short  \
#  0  Trevena, Inc., a biopharmaceutical company, fo...
#
#                                           description founded_date  \
#  0  Trevena, Inc., a biopharmaceutical company, fo...   2014-01-31
#
#           product                 homepage employee_cnt  revenue  \
#  0  Biotechnology  https://www.trevena.com           43    567.0
#
#               ceo_name  ... post_code                 facebook  \
#  0  Ms. Carrie Bourdow  ...     19087  https://www.trevena.com
#
#                     youtube                                               logo  \
#  0  https://www.trevena.com  https://financialmodelingprep.com/image-stock/...
#
#                                        hash_tag nation_id industry_id  \
#  0  #Trevena, Inc., #Biotechnology, #Healthcare        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                           name                    name_eng  \
#  0  Frontier Acquisition Corp.  Frontier Acquisition Corp.
#
#                                     description_short  \
#  0  Frontier Acquisition Corp., is a blank check c...
#
#                                           description founded_date product  \
#  0  Frontier Acquisition Corp., is a blank check c...   2021-05-03
#
#    homepage employee_cnt  revenue                   ceo_name  ... post_code  \
#  0                            0.0  Mr. Christian  Angermayer  ...        NA
#
#    facebook youtube                                               logo  \
#  0                   https://financialmodelingprep.com/image-stock/...
#
#                              hash_tag nation_id industry_id is_active  \
#  0  #Frontier Acquisition Corp., #, #        17           1      True
#
#     created_at  updated_at
#  0  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                            name                     name_eng  \
#  0  Windtree Therapeutics, Inc.  Windtree Therapeutics, Inc.
#
#                                     description_short  \
#  0  Windtree Therapeutics, Inc., a clinical-stage ...
#
#                                           description founded_date  \
#  0  Windtree Therapeutics, Inc., a clinical-stage ...   1995-08-09
#
#           product                homepage employee_cnt  revenue  \
#  0  Biotechnology  https://windtreetx.com           33      0.0
#
#             ceo_name  ...   post_code                facebook  \
#  0  Mr. Craig Fraser  ...  18976-3622  https://windtreetx.com
#
#                    youtube                                               logo  \
#  0  https://windtreetx.com  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Windtree Therapeutics, Inc., #Biotechnology, ...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                                                  name  \
#  0  Calamos Convertible Opportunities and Income Fund
#
#                                              name_eng  \
#  0  Calamos Convertible Opportunities and Income Fund
#
#                                     description_short  \
#  0  Calamos Convertible Opportunities and Income F...
#
#                                           description founded_date  \
# ...
#
#                                           description founded_date  \
#  0  R1 RCM Inc. provides revenue cycle management ...   2010-05-20
#
#                         product               homepage employee_cnt  \
#  0  Health Information Services  https://www.r1rcm.com        20800
#
#        revenue             ceo_name  ... post_code               facebook  \
#  0  1474600000  Mr. Joseph Flanagan  ...     84123  https://www.r1rcm.com
#
#                   youtube                                               logo  \
#  0  https://www.r1rcm.com  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #R1 RCM Inc., #Health Information Services, #H...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#  Empty DataFrame
#  Columns: [name, name_eng, description_short, description, founded_date, product, homepage, employee_cnt, revenue, ceo_name, email, tel, fax, address1, address2, post_code, facebook, youtube, logo, hash_tag, nation_id, industry_id, is_active, created_at, updated_at]
#  Index: []
#
#  [0 rows x 25 columns],
#  Empty DataFrame
#  Columns: [name, name_eng, description_short, description, founded_date, product, homepage, employee_cnt, revenue, ceo_name, email, tel, fax, address1, address2, post_code, facebook, youtube, logo, hash_tag, nation_id, industry_id, is_active, created_at, updated_at]
#  Index: []
#
#  [0 rows x 25 columns],
#                           name                    name_eng  \
#  0  Orion Energy Systems, Inc.  Orion Energy Systems, Inc.
#
#                                     description_short  \
#  0  Orion Energy Systems, Inc. researches, designs...
#
#                                           description founded_date  \
#  0  Orion Energy Systems, Inc. researches, designs...   2007-12-19
#
#                          product                       homepage employee_cnt  \
#  0  Electrical Equipment & Parts  https://www.orionlighting.com          213
#
#       revenue                ceo_name  ... post_code  \
#  0  116840000  Mr. Michael Altschaefl  ...     54220
#
#                          facebook                        youtube  \
#  0  https://www.orionlighting.com  https://www.orionlighting.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Orion Energy Systems, Inc., #Electrical Equip...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                        name                 name_eng  \
#  0  Alphatec Holdings, Inc.  Alphatec Holdings, Inc.
#
#                                     description_short  \
#  0  Alphatec Holdings, Inc., a medical technology ...
#
#                                           description founded_date  \
#  0  Alphatec Holdings, Inc., a medical technology ...   2006-06-02
#
#             product                   homepage employee_cnt    revenue  \
#  0  Medical Devices  https://www.atecspine.com          561  243212000
#
#              ceo_name  ... post_code                   facebook  \
#  0  Mr. Patrick Miles  ...     92008  https://www.atecspine.com
#
#                       youtube  \
#  0  https://www.atecspine.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Alphatec Holdings, Inc., #Medical Devices, #H...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                                               name  \
#  0  Mediobanca Banca di Credito Finanziario S.p.A.
#
#                                           name_eng  \
#  0  Mediobanca Banca di Credito Finanziario S.p.A.
#
#                                     description_short  \
#  0  Mediobanca Banca di Credito Finanziario S.p.A....
#
#                                           description founded_date  \
#  0  Mediobanca Banca di Credito Finanziario S.p.A....   2018-02-28
#
#            product                    homepage employee_cnt     revenue  \
#  0  Banks—Regional  https://www.mediobanca.com         4921  2585347000
#
#    ceo_name  ... post_code                    facebook  \
#  0       NA  ...     20121  https://www.mediobanca.com
#
#                        youtube  \
#  0  https://www.mediobanca.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Mediobanca Banca di Credito Finanziario S.p.A...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#  Empty DataFrame
#  Columns: [name, name_eng, description_short, description, founded_date, product, homepage, employee_cnt, revenue, ceo_name, email, tel, fax, address1, address2, post_code, facebook, youtube, logo, hash_tag, nation_id, industry_id, is_active, created_at, updated_at]
#  Index: []
#
#  [0 rows x 25 columns],
#              name       name_eng  \
#  0  Agiliti, Inc.  Agiliti, Inc.
#
#                                     description_short  \
#  0  Agiliti, Inc. provides healthcare technology m...
#
#                                           description founded_date  \
#  0  Agiliti, Inc. provides healthcare technology m...   2021-04-23
#
#                         product                       homepage employee_cnt  \
#  0  Health Information Services  https://www.agilitihealth.com         4900
#
#        revenue               ceo_name  ...   post_code  \
#  0  1038690000  Mr. Thomas J. Leonard  ...  55439-2604
#
#                          facebook                        youtube  \
#  0  https://www.agilitihealth.com  https://www.agilitihealth.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Agiliti, Inc., #Health Information Services, ...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#           name    name_eng                                  description_short  \
#  0  Cyren Ltd.  Cyren Ltd.  Cyren Ltd., together with its subsidiaries, pr...
#
#                                           description founded_date  \
#  0  Cyren Ltd., together with its subsidiaries, pr...   1999-07-15
#
#                     product               homepage employee_cnt   revenue  \
#  0  Software—Infrastructure  https://www.cyren.com          200  31187000
#
#              ceo_name  ... post_code               facebook  \
#  0  Mr. Brett Jackson  ...   4672561  https://www.cyren.com
#
#                   youtube                                               logo  \
#  0  https://www.cyren.com  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Cyren Ltd., #Software—Infrastructure, #Techno...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                                name                         name_eng  \
#  0  1895 Bancorp of Wisconsin, Inc.  1895 Bancorp of Wisconsin, Inc.
#
#                                     description_short  \
#  0  1895 Bancorp of Wisconsin, Inc. operates as a ...
#
#                                           description founded_date  \
#  0  1895 Bancorp of Wisconsin, Inc. operates as a ...   2019-01-09
#
#            product                                homepage employee_cnt  \
#  0  Banks—Regional  https://www.1895bancorpofwisconsin.com          107
#
#      revenue             ceo_name  ... post_code  \
#  0  16972000  Mr. Richard B. Hurd  ...     53220
#
#                                   facebook  \
#  0  https://www.1895bancorpofwisconsin.com
#
#                                    youtube  \
#  0  https://www.1895bancorpofwisconsin.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #1895 Bancorp of Wisconsin, Inc., #Banks—Regio...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                                            name  \
#  0  Malacca Straits Acquisition Company Limited
#
#                                        name_eng  \
#  0  Malacca Straits Acquisition Company Limited
#
#                                     description_short  \
#  0  Malacca Straits Acquisition Company Limited do...
#
#                                           description founded_date  \
#  0  Malacca Straits Acquisition Company Limited do...   2020-08-06
#
#             product                        homepage employee_cnt  revenue  \
#  0  Shell Companies  https://www.malaccastraits.net         None      0.0
#
#            ceo_name  ... post_code                        facebook  \
#  0  Mr. Kenneth  Ng  ...        NA  https://www.malaccastraits.net
#
#                            youtube  \
#  0  https://www.malaccastraits.net
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Malacca Straits Acquisition Company Limited, ...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                            name                     name_eng  \
#  0  Bank of America Corporation  Bank of America Corporation
#
#                                     description_short  \
#  0  Bank of America Corporation, through its subsi...
#
#                                           description founded_date  \
#  0  Bank of America Corporation, through its subsi...   2009-01-02
#
#               product                       homepage employee_cnt      revenue  \
#  0  Banks—Diversified  https://www.bankofamerica.com       208000  89113000000
#
#    ceo_name  ... post_code                       facebook  \
#  0       NA  ...     28255  https://www.bankofamerica.com
#
#                           youtube  \
#  0  https://www.bankofamerica.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Bank of America Corporation, #Banks—Diversifi...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                    name             name_eng  \
#  0  Hudson Global, Inc.  Hudson Global, Inc.
#
#                                     description_short  \
#  0  Hudson Global, Inc. provides talent solutions ...
#
#                                           description founded_date  \
#  0  Hudson Global, Inc. provides talent solutions ...   2003-03-17
#
#                            product                   homepage employee_cnt  \
#  0  Staffing & Employment Services  https://www.hudsonrpo.com         1300
#
#       revenue              ceo_name  ... post_code                   facebook  \
#  0  169207000  Mr. Jeffrey Eberwein  ...     06870  https://www.hudsonrpo.com
#
#                       youtube  \
#  0  https://www.hudsonrpo.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Hudson Global, Inc., #Staffing & Employment S...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                              name                       name_eng  \
#  0  AMN Healthcare Services, Inc.  AMN Healthcare Services, Inc.
#
#                                     description_short  \
#  0  AMN Healthcare Services, Inc. provides healthc...
#
#                                           description founded_date  \
#  0  AMN Healthcare Services, Inc. provides healthc...   2001-11-13
#
#                     product                       homepage employee_cnt  \
#  0  Medical Care Facilities  https://www.amnhealthcare.com         3800
#
#        revenue         ceo_name  ... post_code                       facebook  \
#  0  3984235000  Ms. Susan Salka  ...     75019  https://www.amnhealthcare.com
#
#                           youtube  \
#  0  https://www.amnhealthcare.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #AMN Healthcare Services, Inc., #Medical Care ...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                        name                 name_eng  \
#  0  Provident Bancorp, Inc.  Provident Bancorp, Inc.
#
#                                     description_short  \
#  0  Provident Bancorp, Inc. operates as the bank h...
#
#                                           description founded_date  \
#  0  Provident Bancorp, Inc. operates as the bank h...   2015-07-16
#
#            product                  homepage employee_cnt   revenue  \
#  0  Banks—Regional  https://www.bankprov.com          170  66599000
#
#                   ceo_name  ... post_code                  facebook  \
#  0  Mr. David P. Mansfield  ...     01913  https://www.bankprov.com
#
#                      youtube  \
#  0  https://www.bankprov.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Provident Bancorp, Inc., #Banks—Regional, #Fi...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                                name                         name_eng  \
#  0  Evolution Petroleum Corporation  Evolution Petroleum Corporation
#
#                                     description_short  \
#  0  Evolution Petroleum Corporation, an oil and na...
#
#                                           description founded_date  \
#  0  Evolution Petroleum Corporation, an oil and na...   1996-04-11
#
#           product                            homepage employee_cnt   revenue  \
#  0  Oil & Gas E&P  https://www.evolutionpetroleum.com            5  32702354
#
#            ceo_name  ... post_code                            facebook  \
#  0  Mr. Jason Brown  ...     77079  https://www.evolutionpetroleum.com
#
#                                youtube  \
#  0  https://www.evolutionpetroleum.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Evolution Petroleum Corporation, #Oil & Gas E...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#  Empty DataFrame
#  Columns: [name, name_eng, description_short, description, founded_date, product, homepage, employee_cnt, revenue, ceo_name, email, tel, fax, address1, address2, post_code, facebook, youtube, logo, hash_tag, nation_id, industry_id, is_active, created_at, updated_at]
#  Index: []
#
#  [0 rows x 25 columns],
#  ...]

# %%
#Convert to CSV
master_df.to_csv(r"C:\Users\DT\Desktop\자료\TestData.csv")

# %% [markdown]
# # Testing and Samples

# %%
#Testing Example 1
is_url = url_generator('CA.PA', 'is', 2, 'annual')
bs_url = url_generator('CA.PA', 'bs', 2, 'annual')
cf_url = url_generator('CA.PA', 'cf', 2, 'annual')

# extractor 함수를 이용하여 API를 통한 데이터를 판다스 데이터프레임으로 갖고옴. 
extractor(is_url)
# Out:
#          date symbol reportedCurrency   cik fillingDate acceptedDate  \
# 0  2020-12-31  CA.PA              EUR  None  2020-12-31   2020-12-31
# 1  2019-12-31  CA.PA              EUR  None  2019-12-31   2019-12-31
#
#   calendarYear period      revenue  costOfRevenue  ...  incomeBeforeTaxRatio  \
# 0         2020     FY  72150000000    56705000000  ...              0.018725
# 1         2019     FY  74142000000    58054000000  ...              0.009738
#
#    incomeTaxExpense   netIncome  netIncomeRatio   eps  epsdiluted  \
# 0         498000000   641000000        0.008884  0.80        0.79
# 1         504000000  1129000000        0.015228  1.43        1.42
#
#    weightedAverageShsOut  weightedAverageShsOutDil  \
# 0              805713713                 807587891
# 1              791473793                 792378702
#
#                                                 link  \
# 0  https://www.infogreffe.com/recherche-entrepris...
# 1  https://www.infogreffe.com/recherche-entrepris...
#
#                                            finalLink
# 0  https://www.infogreffe.com/recherche-entrepris...
# 1  https://www.infogreffe.com/recherche-entrepris...
#
# [2 rows x 38 columns]

# %%
#Testing Example 1
extractor(bs_url)
# Out:
#          date symbol reportedCurrency   cik fillingDate acceptedDate  \
# 0  2020-12-31  CA.PA              EUR  None  2020-12-31   2020-12-31
# 1  2019-12-31  CA.PA              EUR  None  2019-12-31   2019-12-31
#
#   calendarYear period  cashAndCashEquivalents  shortTermInvestments  ...  \
# 0         2020     FY              4439000000             179000000  ...
# 1         2019     FY              4466000000              82000000  ...
#
#    totalStockholdersEquity  totalLiabilitiesAndStockholdersEquity  \
# 0               9795000000                            46086000000
# 1               9940000000                            49066000000
#
#    minorityInterest  totalEquity  totalLiabilitiesAndTotalEquity  \
# 0        1502000000  11297000000                     47588000000
# 1        1736000000  11676000000                     50802000000
#
#    totalInvestments    totalDebt     netDebt  \
# 0        1757000000  12112000000  7673000000
# 1        1809000000  11872000000  7406000000
#
#                                                 link  \
# 0  https://www.infogreffe.com/recherche-entrepris...
# 1  https://www.infogreffe.com/recherche-entrepris...
#
#                                            finalLink
# 0  https://www.infogreffe.com/recherche-entrepris...
# 1  https://www.infogreffe.com/recherche-entrepris...
#
# [2 rows x 54 columns]

# %%
#Testing Example 1
extractor(cf_url)
# Out:
#          date symbol reportedCurrency   cik fillingDate acceptedDate  \
# 0  2020-12-31  CA.PA              EUR  None  2020-12-31   2020-12-31
# 1  2019-12-31  CA.PA              EUR  None  2019-12-31   2019-12-31
#
#   calendarYear period   netIncome  depreciationAndAmortization  ...  \
# 0         2020     FY   641000000                   2292000000  ...
# 1         2019     FY  1129000000                   2328000000  ...
#
#    netCashUsedProvidedByFinancingActivities  effectOfForexChangesOnCash  \
# 0                               -1126000000                  -455000000
# 1                               -1987000000                   -81000000
#
#    netChangeInCash  cashAtEndOfPeriod  cashAtBeginningOfPeriod  \
# 0        -27000000         4439000000               4466000000
# 1        166000000         4466000000               4300000000
#
#    operatingCashFlow  capitalExpenditure  freeCashFlow  \
# 0         3395000000         -1614000000    1781000000
# 1         3247000000         -1725000000    1522000000
#
#                                                 link  \
# 0  https://www.infogreffe.com/recherche-entrepris...
# 1  https://www.infogreffe.com/recherche-entrepris...
#
#                                            finalLink
# 0  https://www.infogreffe.com/recherche-entrepris...
# 1  https://www.infogreffe.com/recherche-entrepris...
#
# [2 rows x 40 columns]

# %%
#Testing Example 1
extractor(is_url)
# Out:
#          date symbol reportedCurrency   cik fillingDate acceptedDate  \
# 0  2020-12-31  CA.PA              EUR  None  2020-12-31   2020-12-31
# 1  2019-12-31  CA.PA              EUR  None  2019-12-31   2019-12-31
#
#   calendarYear period      revenue  costOfRevenue  ...  incomeBeforeTaxRatio  \
# 0         2020     FY  72150000000    56705000000  ...              0.018725
# 1         2019     FY  74142000000    58054000000  ...              0.009738
#
#    incomeTaxExpense   netIncome  netIncomeRatio   eps  epsdiluted  \
# 0         498000000   641000000        0.008884  0.80        0.79
# 1         504000000  1129000000        0.015228  1.43        1.42
#
#    weightedAverageShsOut  weightedAverageShsOutDil  \
# 0              805713713                 807587891
# 1              791473793                 792378702
#
#                                                 link  \
# 0  https://www.infogreffe.com/recherche-entrepris...
# 1  https://www.infogreffe.com/recherche-entrepris...
#
#                                            finalLink
# 0  https://www.infogreffe.com/recherche-entrepris...
# 1  https://www.infogreffe.com/recherche-entrepris...
#
# [2 rows x 38 columns]
