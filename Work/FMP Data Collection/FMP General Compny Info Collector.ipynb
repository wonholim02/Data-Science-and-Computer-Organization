# %% [markdown]
# # Using Financial Modeling Prep to Collect General & Financial Information

# %% [markdown]
# ## Setup Local Environment

# %%
import time
from platform import python_version
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
import csv 
try:
    from urllib.request import urlopen
except ImportError:
    from urllib2 import urlopen
import certifi
from tqdm import tqdm

# %%
print(python_version())
print(pd.__version__)
# Out:
# 3.10.4
# 1.4.2

# %%
#check the local address
cover = open('TestData.csv','w', newline='', encoding='UTF-8')
writing = csv.writer(cover)
writing.writerow(['name','name_eng','description_short','description','founded_date','product','homepage','employee_cnt','revenue','ceo_name','email','tel','fax','address1','address2','post_code','facebook','youtube','logo','hash_tag','nation_id','industry_id','is_active','created_at','updated_at'])
# Out:
# 232

# %% [markdown]
# ## Setup API Environment

# %%
def get_jsonparsed_data(url):
    """
    Receive the content of ``url``, parse it as JSON and return the object.

    Parameters
    ----------
    url : str

    Returns
    -------
    dict
    """
    response = urlopen(url, cafile=certifi.where())
    data = response.read().decode("utf-8")
    return json.loads(data)

# %%
url = ("https://financialmodelingprep.com/api/v3/financial-statement-symbol-lists?apikey=33d67d9c5e5ed94ff134e9bf93f9d818")
Symbols = get_jsonparsed_data(url)
# Out:
# C:\Users\DT\AppData\Local\Temp\ipykernel_12272\3606349989.py:13: DeprecationWarning: cafile, capath and cadefault are deprecated, use a custom context instead.
#   response = urlopen(url, cafile=certifi.where())

# %% [markdown]
# ## Check Availability

# %%
Symbols
# Out:
# ['ETH',
#  'GOGN',
#  '000540.SZ',
#  '603931.SS',
#  'JMG.L',
#  '067900.KS',
#  'BSP.AX',
#  'ERM.L',
#  'LVCLY',
#  'SBFMW',
#  'CPAH',
#  'JGLE.JK',
#  'SMWN.DE',
#  '0729.HK',
#  'CYBN',
#  'PLUGD',
#  '0440.HK',
#  'FVTID',
#  '1930.HK',
#  'CDTI',
#  'PRCX',
#  '688133.SS',
#  'SCRM',
#  'SHALPAINTS.NS',
#  'ATZ.TO',
#  '8187.HK',
#  '1210.HK',
#  'AMST',
#  '603023.SS',
#  'VRSN',
#  'DFRG',
#  'EMHTF',
#  'ALO',
#  'MEC',
#  'CTAQU',
#  'WFT.TO',
#  'NFG',
#  '300050.SZ',
#  'BT-A.L',
#  '8395.HK',
#  'KLTR',
#  '1815.T',
#  'VSVS.L',
#  '0771.HK',
#  'LEAT',
#  'PRO',
#  'GZF.DE',
#  'BDXA',
#  'HRB',
#  '002042.SZ',
#  'AURCU',
#  'AHNR',
#  'TCT.ST',
#  '7816.T',
#  'GUL.AX',
#  'UIHCU',
#  'SRTS',
#  'AQ',
#  'ALAQU.PA',
#  'THYCY',
#  'GRX',
#  'AUC.AX',
#  'EC.PA',
#  'BCI.TO',
#  'MARUY',
#  'TPVG',
#  'MLIA.JK',
#  'ORIA',
#  '688767.SS',
#  'BAYERCROP.NS',
#  '002123.SZ',
#  'WSR',
#  'BWCXP',
#  'XAM.AX',
#  '601877.SS',
#  'SRBANK.OL',
#  'FFHL',
#  'PRU.TO',
#  'OBTC',
#  'CLN.SW',
#  'SLT.DE',
#  'VLD',
#  'EMR.AX',
#  'CAP.PA',
#  'QRMLF',
#  'ZEV-WT',
#  'LSYN',
#  'VWAPY',
#  'RVLV',
#  '4100.T',
#  '3924.T',
#  '7606.T',
#  'AXAC-RI',
#  'GE.SW',
#  'MIGI',
#  'EQT.AX',
#  'ARIES.NS',
#  'DHCNL',
#  'BLUECHIP.NS',
#  '8616.T',
#  'VII',
#  '000972.SZ',
#  'BONAS.ST',
#  '600486.SS',
#  'ADDERA.ST',
#  'SYX',
#  'TRVN',
#  'DBL.NS',
#  '1201.SR',
#  'FRONW',
#  'WINT',
#  'CHI',
#  '3032.TW',
#  'ATC.AX',
#  'CLBR',
#  '6506.T',
#  'CGEM',
#  'NM',
#  'SPG',
#  'AI.TO',
#  '603444.SS',
#  'KYN',
#  '2220.SR',
#  '603363.SS',
#  'MANAPPURAM.NS',
#  '5363.T',
#  'LTHM.L',
#  'ASPO.HE',
#  'TCRI',
#  'LGACW',
#  '0067.HK',
#  'CNV.PA',
#  'CAZ.AX',
#  'GRPAQ',
#  '6908.T',
#  'NTRSP',
#  'STRC',
#  'ISSDY',
#  'BEI.DE',
#  'ACT.L',
#  'GRCY',
#  'AEF',
#  'FULO',
#  '9067.T',
#  'TZPS',
#  '300073.SZ',
#  'GBRGR',
#  '1775.HK',
#  'SWN.DE',
#  'CII',
#  'KND',
#  'IVDN',
#  'PFX',
#  'CBKCQ',
#  '2155.HK',
#  'SIMP.JK',
#  '603896.SS',
#  'VPRB',
#  'IDZ.AX',
#  'MRM',
#  '2231.TW',
#  'WORK',
#  '6196.HK',
#  'LSI.WA',
#  'BOSCHLTD.NS',
#  'HTWS.L',
#  '4722.TW',
#  'KSL.NS',
#  'ACBA',
#  '603319.SS',
#  '2802.T',
#  'GET&D.NS',
#  'QVE.AX',
#  '4725.T',
#  'SLAC-WT',
#  'KMEZ.ME',
#  '002674.SZ',
#  'FERGY',
#  '3052.TW',
#  'HKHHY',
#  'PSA-PN',
#  '8135.HK',
#  'EVEPQ',
#  'A7A.DE',
#  'IGM.TO',
#  'KIRIINDUS.NS',
#  'DONKEY.CO',
#  'MCM.AX',
#  'NESTLEIND.NS',
#  'HON.L',
#  'MXL',
#  '051910.KS',
#  'VLX.L',
#  '0184.HK',
#  '002208.SZ',
#  'NS-PA',
#  '6633.KL',
#  '7100.KL',
#  'RMYHY',
#  'CRWS',
#  'SHIVATEX.NS',
#  '172580.KS',
#  'OPG.L',
#  'DRMAW',
#  'FGNV',
#  'ZMI.AX',
#  'PERI',
#  'RBG.L',
#  'ENDUR.OL',
#  'KINGFA.NS',
#  'VTNA',
#  'KAYS',
#  'SREINFRA.NS',
#  'FRGE',
#  '7532.T',
#  'BML.WA',
#  '4540.TW',
#  'HP3A.DE',
#  'MAGLE.ST',
#  'INAF.JK',
#  'CHWY',
#  'PACE-UN',
#  'CGI.L',
#  '1227.HK',
#  'CTU',
#  '5243.TW',
#  'GKOS',
#  'DYAN.JK',
#  'HMST',
#  'MAXD',
#  'ASB-PD',
#  '601868.SS',
#  'POAHY',
#  '688687.SS',
#  '3447.T',
#  'EJPRY',
#  '4336.HK',
#  'BAC-PN',
#  '0277.HK',
#  'RVIV',
#  '8406.TWO',
#  'FDX.DE',
#  'ASB-PC',
#  'MDEX',
#  'AGI',
#  '4553.T',
#  '6787.T',
#  '7201.SR',
#  'UNIT',
#  'KYK.AX',
#  '0581.HK',
#  '1776.TW',
#  'APLAPOLLO.NS',
#  'AIB',
#  'CVEO',
#  'MUTHOOTFIN.NS',
#  'TTB.AX',
#  '002022.SZ',
#  'FTSV',
#  'TIRT.JK',
#  'PGRE',
#  'VMX.AX',
#  'TYM.L',
#  'MYC',
#  '6178.T',
#  '3MINDIA.NS',
#  'FIX',
#  '000803.SZ',
#  'BZFDW',
#  'ELEC',
#  '4280.SR',
#  'PCF.WA',
#  'MGG.AX',
#  'CTP2.DE',
#  '2723.TW',
#  'FCRM.L',
#  'DLTA.PA',
#  '207940.KS',
#  'BMPG.L',
#  'GWH-WT',
#  '2120.T',
#  '600278.SS',
#  '001620.KS',
#  '688269.SS',
#  'HEAD.ST',
#  'GHY',
#  'MYL',
#  'SPR.L',
#  'SDIP-PREF.ST',
#  'AJX.TO',
#  'EXPCU',
#  'LZRFY',
#  'GMCR',
#  'ZEEL.NS',
#  '000011.SZ',
#  'NMM',
#  'DRVN',
#  'EVFM',
#  '300223.SZ',
#  '4476.T',
#  'BSN.DE',
#  'PIAI-UN',
#  'NDP',
#  'GFN.AX',
#  'EIX',
#  'AWX',
#  'ORGN',
#  'MLHR',
#  'ABEOW',
#  'TAKE.NS',
#  'INR.DE',
#  'IONI',
#  '0889.HK',
#  'IIIV',
#  '000721.SZ',
#  'ENZ',
#  'CU.TO',
#  'REACH.OL',
#  '2012.TW',
#  'JELD',
#  'EDC.AX',
#  'HTAQ-UN',
#  'RAMCOCEM.NS',
#  '2482.TW',
#  'SKIN.SW',
#  'CAMS.NS',
#  'GHH.L',
#  'EXF.TO',
#  '4011.SR',
#  'CEA',
#  'MLECO.PA',
#  'TREAY',
#  'ARIA',
#  'IMU.DE',
#  '000809.SZ',
#  'LUNG',
#  'BKY.AX',
#  'ANGO',
#  '7480.T',
#  '605116.SS',
#  'INGERRAND.NS',
#  'CLRMW',
#  'HNST',
#  'FNOX.ST',
#  'EMKR',
#  'ODY.AX',
#  '4746.T',
#  'ALPC',
#  'NBST',
#  'FSI.AX',
#  'FMTX',
#  '002837.SZ',
#  '600285.SS',
#  'VOLV-B.ST',
#  'CPTK',
#  'SHH.L',
#  'LFAC',
#  'AGRPY',
#  'ACR-PD',
#  'FEET.L',
#  'DEH-WT',
#  'CLA-B.ST',
#  'TSTL.L',
#  'BVA.L',
#  'ECII.JK',
#  '5099.KL',
#  'NTIC',
#  'BELFB',
#  'ALL.WA',
#  '0918.HK',
#  '023000.KS',
#  '000561.SZ',
#  'TJX',
#  'CLNY-PH',
#  'ORISSAMINE.NS',
#  'TWNK',
#  'TETC',
#  '7943.T',
#  'DTG.L',
#  'VTH.AX',
#  'YAKG.ME',
#  'WATT',
#  'OMINFRAL.NS',
#  '2225.HK',
#  'ALB.MC',
#  'RMX.AX',
#  'IGAS.L',
#  'PZS.DE',
#  'IBSU.L',
#  'PCN',
#  '600054.SS',
#  'ALTM',
#  'EXPE',
#  'YALA',
#  'CAA.AX',
#  'WE',
#  'ALOG',
#  'KCGI-WT',
#  'ATER',
#  'ASM.AX',
#  'DVL.NS',
#  'HXG.AX',
#  '3464.T',
#  '688793.SS',
#  'SWBI',
#  'IFIN-UN',
#  'ADALU',
#  'JOUL.L',
#  'FWONK',
#  'GRL.L',
#  '0434.HK',
#  'GTYHU',
#  '600260.SS',
#  '600731.SS',
#  'QTM.AX',
#  'MODN',
#  'ADVI.PA',
#  'HAVELLS.NS',
#  '4390.T',
#  'RVLP',
#  'BFUTILITIE.NS',
#  '601279.SS',
#  '0326.HK',
#  'TMPMW',
#  'TLKM.JK',
#  'HELIO.ST',
#  'ILU.DE',
#  'INDSWFTLTD.NS',
#  'PFND',
#  'AIB.AX',
#  'ALNN6.PA',
#  'IMAHF',
#  'GECCN',
#  '002977.SZ',
#  'EL',
#  '003075.KS',
#  'SHA.DE',
#  '8306.T',
#  '7277.T',
#  '600708.SS',
#  'UDG.L',
#  'KMT',
#  'EXPN.L',
#  'GRPN',
#  '5347.TWO',
#  'TIK',
#  '002170.SZ',
#  'PGR',
#  'PINE',
#  'ROC',
#  'IGNYU',
#  'UEEC',
#  'UVSP',
#  '2936.TW',
#  'AINC',
#  'MCT.L',
#  'PGLI.JK',
#  '600501.SS',
#  'EGL',
#  '1445.TW',
#  'NUM.L',
#  'RDW.L',
#  'VR1.AX',
#  'VISAKAIND.NS',
#  '002745.SZ',
#  'DBREALTY.NS',
#  'GSAQW',
#  'TDHOY',
#  'UCBJY',
#  '688561.SS',
#  'MGCI.L',
#  '000838.SZ',
#  'ORIENTELEC.NS',
#  'BROOKS.NS',
#  '9988.HK',
#  '1129.HK',
#  '1833.T',
#  'BORORENEW.NS',
#  '0295.HK',
#  '600273.SS',
#  'PMBC',
#  'JHY',
#  'BBZA.DE',
#  'BWF.AX',
#  '605289.SS',
#  'JFKKW',
#  'PBHC',
#  '002851.SZ',
#  'SECO',
#  'CSGS',
#  '9999.HK',
#  'ODA.AX',
#  '2098.HK',
#  'VUZ',
#  '003000.KS',
#  'FXCOW',
#  'SQZ',
#  'SKHSY',
#  '3004.SR',
#  'ARGO-PA',
#  '002803.SZ',
#  'RFX.AX',
#  'WHLM',
#  'JAGX',
#  '688707.SS',
#  '1722.TW',
#  'ZINGW',
#  'TEF',
#  'NORBTEAEXP.NS',
#  'TGP-PB',
#  '8137.HK',
#  'IGNYW',
#  '2889.TW',
#  'ELO.AX',
#  '688108.SS',
#  'HFUS',
#  'HHV.L',
#  '6358.T',
#  'AEVA-WT',
#  'GSCLCEMENT.NS',
#  'ALTIA.HE',
#  '3053.T',
#  'WKSP',
#  'SGKN.SW',
#  'FDML',
#  'PRPB-WT',
#  'CREATIVEYE.NS',
#  '002776.SZ',
#  'MORF',
#  'AESANDES.SN',
#  'DVD',
#  'CA.PA',
#  '1593.HK',
#  '2888.TW',
#  'OPN.PA',
#  'ARMP',
#  'AZIHY',
#  '0232.HK',
#  'IDEX.OL',
#  'ASTEC.NS',
#  '8310.HK',
#  '000820.SZ',
#  '2820.T',
#  '002984.SZ',
#  '002485.SZ',
#  'KMPR',
#  'JNP',
#  '1062.HK',
#  '002405.SZ',
#  '4137.TW',
#  'HYQ.DE',
#  'AFG.OL',
#  'HEINY',
#  'LYTWW',
#  'CHMT',
#  'GLIZ.L',
#  'APEN',
#  'CTCM',
#  'ETY.DE',
#  '002489.SZ',
#  'RIB.DE',
#  'BVS',
#  '011170.KS',
#  'FSEN',
#  'RSWM.NS',
#  '3419.TW',
#  '2343.HK',
#  'ETCK',
#  'LFTPP',
#  '1305.HK',
#  '603535.SS',
#  'PGND',
#  '6932.T',
#  '688333.SS',
#  'AURIONPRO.NS',
#  'FWRG',
#  'PRG',
#  'DMYS-UN',
#  '0659.HK',
#  'ALKT',
#  'VER',
#  'MON',
#  'NORBIT.OL',
#  'PCG.AX',
#  '1210.SR',
#  '1413.TW',
#  'LUMN',
#  '300636.SZ',
#  '4681.T',
#  'THCPU',
#  '600939.SS',
#  'SLB.PA',
#  'PUNJLLOYD.NS',
#  '000050.SZ',
#  'GHM',
#  'ECC',
#  'AUTO.V',
#  'SREDY',
#  'HLIO',
#  'PRLB',
#  'CEADW',
#  'GTCH',
#  '4674.T',
#  '8112.HK',
#  'WSI.AX',
#  'APCA',
#  'NSSC',
#  'PXEN.L',
#  'MFT.MI',
#  '300720.KS',
#  'VMAC',
#  '688308.SS',
#  '0769.HK',
#  'HLFFF',
#  'GOODP',
#  '4155.TW',
#  'RLS.ST',
#  '600123.SS',
#  'BAD.TO',
#  'MORE.L',
#  'DAMODARIND.NS',
#  'HEPA',
#  'CTZ.V',
#  '0496.HK',
#  'MCMJW',
#  'NEIK',
#  'VLVLY',
#  'ENGI.PA',
#  'HBSL.NS',
#  '002175.SZ',
#  '1455.TW',
#  'LEA',
#  'AP-WT',
#  'SLC.AX',
#  '688317.SS',
#  '002326.SZ',
#  'PRGO',
#  '603357.SS',
#  'DHCAU',
#  'GLOP',
#  'STRO',
#  '3421.T',
#  '8166.T',
#  '688006.SS',
#  'IDXX',
#  'DPA.AS',
#  'QTRX',
#  'USL',
#  'BROS',
#  'GVC.L',
#  '3316.HK',
#  'NAKD',
#  'CVM',
#  'VIV.PA',
#  'JBGS',
#  'NEW.AX',
#  'PFSI',
#  'MTAL-WT',
#  'CAY.AX',
#  '603722.SS',
#  'UCBIO',
#  '6328.T',
#  'NSI.L',
#  'ABST.TO',
#  'TGA',
#  'MKP.TO',
#  'OSE.PA',
#  '5521.TW',
#  'TCBS',
#  'B4B.SW',
#  'SCIN.L',
#  'PSH.L',
#  'ZSL',
#  'GMBLZ',
#  'PPP.L',
#  'FIACW',
#  '4496.T',
#  '002859.SZ',
#  'HONY.L',
#  '3031.TW',
#  '302440.KS',
#  '603926.SS',
#  'LMG.AX',
#  'MITT-PC',
#  'FJHLD',
#  '950130.KS',
#  '5464.T',
#  '2334.T',
#  '0305.HK',
#  'DRH-PA',
#  '001430.KS',
#  '4064.T',
#  '4762.T',
#  'CIXX',
#  'TIETO.HE',
#  'WELX',
#  'SOLV.BR',
#  'TMRR',
#  'TD.MI',
#  'RELIGARE.NS',
#  'MRRTY',
#  '153360.KS',
#  'MCF',
#  'AKUS',
#  'KO',
#  '6324.T',
#  'IFF.PA',
#  'CMS',
#  '300359.SZ',
#  'WBMD',
#  'GDL',
#  'HNIB.DE',
#  'MIXT',
#  'AZ2.DE',
#  'ASG.AX',
#  'IFNY',
#  'PEB-PD',
#  'QB7.DE',
#  '8361.T',
#  '5352.T',
#  'RGEN',
#  'GPORQ',
#  'MAU.AX',
#  'OMK.SI',
#  '5533.TW',
#  'MC.SW',
#  '0632.HK',
#  '8830.T',
#  'CTICD',
#  '1655.HK',
#  'DOLE',
#  'MAZDA.NS',
#  '002438.SZ',
#  '3275.T',
#  '7315.T',
#  '3923.T',
#  'TMRVL.NS',
#  'TST',
#  'NBB',
#  '002249.SZ',
#  'SOG.PA',
#  'CSSEP',
#  '600644.SS',
#  'CRTN',
#  '600426.SS',
#  '084695.KS',
#  '5484.TW',
#  '2210.SR',
#  'NEX',
#  'VNO',
#  'AC',
#  '2294.T',
#  '688309.SS',
#  'ITAQW',
#  '600551.SS',
#  '1907.HK',
#  '2266.T',
#  '001210.KS',
#  'VCISY',
#  'LB.TO',
#  'SCHP.SW',
#  '192080.KS',
#  '2636.TW',
#  'OXF.L',
#  'CMPO',
#  'MDLZ',
#  'GRBK',
#  '6473.T',
#  '002870.SZ',
#  'MRACU',
#  '9059.KL',
#  'DDD',
#  'DNMR',
#  '5226.KL',
#  'SUPRIYA.NS',
#  'ZEELEARN.NS',
#  'LGEN.L',
#  '600235.SS',
#  'XESP',
#  'LNKD',
#  'LOAK-WT',
#  'D13.AX',
#  '6616.T',
#  'MEND.CN',
#  'GSAQ',
#  '016360.KS',
#  '1260.HK',
#  'CLIG.L',
#  'WALDU',
#  'FEXD',
#  'FMAC-UN',
#  '03473K.KS',
#  'CAPMAN.HE',
#  'VTEX',
#  'DQ5.IR',
#  '6196.T',
#  'DCOM',
#  '601126.SS',
#  'ENI.DE',
#  '688663.SS',
#  'GGE.AX',
#  'OTEL',
#  'DRAY',
#  'WFC.SW',
#  '2867.TW',
#  '6176.TW',
#  '4440.T',
#  'APXI',
#  'ALKEM.PA',
#  '002349.SZ',
#  '003560.KS',
#  '688668.SS',
#  '004140.KS',
#  'FLEXM.ST',
#  'FRU.TO',
#  '603786.SS',
#  'EQE.AX',
#  '4536.TW',
#  'DBRG-PH',
#  '3853.T',
#  'OTGLY',
#  'RAM.LS',
#  '002439.SZ',
#  'ARTNB',
#  '4519.T',
#  '002789.SZ',
#  'GAZ.DE',
#  'MLFMV.LS',
#  'YEXT',
#  '3446.T',
#  '002386.SZ',
#  'NDVN',
#  'WHLR',
#  'TLIS',
#  'MPLS.L',
#  'CDFF.L',
#  'WELL.TO',
#  '0336.HK',
#  'AUDC',
#  'ANIOY',
#  'DQ7A.IR',
#  'PSA-PL',
#  '059090.KS',
#  'SST',
#  'PHOR.ME',
#  'BLUWU',
#  'MOSY',
#  'WPF-WT',
#  'RMAX',
#  '9045.T',
#  'ASHOKLEY.NS',
#  'TOT.TO',
#  'BG',
#  'VINE',
#  'LOGI-B.ST',
#  'ASGLY',
#  '3050.SR',
#  'RGP',
#  'ECHO',
#  'UNITECH.NS',
#  '688055.SS',
#  'NAVA.OL',
#  'N7G.DE',
#  'PWP',
#  'IQNT',
#  'SECARE.ST',
#  'RILY',
#  'WFTLF',
#  'PWOD',
#  'OUST',
#  'BIOS.ST',
#  'JINDALPOLY.NS',
#  'LENB',
#  '4030.SR',
#  'GPRO',
#  'EXO.MI',
#  'OTLK',
#  'KONI.JK',
#  'ALYA',
#  'BTQ.DE',
#  '600186.SS',
#  '0408.HK',
#  'LUMAXTECH.NS',
#  '9J4.F',
#  'GNRC',
#  'CNTWW',
#  'PSTVZ',
#  '002492.SZ',
#  'GROW',
#  'PPH.L',
#  '2169.T',
#  'OBE.TO',
#  'GSAT',
#  'BFC.AX',
#  'GFOR',
#  'GUID',
#  'JZCP.L',
#  '6387.T',
#  'VRNL.PA',
#  'SIVBP',
#  'TIBRU',
#  'NGACU',
#  '0116.HK',
#  'ATHM',
#  'UNVR',
#  'SWGAY',
#  'YCQH',
#  '1875.HK',
#  'SCL.TO',
#  'RUSI.ME',
#  '9992.HK',
#  'LPPS.JK',
#  'PREMIER.NS',
#  'AMOT',
#  '007110.KS',
#  'GUI.PA',
#  'AF.PA',
#  'FYI.AX',
#  'CLBR-UN',
#  'GLBLW',
#  '0011.HK',
#  'ETI-P',
#  'RWT',
#  'TNGNQ',
#  '8104.T',
#  'LBTYK',
#  'ACF.AX',
#  '002172.SZ',
#  '8351.HK',
#  '8061.T',
#  'ASHOKA.NS',
#  'FENC',
#  '002404.SZ',
#  '4488.T',
#  'TRLC',
#  '900140.KS',
#  '8219.HK',
#  'CPINV.BR',
#  '3296.TW',
#  'OTB.L',
#  '600676.SS',
#  'ARRW',
#  'BFIIW',
#  'ARGX.BR',
#  'STYLAMIND.NS',
#  'BTPS.JK',
#  'EXP',
#  'NOAV',
#  'EEP',
#  '603360.SS',
#  'ARTW',
#  'SUNS',
#  'AUUD',
#  'GLJ.DE',
#  'CASN.SW',
#  'PTICW',
#  'KWR.AX',
#  'KIRLOSENG.NS',
#  'HITECH.NS',
#  '600176.SS',
#  'CAS',
#  'GAMCU',
#  'NYMTO',
#  'ESI.TO',
#  'PHIL',
#  '4491.T',
#  'INFOMEDIA.NS',
#  'BHVN',
#  'DORM',
#  'SUNDARMFIN.NS',
#  'ESTER.NS',
#  '085620.KS',
#  'EFOI',
#  '002369.SZ',
#  'AIZN',
#  'BSP.DE',
#  'KRG',
#  '0833.HK',
#  'FBPRO',
#  'COY.AX',
#  'CCOI',
#  'TORO.L',
#  '3308.TW',
#  '6165.TW',
#  '9926.HK',
#  'MDXL',
#  '5192.T',
#  '7378.T',
#  'BXLT',
#  'MCRAA',
#  '002880.SZ',
#  '000885.SZ',
#  'ACKB.BR',
#  '6833.HK',
#  'CIT',
#  'GNTA',
#  '002561.SZ',
#  'VEDL',
#  '2208.TW',
#  '0558.HK',
#  ...]

# %%
US_symbols = []          # 
Canada_symbols = []      #TO
France_symbols = []      #PA ? 
Germany_symbols = []     #DE
India_symbols = []       #NS
London_symbols = []      #L
Hongkong_symbols = []    #HK
Japan_symbols = []       #T
Swiss_symbols = []       #SW
Korea_symbols = []       #KR
Netherlands_symbols = []

for Symbol in Symbols : 
    if ".TO" in Symbol : 
        Canada_symbols.append(Symbol) 
    elif ".PA" in Symbol : 
        France_symbols.append(Symbol) 
    elif ".DE" in Symbol : 
        Germany_symbols.append(Symbol) 
    elif ".NS" in Symbol : 
        India_symbols.append(Symbol) 
    elif ".L" in Symbol : 
        London_symbols.append(Symbol) 
    elif ".HK" in Symbol : 
        Hongkong_symbols.append(Symbol) 
    elif ".T" in Symbol : 
        Japan_symbols.append(Symbol) 
    elif ".SW" in Symbol : 
        Swiss_symbols.append(Symbol) 
    elif ".KS" in Symbol :
        Korea_symbols.append(Symbol)
    elif "." not in Symbol :
        US_symbols.append(Symbol) 
    elif ".EU" in Symbol : 
        Netherlands_symbols.append(Symbol)

# %%
# 국가별 재무정보 추출 기업 수 
print(f"US에서 뽑아낼 수 있는 상장기업 수 : {len(US_symbols)}")
print(f"Canada에서 뽑아낼 수 있는 상장기업 수 : {len(Canada_symbols)}")
print(f"France에서 뽑아낼 수 있는 상장기업 수 : {len(France_symbols)}")
print(f"Germany에서 뽑아낼 수 있는 상장기업 수 : {len(Germany_symbols)}")
print(f"India에서 뽑아낼 수 있는 상장기업 수 : {len(India_symbols)}")
print(f"London에서 뽑아낼 수 있는 상장기업 수 : {len(London_symbols)}")
print(f"Hongkong에서 뽑아낼 수 있는 상장기업 수 : {len(Hongkong_symbols)}")
print(f"Japan에서 뽑아낼 수 있는 상장기업 수 : {len(Japan_symbols)}")
print(f"Swiss에서 뽑아낼 수 있는 상장기업 수 : {len(Swiss_symbols)}")
print(f"Korea에서 뽑아낼 수 있는 상장기업 수 : {len(Korea_symbols)}")
# Out:
# US에서 뽑아낼 수 있는 상장기업 수 : 14959
# Canada에서 뽑아낼 수 있는 상장기업 수 : 845
# France에서 뽑아낼 수 있는 상장기업 수 : 711
# Germany에서 뽑아낼 수 있는 상장기업 수 : 957
# India에서 뽑아낼 수 있는 상장기업 수 : 1836
# London에서 뽑아낼 수 있는 상장기업 수 : 2068
# Hongkong에서 뽑아낼 수 있는 상장기업 수 : 2579
# Japan에서 뽑아낼 수 있는 상장기업 수 : 3513
# Swiss에서 뽑아낼 수 있는 상장기업 수 : 407
# Korea에서 뽑아낼 수 있는 상장기업 수 : 990

# %% [markdown]
# ## Function Setup

# %%
def extractor(url) : 
    try:
        from pandas import json_normalize
    except ImportError:
        from pandas.io.json import json_normalize
    # 데이터 갖고오기
    req=requests.get(url)
    # json load
    data = json.loads(req.text)
    # json to pandas
    preprocessed = json_normalize(data)
    return preprocessed

# %%
def url_generator(target_Symbol, filing_type, limit,period='quarter') : 
    base_url = 'https://financialmodelingprep.com/api/v3/income-statement/RY.TO?limit=5&period=quarter&apikey=89d4891348727c3950b79b9067127c3f'
    if period == 'annual' : 
        base_url = base_url.replace('&period=quarter','')
    
    is_url = base_url.replace('RY.TO', target_Symbol)
    is_url = is_url.replace('=5', '='+str(limit))
    bs_url = is_url.replace('income-statement','balance-sheet-statement')
    cf_url = is_url.replace('income-statement','cash-flow-statement')
    
    if filing_type == 'is' : 
        return is_url
    elif filing_type == 'bs' : 
        return bs_url
    elif filing_type == 'cf' : 
        return cf_url 
    else :
        return "Please input proper filing_type"

# %%
# 손익계산서에서 추출할 핵심정보 
is_cols = ['revenue','costOfRevenue','sellingGeneralAndAdministrativeExpenses','operatingIncome','interestIncome','interestExpense',
          'incomeBeforeTax','netIncome','operatingIncomeRatio'] 
# 대차대조표에서 추출할 핵심정보 
bs_cols = ['fillingDate','totalCurrentAssets','totalNonCurrentAssets','totalAssets', 'totalCurrentLiabilities','totalNonCurrentLiabilities',
           'totalLiabilities','totalEquity','totalLiabilitiesAndTotalEquity']
# 현금흐름표에서 추출할 핵심정보 
cf_cols = ['netCashProvidedByOperatingActivities','netCashUsedForInvestingActivites','netCashUsedProvidedByFinancingActivities',
          'cashAtBeginningOfPeriod','cashAtEndOfPeriod']

# %%
def url_generator(target_Symbol, filing_type, limit,period='quarter') : 
    base_url = 'https://financialmodelingprep.com/api/v3/income-statement/RY.TO?limit=5&period=quarter&apikey=89d4891348727c3950b79b9067127c3f'
    if period == 'annual' : 
        base_url = base_url.replace('&period=quarter','')
    
    is_url = base_url.replace('RY.TO', target_Symbol)
    is_url = is_url.replace('=5', '='+str(limit))
    bs_url = is_url.replace('income-statement','balance-sheet-statement')
    cf_url = is_url.replace('income-statement','cash-flow-statement')
    
    if filing_type == 'is' : 
        return is_url
    elif filing_type == 'bs' : 
        return bs_url
    elif filing_type == 'cf' : 
        return cf_url 
    else :
        return "Please input proper filing_type"

# %% [markdown]
# ## Testing

# %%
    # 기업별 URL 생성 
    is_url = url_generator(target_Symbol, 'is', 2, 'annual')
    bs_url = url_generator(target_Symbol, 'bs', 2, 'annual')
    cf_url = url_generator(target_Symbol, 'cf', 2, 'annual')
    
    # extractor 함수를 이용하여 API를 통한 데이터를 판다스 데이터프레임으로 갖고옴. 
    df_is = extractor(is_url)
    df_bs = extractor(bs_url)
    df_cf = extractor(cf_url)
    
    
    #revenue 만 받는 방법
    print(df_is['revenue'][0])
# Out:
# 827205000

# %% [markdown]
# ## Main Code for Collection

# %%
company_df_list = []
for target_Symbol in tqdm(Japan_symbols[0:30]) :  
    
    # 기업별 URL 생성 
    is_url = url_generator(target_Symbol, 'is', 2, 'annual')
    
    # extractor 함수를 이용하여 API를 통한 데이터를 판다스 데이터프레임으로 갖고옴. 
    df_is = extractor(is_url)

    # 오류 회피 
    # 간혹가다 손익 계산서, 대차대조표는 있는데 현금흐름표가 없는등의 문제가 있다. 
    # 모든 경우에 대한 오류 회피 
    # try : 만약 추출해 올 열들에 대한 정보가 존재한다면 불러온다
    # except : 만약 추출 해 올 열들에 대한 정보가 있으면, core_is()
      
        
    #company_df = pd.merge(company_df, df_cf)
    column_names = ['name','name_eng','description_short','description','founded_date','product','homepage','employee_cnt','revenue','ceo_name','email','tel','fax','address1','address2','post_code','facebook','youtube','logo','hash_tag','nation_id','industry_id','is_active','created_at','updated_at']
    df = pd.DataFrame(columns = column_names)
    
    # 숫자 데이터 이외에 필요한 기업 일반정보들을 추가한다. 
    # Financil Modeling Prep의 Company profile API를 이용한다. 
    base_url = 'https://financialmodelingprep.com/api/v3/profile/RY.TO?apikey=89d4891348727c3950b79b9067127c3f'
    target_url = base_url.replace('RY.TO', target_Symbol)
    
    # request로 데이터 갖고오기 
    req = requests.get(target_url)
    data = json.loads(req.text)
    
    # 데이터 명세서에 근거하여 필요한 일반정보 칼럼들만 추출하여 company_df에 추가한다. 
    
    try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
    except :df['name'] = "NA"
    try : df['name_eng'] = data[0]['companyName'] 
    except :df['name_eng'] = "NA"
    try : df['description_short'] = data[0]['description']
    except :df['description_short'] = "NA"
    try : df['description'] =data[0]['description']
    except : df['description'] = "NA"
    try : df['founded_date'] =data[0]['ipoDate']
    except : df['founded_date'] = "NA"
    try : df['product'] =data[0]['industry']
    except : df['product'] = "NA"
    try : df['homepage'] =data[0]['website']
    except : df['homepage'] = "NA"
    try : df['employee_cnt'] =data[0]['fullTimeEmployees']
    except : df['employee_cnt'] = "NA"
    try : 
        df['revenue'] = df_is['revenue'][0]
    except : df['revenue'] = "NA"
    try : 
        df['ceo_name'] = data[0]['ceo']
        if data[0]['ceo'] == "" or data[0]['ceo'] == None or data[0]['ceo'] == "NaN" :
            df['ceo_name'] = "NA"
    except : df['ceo_name'] = "NA"
    try : 
        df['email'] = data[0]['email']
        if data[0]['email'] == "" or data[0]['email'] == None or data[0]['fax'] == "email" :
            df['email'] = "NA"
    except : df['email'] = "NA"
    try : df['tel'] =data[0]['phone']
    except : df['tel'] = "NA"
    try :
        df['fax'] = data[0]['fax']
        if data[0]['fax'] == "" or data[0]['fax'] == None or data[0]['fax'] == "NaN" :
            df['fax'] ="NA"
    except : df['fax'] = "NA"
    try : df['address1'] =data[0]['address']
    except : df['address1'] = "NA"
    try : df['address2'] = data[0]['city'] + ", " + data[0]['state'] + ", " + data[0]['country']
    except : df['address2'] = "NA"
    try : 
        df['post_code'] = data[0]['zip']
        if data[0]['zip'] == "" or data[0]['zip'] == None or data[0]['zip'] == "NaN" :
            df['post_code'] = "NA"
    except : df['post_code'] = "NA"
    try : df['facebook'] = data[0]['website']
    except : df['facebook'] = "NA"
    try : df['youtube'] =data[0]['website']
    except : df['youtube'] = "NA"
    try : df['logo'] =data[0]['image']
    except : df['logo'] = "NA"    
    try : df['hash_tag'] = "#"+ data[0]['companyName'] + ", #" + data[0]['industry'] + ", #" + data[0]['sector']
    except : df['hash_tag'] = "NA"
    try : df['nation_id'] = "17"
    except : df['nation_id'] = "NA"
    try : df['industry_id'] = 1
    except : df['industry_id'] = "NA"
    try : df['is_active'] =data[0]['isActivelyTrading']
    except : df['is_active'] = "NA"
    try : df['created_at'] = '2022-05-23'
    except : df['created_at'] = "NA"
    try : df['updated_at'] = '2022-05-23'
    except : df['updated_at'] = "NA"
    
    company_df_list.append(df)
# Out:
#   0%|                                                                                           | 0/30 [00:00<?, ?it/s]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   3%|██▊                                                                                | 1/30 [00:02<01:07,  2.32s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   7%|█████▌                                                                             | 2/30 [00:04<00:54,  1.96s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  10%|████████▎                                                                          | 3/30 [00:05<00:50,  1.86s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  13%|███████████                                                                        | 4/30 [00:07<00:46,  1.81s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  17%|█████████████▊                                                                     | 5/30 [00:09<00:44,  1.78s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  20%|████████████████▌                                                                  | 6/30 [00:10<00:42,  1.76s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  23%|███████████████████▎                                                               | 7/30 [00:12<00:40,  1.76s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  27%|██████████████████████▏                                                            | 8/30 [00:14<00:38,  1.77s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  30%|████████████████████████▉                                                          | 9/30 [00:16<00:36,  1.75s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  33%|███████████████████████████▎                                                      | 10/30 [00:17<00:35,  1.76s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  37%|██████████████████████████████                                                    | 11/30 [00:19<00:33,  1.76s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  40%|████████████████████████████████▊                                                 | 12/30 [00:21<00:31,  1.77s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  43%|███████████████████████████████████▌                                              | 13/30 [00:23<00:29,  1.75s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  47%|██████████████████████████████████████▎                                           | 14/30 [00:24<00:27,  1.73s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  50%|█████████████████████████████████████████                                         | 15/30 [00:26<00:26,  1.75s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  53%|███████████████████████████████████████████▋                                      | 16/30 [00:28<00:25,  1.79s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  57%|██████████████████████████████████████████████▍                                   | 17/30 [00:30<00:22,  1.76s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  60%|█████████████████████████████████████████████████▏                                | 18/30 [00:31<00:20,  1.74s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  63%|███████████████████████████████████████████████████▉                              | 19/30 [00:33<00:18,  1.72s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  67%|██████████████████████████████████████████████████████▋                           | 20/30 [00:35<00:17,  1.73s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  70%|█████████████████████████████████████████████████████████▍                        | 21/30 [00:37<00:15,  1.74s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  73%|████████████████████████████████████████████████████████████▏                     | 22/30 [00:38<00:13,  1.75s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  77%|██████████████████████████████████████████████████████████████▊                   | 23/30 [00:40<00:12,  1.75s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  80%|█████████████████████████████████████████████████████████████████▌                | 24/30 [00:42<00:10,  1.77s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  83%|████████████████████████████████████████████████████████████████████▎             | 25/30 [00:44<00:08,  1.77s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  87%|███████████████████████████████████████████████████████████████████████           | 26/30 [00:45<00:06,  1.75s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  90%|█████████████████████████████████████████████████████████████████████████▊        | 27/30 [00:47<00:05,  1.73s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  93%|████████████████████████████████████████████████████████████████████████████▌     | 28/30 [00:49<00:03,  1.74s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  97%|███████████████████████████████████████████████████████████████████████████████▎  | 29/30 [00:51<00:01,  1.75s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_12272\2838270580.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:52<00:00,  1.77s/it]

# %% [markdown]
# # Summary and Visualization

# %%
#Sum up
master_df = pd.concat(company_df_list, ignore_index = True)

# %%
#Visualization
master_df
# Out:
#                                               name  \
# 0                               Tekken Corporation
# 1                                  Snow Peak, Inc.
# 2                                 Toda Kogyo Corp.
# 3                            R&D Computer Co.,Ltd.
# 4                               United Arrows Ltd.
# 5             Tokai Tokyo Financial Holdings, Inc.
# 6                   Compucase Enterprise Co., Ltd.
# 7                     YASKAWA Electric Corporation
# 8                                  TYK Corporation
# 9                      Iriso Electronics Co., Ltd.
# 10                              Maruwn Corporation
# 11                              Cub Elecparts Inc.
# 12                        Qualipoly Chemical Corp.
# 13                             Ajinomoto Co., Inc.
# 14                        CAC Holdings Corporation
# 15                Apex Science & Engineering Corp.
# 16  Pan Pacific International Holdings Corporation
# 17                 Tbi Motion Technology Co., Ltd.
# 18                   Eson Precision Ind. Co., Ltd.
# 19                                Shinwa Co., Ltd.
# 20                   Ginko International Co., Ltd.
# 21                   Towa Pharmaceutical Co., Ltd.
# 22                     Meiko Electronics Co., Ltd.
# 23                 Headway Advanced Materials Inc.
# 24                   Japan Post Holdings Co., Ltd.
# 25                         Gourmet Master Co. Ltd.
# 26                                LIFULL Co., Ltd.
# 27                                   AI CROSS Inc.
# 28                       Chun Yu Works & Co., Ltd.
# 29                  Uniform Industrial Corporation
#
#                                           name_eng  \
# 0                               Tekken Corporation
# 1                                  Snow Peak, Inc.
# 2                                 Toda Kogyo Corp.
# 3                            R&D Computer Co.,Ltd.
# 4                               United Arrows Ltd.
# 5             Tokai Tokyo Financial Holdings, Inc.
# 6                   Compucase Enterprise Co., Ltd.
# 7                     YASKAWA Electric Corporation
# 8                                  TYK Corporation
# 9                      Iriso Electronics Co., Ltd.
# 10                              Maruwn Corporation
# 11                              Cub Elecparts Inc.
# 12                        Qualipoly Chemical Corp.
# 13                             Ajinomoto Co., Inc.
# 14                        CAC Holdings Corporation
# 15                Apex Science & Engineering Corp.
# 16  Pan Pacific International Holdings Corporation
# 17                 Tbi Motion Technology Co., Ltd.
# 18                   Eson Precision Ind. Co., Ltd.
# 19                                Shinwa Co., Ltd.
# 20                   Ginko International Co., Ltd.
# 21                   Towa Pharmaceutical Co., Ltd.
# 22                     Meiko Electronics Co., Ltd.
# 23                 Headway Advanced Materials Inc.
# 24                   Japan Post Holdings Co., Ltd.
# 25                         Gourmet Master Co. Ltd.
# 26                                LIFULL Co., Ltd.
# 27                                   AI CROSS Inc.
# 28                       Chun Yu Works & Co., Ltd.
# 29                  Uniform Industrial Corporation
#
#                                     description_short  \
# 0   Tekken Corporation engages in the construction...
# 1   Snow Peak, Inc. develops, manufactures, and se...
# 2   Toda Kogyo Corp. manufactures and sells functi...
# 3   R&D Computer Co.,Ltd. provides system integrat...
# 4   United Arrows Ltd. plans, buys, and retails me...
# 5   Tokai Tokyo Financial Holdings, Inc. operates ...
# 6   Compucase Enterprise Co., Ltd. designs and man...
# 7   YASKAWA Electric Corporation engages in motion...
# 8   TYK Corporation engages in the development, pr...
# 9   Iriso Electronics Co., Ltd. develops, manufact...
# 10  Maruwn Corporation provides logistics solution...
# 11  Cub Elecparts Inc. manufactures and supplies a...
# 12  Qualipoly Chemical Corp. manufactures and supp...
# 13  Ajinomoto Co., Inc. engages in the seasonings ...
# 14  CAC Holdings Corporation, through its subsidia...
# 15  Apex Science & Engineering Corp. operates as a...
# 16  Pan Pacific International Holdings Corporation...
# 17  TBI MOTION Technology Co., Ltd. manufactures a...
# 18  Eson Precision Ind. Co., Ltd. designs, develop...
# 19  Shinwa Co., Ltd. provides construction and log...
# 20  Ginko International Co., Ltd. manufactures and...
# 21  Towa Pharmaceutical Co., Ltd., together with i...
# 22  Meiko Electronics Co., Ltd. engages in the des...
# 23  Headway Advanced Materials Inc. manufactures a...
# 24  Japan Post Holdings Co., Ltd. provides postal,...
# 25  Gourmet Master Co. Ltd., an investment holding...
# 26  LIFULL Co., Ltd. provides real estate informat...
# 27  AI CROSS Inc. engages in the business communic...
# 28  Chun Yu Works & Co., Ltd. manufactures and sel...
# 29  Uniform Industrial Corporation provides variou...
#
#                                           description founded_date  \
# 0   Tekken Corporation engages in the construction...   2001-01-01
# 1   Snow Peak, Inc. develops, manufactures, and se...   2014-12-11
# 2   Toda Kogyo Corp. manufactures and sells functi...   2001-01-01
# 3   R&D Computer Co.,Ltd. provides system integrat...   2015-12-11
# 4   United Arrows Ltd. plans, buys, and retails me...   2002-03-19
# 5   Tokai Tokyo Financial Holdings, Inc. operates ...   2001-01-01
# 6   Compucase Enterprise Co., Ltd. designs and man...   2021-09-08
# 7   YASKAWA Electric Corporation engages in motion...   2001-01-01
# 8   TYK Corporation engages in the development, pr...   2001-01-01
# 9   Iriso Electronics Co., Ltd. develops, manufact...   2000-01-04
# 10  Maruwn Corporation provides logistics solution...   2001-01-01
# 11  Cub Elecparts Inc. manufactures and supplies a...   2007-12-31
# 12  Qualipoly Chemical Corp. manufactures and supp...   2007-12-31
# 13  Ajinomoto Co., Inc. engages in the seasonings ...   2000-01-04
# 14  CAC Holdings Corporation, through its subsidia...   2001-01-04
# 15  Apex Science & Engineering Corp. operates as a...   2000-01-04
# 16  Pan Pacific International Holdings Corporation...   2001-01-01
# 17  TBI MOTION Technology Co., Ltd. manufactures a...   2014-11-19
# 18  Eson Precision Ind. Co., Ltd. designs, develop...   2013-11-25
# 19  Shinwa Co., Ltd. provides construction and log...   2018-03-20
# 20  Ginko International Co., Ltd. manufactures and...   2012-04-27
# 21  Towa Pharmaceutical Co., Ltd., together with i...   2004-04-05
# 22  Meiko Electronics Co., Ltd. engages in the des...   2000-12-08
# 23  Headway Advanced Materials Inc. manufactures a...   2007-12-31
# 24  Japan Post Holdings Co., Ltd. provides postal,...   2015-11-04
# 25  Gourmet Master Co. Ltd., an investment holding...   2021-09-08
# 26  LIFULL Co., Ltd. provides real estate informat...   2006-10-31
# 27  AI CROSS Inc. engages in the business communic...   2019-10-08
# 28  Chun Yu Works & Co., Ltd. manufactures and sel...   2000-01-04
# 29  Uniform Industrial Corporation provides variou...   2000-01-04
#
#                                    product  \
# 0               Engineering & Construction
# 1                                  Leisure
# 2                      Specialty Chemicals
# 3          Information Technology Services
# 4                           Apparel Retail
# 5                         Asset Management
# 6                        Computer Hardware
# 7             Electrical Equipment & Parts
# 8                       Building Materials
# 9                    Electronic Components
# 10                                Trucking
# 11                              Auto Parts
# 12                     Specialty Chemicals
# 13                          Packaged Foods
# 14         Information Technology Services
# 15              Engineering & Construction
# 16                         Discount Stores
# 17                     Tools & Accessories
# 18                   Electronic Components
# 19                       Metal Fabrication
# 20          Medical Instruments & Supplies
# 21  Drug Manufacturers—Specialty & Generic
# 22                   Electronic Components
# 23                               Chemicals
# 24                          Banks—Regional
# 25                             Restaurants
# 26          Internet Content & Information
# 27                    Software—Application
# 28                                   Steel
# 29           Business Equipment & Supplies
#
#                               homepage employee_cnt       revenue ceo_name  \
# 0             https://www.tekken.co.jp         1983  1.820200e+11       NA
# 1           https://www.snowpeak.co.jp          623  2.571354e+10       NA
# 2          https://www.todakogyo.co.jp         1208  2.902400e+10       NA
# 3               https://www.rand.co.jp               8.877449e+09       NA
# 4      https://www.united-arrows.co.jp         4641  1.217120e+11       NA
# 5         https://www.tokaitokyo-fh.jp         2907  6.936100e+10       NA
# 6         https://www.hec-group.com.tw               8.293189e+09       NA
# 7            https://www.yaskawa.co.jp        12925  3.897120e+11       NA
# 8                https://www.tyk.co.jp          930  2.291462e+10       NA
# 9              https://www.iriso.co.jp         3277  3.652000e+10       NA
# 10            https://www.maruwn.co.jp         2283  4.727000e+10       NA
# 11          https://www.cubelec.com.tw               4.080435e+09       NA
# 12           https://www.qualipoly.com               4.830426e+09       NA
# 13         https://www.ajinomoto.co.jp        33461  1.071453e+12       NA
# 14        https://www.cac-holdings.com         4249  4.793500e+10       NA
# 15          https://www.apexgrp.com.tw          204  3.614744e+09       NA
# 16              https://www.ppih.co.jp        16838  1.708635e+12       NA
# 17        https://www.tbimotion.com.tw               3.285319e+09       NA
# 18             https://www.eson.com.cn               1.204244e+10       NA
# 19           https://www.shinwa-jp.com          148  1.388576e+10       NA
# 20  https://www.ginkointernational.com               8.901248e+09       NA
# 21       https://www.towayakuhin.co.jp         3456  1.549000e+11       NA
# 22          https://www.meiko-elec.com        13721  1.192570e+11       NA
# 23          https://www.headway.com.tw               1.476066e+09       NA
# 24            https://www.japanpost.jp       243612  1.172040e+13       NA
# 25              https://www.85cafe.com               1.986113e+10       NA
# 26              https://www.lifull.com         1300  3.585718e+10       NA
# 27           https://www.aicross.co.jp           44  2.422444e+09       NA
# 28           https://www.chunyu.com.tw               1.181024e+10       NA
# 29             https://uicpayworld.com               8.272050e+08       NA
#
#     ... post_code                            facebook  \
# 0   ...  101-8366            https://www.tekken.co.jp
# 1   ...  955-0147          https://www.snowpeak.co.jp
# 2   ...  732-0828         https://www.todakogyo.co.jp
# 3   ...  108-0023              https://www.rand.co.jp
# 4   ...  107-0052     https://www.united-arrows.co.jp
# 5   ...  103-6130        https://www.tokaitokyo-fh.jp
# 6   ...        NA        https://www.hec-group.com.tw
# 7   ...  806-0004           https://www.yaskawa.co.jp
# 8   ...   108-005               https://www.tyk.co.jp
# 9   ...  222-0033             https://www.iriso.co.jp
# 10  ...  103-0016            https://www.maruwn.co.jp
# 11  ...     50648          https://www.cubelec.com.tw
# 12  ...     82841           https://www.qualipoly.com
# 13  ...  104-8315         https://www.ajinomoto.co.jp
# 14  ...  103-0015        https://www.cac-holdings.com
# 15  ...       235          https://www.apexgrp.com.tw
# 16  ...  153-0042              https://www.ppih.co.jp
# 17  ...     23876        https://www.tbimotion.com.tw
# 18  ...  KY1-1205             https://www.eson.com.cn
# 19  ...  503-0311           https://www.shinwa-jp.com
# 20  ...  KY1-1205  https://www.ginkointernational.com
# 21  ...  571-8580       https://www.towayakuhin.co.jp
# 22  ...  252-1104          https://www.meiko-elec.com
# 23  ...       303          https://www.headway.com.tw
# 24  ...  100-8791            https://www.japanpost.jp
# 25  ...       408              https://www.85cafe.com
# 26  ...  102-0083              https://www.lifull.com
# 27  ...  105-0003           https://www.aicross.co.jp
# 28  ...       820           https://www.chunyu.com.tw
# 29  ...       236             https://uicpayworld.com
#
#                                youtube  \
# 0             https://www.tekken.co.jp
# 1           https://www.snowpeak.co.jp
# 2          https://www.todakogyo.co.jp
# 3               https://www.rand.co.jp
# 4      https://www.united-arrows.co.jp
# 5         https://www.tokaitokyo-fh.jp
# 6         https://www.hec-group.com.tw
# 7            https://www.yaskawa.co.jp
# 8                https://www.tyk.co.jp
# 9              https://www.iriso.co.jp
# 10            https://www.maruwn.co.jp
# 11          https://www.cubelec.com.tw
# 12           https://www.qualipoly.com
# 13         https://www.ajinomoto.co.jp
# 14        https://www.cac-holdings.com
# 15          https://www.apexgrp.com.tw
# 16              https://www.ppih.co.jp
# 17        https://www.tbimotion.com.tw
# 18             https://www.eson.com.cn
# 19           https://www.shinwa-jp.com
# 20  https://www.ginkointernational.com
# 21       https://www.towayakuhin.co.jp
# 22          https://www.meiko-elec.com
# 23          https://www.headway.com.tw
# 24            https://www.japanpost.jp
# 25              https://www.85cafe.com
# 26              https://www.lifull.com
# 27           https://www.aicross.co.jp
# 28           https://www.chunyu.com.tw
# 29             https://uicpayworld.com
#
#                                                  logo  \
# 0   https://financialmodelingprep.com/image-stock/...
# 1   https://financialmodelingprep.com/image-stock/...
# 2   https://financialmodelingprep.com/image-stock/...
# 3   https://financialmodelingprep.com/image-stock/...
# 4   https://financialmodelingprep.com/image-stock/...
# 5   https://financialmodelingprep.com/image-stock/...
# 6   https://financialmodelingprep.com/image-stock/...
# 7   https://financialmodelingprep.com/image-stock/...
# 8   https://financialmodelingprep.com/image-stock/...
# 9   https://financialmodelingprep.com/image-stock/...
# 10  https://financialmodelingprep.com/image-stock/...
# 11  https://financialmodelingprep.com/image-stock/...
# 12  https://financialmodelingprep.com/image-stock/...
# 13  https://financialmodelingprep.com/image-stock/...
# 14  https://financialmodelingprep.com/image-stock/...
# 15  https://financialmodelingprep.com/image-stock/...
# 16  https://financialmodelingprep.com/image-stock/...
# 17  https://financialmodelingprep.com/image-stock/...
# 18  https://financialmodelingprep.com/image-stock/...
# 19  https://financialmodelingprep.com/image-stock/...
# 20  https://financialmodelingprep.com/image-stock/...
# 21  https://financialmodelingprep.com/image-stock/...
# 22  https://financialmodelingprep.com/image-stock/...
# 23  https://financialmodelingprep.com/image-stock/...
# 24  https://financialmodelingprep.com/image-stock/...
# 25  https://financialmodelingprep.com/image-stock/...
# 26  https://financialmodelingprep.com/image-stock/...
# 27  https://financialmodelingprep.com/image-stock/...
# 28  https://financialmodelingprep.com/image-stock/...
# 29  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
# 0   #Tekken Corporation, #Engineering & Constructi...        17           1
# 1      #Snow Peak, Inc., #Leisure, #Consumer Cyclical        17           1
# 2   #Toda Kogyo Corp., #Specialty Chemicals, #Basi...        17           1
# 3   #R&D Computer Co.,Ltd., #Information Technolog...        17           1
# 4   #United Arrows Ltd., #Apparel Retail, #Consume...        17           1
# 5   #Tokai Tokyo Financial Holdings, Inc., #Asset ...        17           1
# 6   #Compucase Enterprise Co., Ltd., #Computer Har...        17           1
# 7   #YASKAWA Electric Corporation, #Electrical Equ...        17           1
# 8   #TYK Corporation, #Building Materials, #Basic ...        17           1
# 9   #Iriso Electronics Co., Ltd., #Electronic Comp...        17           1
# 10       #Maruwn Corporation, #Trucking, #Industrials        17           1
# 11  #Cub Elecparts Inc., #Auto Parts, #Consumer Cy...        17           1
# 12  #Qualipoly Chemical Corp., #Specialty Chemical...        17           1
# 13  #Ajinomoto Co., Inc., #Packaged Foods, #Consum...        17           1
# 14  #CAC Holdings Corporation, #Information Techno...        17           1
# 15  #Apex Science & Engineering Corp., #Engineerin...        17           1
# 16  #Pan Pacific International Holdings Corporatio...        17           1
# 17  #Tbi Motion Technology Co., Ltd., #Tools & Acc...        17           1
# 18  #Eson Precision Ind. Co., Ltd., #Electronic Co...        17           1
# 19  #Shinwa Co., Ltd., #Metal Fabrication, #Indust...        17           1
# 20  #Ginko International Co., Ltd., #Medical Instr...        17           1
# 21  #Towa Pharmaceutical Co., Ltd., #Drug Manufact...        17           1
# 22  #Meiko Electronics Co., Ltd., #Electronic Comp...        17           1
# 23  #Headway Advanced Materials Inc., #Chemicals, ...        17           1
# 24  #Japan Post Holdings Co., Ltd., #Banks—Regiona...        17           1
# 25  #Gourmet Master Co. Ltd., #Restaurants, #Consu...        17           1
# 26  #LIFULL Co., Ltd., #Internet Content & Informa...        17           1
# 27  #AI CROSS Inc., #Software—Application, #Techno...        17           1
# 28  #Chun Yu Works & Co., Ltd., #Steel, #Basic Mat...        17           1
# 29  #Uniform Industrial Corporation, #Business Equ...        17           1
#
#    is_active  created_at  updated_at
# 0       True  2022-05-23  2022-05-23
# 1       True  2022-05-23  2022-05-23
# 2       True  2022-05-23  2022-05-23
# 3       True  2022-05-23  2022-05-23
# 4       True  2022-05-23  2022-05-23
# 5       True  2022-05-23  2022-05-23
# 6       True  2022-05-23  2022-05-23
# 7       True  2022-05-23  2022-05-23
# 8       True  2022-05-23  2022-05-23
# 9       True  2022-05-23  2022-05-23
# 10      True  2022-05-23  2022-05-23
# 11      True  2022-05-23  2022-05-23
# 12      True  2022-05-23  2022-05-23
# 13      True  2022-05-23  2022-05-23
# 14      True  2022-05-23  2022-05-23
# 15      True  2022-05-23  2022-05-23
# 16      True  2022-05-23  2022-05-23
# 17      True  2022-05-23  2022-05-23
# 18      True  2022-05-23  2022-05-23
# 19      True  2022-05-23  2022-05-23
# 20     False  2022-05-23  2022-05-23
# 21      True  2022-05-23  2022-05-23
# 22      True  2022-05-23  2022-05-23
# 23      True  2022-05-23  2022-05-23
# 24      True  2022-05-23  2022-05-23
# 25      True  2022-05-23  2022-05-23
# 26      True  2022-05-23  2022-05-23
# 27      True  2022-05-23  2022-05-23
# 28      True  2022-05-23  2022-05-23
# 29      True  2022-05-23  2022-05-23
#
# [30 rows x 25 columns]

# %%
#Visualization2
company_df_list
# Out:
# [                 name            name_eng  \
#  0  Tekken Corporation  Tekken Corporation
#
#                                     description_short  \
#  0  Tekken Corporation engages in the construction...
#
#                                           description founded_date  \
#  0  Tekken Corporation engages in the construction...   2001-01-01
#
#                        product                  homepage employee_cnt  \
#  0  Engineering & Construction  https://www.tekken.co.jp         1983
#
#          revenue ceo_name  ... post_code                  facebook  \
#  0  182020000000       NA  ...  101-8366  https://www.tekken.co.jp
#
#                      youtube  \
#  0  https://www.tekken.co.jp
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Tekken Corporation, #Engineering & Constructi...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                name         name_eng  \
#  0  Snow Peak, Inc.  Snow Peak, Inc.
#
#                                     description_short  \
#  0  Snow Peak, Inc. develops, manufactures, and se...
#
#                                           description founded_date  product  \
#  0  Snow Peak, Inc. develops, manufactures, and se...   2014-12-11  Leisure
#
#                       homepage employee_cnt       revenue ceo_name  ...  \
#  0  https://www.snowpeak.co.jp          623  2.571354e+10       NA  ...
#
#    post_code                    facebook                     youtube  \
#  0  955-0147  https://www.snowpeak.co.jp  https://www.snowpeak.co.jp
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                           hash_tag nation_id industry_id  \
#  0  #Snow Peak, Inc., #Leisure, #Consumer Cyclical        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                 name          name_eng  \
#  0  Toda Kogyo Corp.  Toda Kogyo Corp.
#
#                                     description_short  \
#  0  Toda Kogyo Corp. manufactures and sells functi...
#
#                                           description founded_date  \
#  0  Toda Kogyo Corp. manufactures and sells functi...   2001-01-01
#
#                 product                     homepage employee_cnt      revenue  \
#  0  Specialty Chemicals  https://www.todakogyo.co.jp         1208  29024000000
#
#    ceo_name  ... post_code                     facebook  \
#  0       NA  ...  732-0828  https://www.todakogyo.co.jp
#
#                         youtube  \
#  0  https://www.todakogyo.co.jp
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Toda Kogyo Corp., #Specialty Chemicals, #Basi...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                      name               name_eng  \
#  0  R&D Computer Co.,Ltd.  R&D Computer Co.,Ltd.
#
#                                     description_short  \
#  0  R&D Computer Co.,Ltd. provides system integrat...
#
#                                           description founded_date  \
#  0  R&D Computer Co.,Ltd. provides system integrat...   2015-12-11
#
#                             product                homepage employee_cnt  \
#  0  Information Technology Services  https://www.rand.co.jp
#
#        revenue ceo_name  ... post_code                facebook  \
#  0  8877449000       NA  ...  108-0023  https://www.rand.co.jp
#
#                    youtube                                               logo  \
#  0  https://www.rand.co.jp  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #R&D Computer Co.,Ltd., #Information Technolog...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                   name            name_eng  \
#  0  United Arrows Ltd.  United Arrows Ltd.
#
#                                     description_short  \
#  0  United Arrows Ltd. plans, buys, and retails me...
#
#                                           description founded_date  \
#  0  United Arrows Ltd. plans, buys, and retails me...   2002-03-19
#
#            product                         homepage employee_cnt       revenue  \
#  0  Apparel Retail  https://www.united-arrows.co.jp         4641  121712000000
#
#    ceo_name  ... post_code                         facebook  \
#  0       NA  ...  107-0052  https://www.united-arrows.co.jp
#
#                             youtube  \
#  0  https://www.united-arrows.co.jp
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #United Arrows Ltd., #Apparel Retail, #Consume...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                                     name                              name_eng  \
#  0  Tokai Tokyo Financial Holdings, Inc.  Tokai Tokyo Financial Holdings, Inc.
#
#                                     description_short  \
#  0  Tokai Tokyo Financial Holdings, Inc. operates ...
#
#                                           description founded_date  \
#  0  Tokai Tokyo Financial Holdings, Inc. operates ...   2001-01-01
#
#              product                      homepage employee_cnt      revenue  \
#  0  Asset Management  https://www.tokaitokyo-fh.jp         2907  69361000000
#
#    ceo_name  ... post_code                      facebook  \
#  0       NA  ...  103-6130  https://www.tokaitokyo-fh.jp
#
#                          youtube  \
#  0  https://www.tokaitokyo-fh.jp
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Tokai Tokyo Financial Holdings, Inc., #Asset ...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                               name                        name_eng  \
#  0  Compucase Enterprise Co., Ltd.  Compucase Enterprise Co., Ltd.
#
#                                     description_short  \
#  0  Compucase Enterprise Co., Ltd. designs and man...
#
#                                           description founded_date  \
#  0  Compucase Enterprise Co., Ltd. designs and man...   2021-09-08
#
#               product                      homepage employee_cnt     revenue  \
#  0  Computer Hardware  https://www.hec-group.com.tw               8293189000
#
#    ceo_name  ... post_code                      facebook  \
#  0       NA  ...        NA  https://www.hec-group.com.tw
#
#                          youtube  \
#  0  https://www.hec-group.com.tw
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Compucase Enterprise Co., Ltd., #Computer Har...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                             name                      name_eng  \
#  0  YASKAWA Electric Corporation  YASKAWA Electric Corporation
#
#                                     description_short  \
#  0  YASKAWA Electric Corporation engages in motion...
#
#                                           description founded_date  \
#  0  YASKAWA Electric Corporation engages in motion...   2001-01-01
#
#                          product                   homepage employee_cnt  \
#  0  Electrical Equipment & Parts  https://www.yaskawa.co.jp        12925
#
#          revenue ceo_name  ... post_code                   facebook  \
#  0  389712000000       NA  ...  806-0004  https://www.yaskawa.co.jp
#
#                       youtube  \
#  0  https://www.yaskawa.co.jp
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #YASKAWA Electric Corporation, #Electrical Equ...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                name         name_eng  \
#  0  TYK Corporation  TYK Corporation
#
#                                     description_short  \
#  0  TYK Corporation engages in the development, pr...
#
#                                           description founded_date  \
#  0  TYK Corporation engages in the development, pr...   2001-01-01
#
#                product               homepage employee_cnt      revenue  \
#  0  Building Materials  https://www.tyk.co.jp          930  22914616000
#
#    ceo_name  ... post_code               facebook                youtube  \
#  0       NA  ...   108-005  https://www.tyk.co.jp  https://www.tyk.co.jp
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #TYK Corporation, #Building Materials, #Basic ...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                            name                     name_eng  \
#  0  Iriso Electronics Co., Ltd.  Iriso Electronics Co., Ltd.
#
#                                     description_short  \
#  0  Iriso Electronics Co., Ltd. develops, manufact...
#
#                                           description founded_date  \
#  0  Iriso Electronics Co., Ltd. develops, manufact...   2000-01-04
#
#                   product                 homepage employee_cnt      revenue  \
#  0  Electronic Components  https://www.iriso.co.jp         3277  36520000000
#
#    ceo_name  ... post_code                 facebook                  youtube  \
#  0       NA  ...  222-0033  https://www.iriso.co.jp  https://www.iriso.co.jp
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Iriso Electronics Co., Ltd., #Electronic Comp...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                   name            name_eng  \
#  0  Maruwn Corporation  Maruwn Corporation
#
#                                     description_short  \
#  0  Maruwn Corporation provides logistics solution...
#
#                                           description founded_date   product  \
#  0  Maruwn Corporation provides logistics solution...   2001-01-01  Trucking
#
#                     homepage employee_cnt      revenue ceo_name  ... post_code  \
#  0  https://www.maruwn.co.jp         2283  47270000000       NA  ...  103-0016
#
#                     facebook                   youtube  \
#  0  https://www.maruwn.co.jp  https://www.maruwn.co.jp
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                         hash_tag nation_id industry_id  \
#  0  #Maruwn Corporation, #Trucking, #Industrials        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                   name            name_eng  \
#  0  Cub Elecparts Inc.  Cub Elecparts Inc.
#
#                                     description_short  \
#  0  Cub Elecparts Inc. manufactures and supplies a...
#
#                                           description founded_date     product  \
#  0  Cub Elecparts Inc. manufactures and supplies a...   2007-12-31  Auto Parts
#
#                       homepage employee_cnt     revenue ceo_name  ...  \
#  0  https://www.cubelec.com.tw               4080435000       NA  ...
#
#    post_code                    facebook                     youtube  \
#  0     50648  https://www.cubelec.com.tw  https://www.cubelec.com.tw
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Cub Elecparts Inc., #Auto Parts, #Consumer Cy...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                         name                  name_eng  \
#  0  Qualipoly Chemical Corp.  Qualipoly Chemical Corp.
#
#                                     description_short  \
#  0  Qualipoly Chemical Corp. manufactures and supp...
#
#                                           description founded_date  \
#  0  Qualipoly Chemical Corp. manufactures and supp...   2007-12-31
#
#                 product                   homepage employee_cnt     revenue  \
#  0  Specialty Chemicals  https://www.qualipoly.com               4830426000
#
#    ceo_name  ... post_code                   facebook  \
#  0       NA  ...     82841  https://www.qualipoly.com
#
#                       youtube  \
#  0  https://www.qualipoly.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Qualipoly Chemical Corp., #Specialty Chemical...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                    name             name_eng  \
#  0  Ajinomoto Co., Inc.  Ajinomoto Co., Inc.
#
#                                     description_short  \
#  0  Ajinomoto Co., Inc. engages in the seasonings ...
#
#                                           description founded_date  \
#  0  Ajinomoto Co., Inc. engages in the seasonings ...   2000-01-04
#
#            product                     homepage employee_cnt        revenue  \
#  0  Packaged Foods  https://www.ajinomoto.co.jp        33461  1071453000000
#
#    ceo_name  ... post_code                     facebook  \
#  0       NA  ...  104-8315  https://www.ajinomoto.co.jp
#
#                         youtube  \
#  0  https://www.ajinomoto.co.jp
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Ajinomoto Co., Inc., #Packaged Foods, #Consum...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                         name                  name_eng  \
#  0  CAC Holdings Corporation  CAC Holdings Corporation
#
#                                     description_short  \
#  0  CAC Holdings Corporation, through its subsidia...
#
#                                           description founded_date  \
#  0  CAC Holdings Corporation, through its subsidia...   2001-01-04
#
#                             product                      homepage employee_cnt  \
#  0  Information Technology Services  https://www.cac-holdings.com         4249
#
#         revenue ceo_name  ... post_code                      facebook  \
#  0  47935000000       NA  ...  103-0015  https://www.cac-holdings.com
#
#                          youtube  \
#  0  https://www.cac-holdings.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #CAC Holdings Corporation, #Information Techno...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                                 name                          name_eng  \
#  0  Apex Science & Engineering Corp.  Apex Science & Engineering Corp.
#
#                                     description_short  \
#  0  Apex Science & Engineering Corp. operates as a...
#
#                                           description founded_date  \
#  0  Apex Science & Engineering Corp. operates as a...   2000-01-04
#
#                        product                    homepage employee_cnt  \
#  0  Engineering & Construction  https://www.apexgrp.com.tw          204
#
#        revenue ceo_name  ... post_code                    facebook  \
#  0  3614744000       NA  ...       235  https://www.apexgrp.com.tw
#
#                        youtube  \
#  0  https://www.apexgrp.com.tw
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Apex Science & Engineering Corp., #Engineerin...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                                               name  \
#  0  Pan Pacific International Holdings Corporation
#
#                                           name_eng  \
#  0  Pan Pacific International Holdings Corporation
#
#                                     description_short  \
#  0  Pan Pacific International Holdings Corporation...
#
#                                           description founded_date  \
#  0  Pan Pacific International Holdings Corporation...   2001-01-01
#
#             product                homepage employee_cnt        revenue  \
#  0  Discount Stores  https://www.ppih.co.jp        16838  1708635000000
#
#    ceo_name  ... post_code                facebook                 youtube  \
#  0       NA  ...  153-0042  https://www.ppih.co.jp  https://www.ppih.co.jp
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Pan Pacific International Holdings Corporatio...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                                name                         name_eng  \
#  0  Tbi Motion Technology Co., Ltd.  Tbi Motion Technology Co., Ltd.
#
#                                     description_short  \
#  0  TBI MOTION Technology Co., Ltd. manufactures a...
#
#                                           description founded_date  \
#  0  TBI MOTION Technology Co., Ltd. manufactures a...   2014-11-19
#
#                 product                      homepage employee_cnt     revenue  \
#  0  Tools & Accessories  https://www.tbimotion.com.tw               3285319000
#
#    ceo_name  ... post_code                      facebook  \
#  0       NA  ...     23876  https://www.tbimotion.com.tw
#
#                          youtube  \
#  0  https://www.tbimotion.com.tw
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Tbi Motion Technology Co., Ltd., #Tools & Acc...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                              name                       name_eng  \
#  0  Eson Precision Ind. Co., Ltd.  Eson Precision Ind. Co., Ltd.
#
#                                     description_short  \
#  0  Eson Precision Ind. Co., Ltd. designs, develop...
#
#                                           description founded_date  \
#  0  Eson Precision Ind. Co., Ltd. designs, develop...   2013-11-25
#
#                   product                 homepage employee_cnt      revenue  \
#  0  Electronic Components  https://www.eson.com.cn               12042445000
#
#    ceo_name  ... post_code                 facebook                  youtube  \
#  0       NA  ...  KY1-1205  https://www.eson.com.cn  https://www.eson.com.cn
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Eson Precision Ind. Co., Ltd., #Electronic Co...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                 name          name_eng  \
#  0  Shinwa Co., Ltd.  Shinwa Co., Ltd.
#
#                                     description_short  \
#  0  Shinwa Co., Ltd. provides construction and log...
#
#                                           description founded_date  \
#  0  Shinwa Co., Ltd. provides construction and log...   2018-03-20
#
#               product                   homepage employee_cnt      revenue  \
#  0  Metal Fabrication  https://www.shinwa-jp.com          148  13885758000
#
#    ceo_name  ... post_code                   facebook  \
#  0       NA  ...  503-0311  https://www.shinwa-jp.com
#
#                       youtube  \
#  0  https://www.shinwa-jp.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Shinwa Co., Ltd., #Metal Fabrication, #Indust...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                              name                       name_eng  \
#  0  Ginko International Co., Ltd.  Ginko International Co., Ltd.
#
#                                     description_short  \
#  0  Ginko International Co., Ltd. manufactures and...
#
#                                           description founded_date  \
#  0  Ginko International Co., Ltd. manufactures and...   2012-04-27
#
#                            product                            homepage  \
#  0  Medical Instruments & Supplies  https://www.ginkointernational.com
#
#    employee_cnt     revenue ceo_name  ... post_code  \
#  0               8901248000       NA  ...  KY1-1205
#
#                               facebook                             youtube  \
#  0  https://www.ginkointernational.com  https://www.ginkointernational.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Ginko International Co., Ltd., #Medical Instr...        17           1
#
#    is_active  created_at  updated_at
#  0     False  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                              name                       name_eng  \
#  0  Towa Pharmaceutical Co., Ltd.  Towa Pharmaceutical Co., Ltd.
#
#                                     description_short  \
#  0  Towa Pharmaceutical Co., Ltd., together with i...
#
#                                           description founded_date  \
#  0  Towa Pharmaceutical Co., Ltd., together with i...   2004-04-05
#
#                                    product                       homepage  \
#  0  Drug Manufacturers—Specialty & Generic  https://www.towayakuhin.co.jp
#
#    employee_cnt       revenue ceo_name  ... post_code  \
#  0         3456  154900000000       NA  ...  571-8580
#
#                          facebook                        youtube  \
#  0  https://www.towayakuhin.co.jp  https://www.towayakuhin.co.jp
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Towa Pharmaceutical Co., Ltd., #Drug Manufact...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                            name                     name_eng  \
#  0  Meiko Electronics Co., Ltd.  Meiko Electronics Co., Ltd.
#
#                                     description_short  \
#  0  Meiko Electronics Co., Ltd. engages in the des...
#
#                                           description founded_date  \
#  0  Meiko Electronics Co., Ltd. engages in the des...   2000-12-08
#
#                   product                    homepage employee_cnt  \
#  0  Electronic Components  https://www.meiko-elec.com        13721
#
#          revenue ceo_name  ... post_code                    facebook  \
#  0  119257000000       NA  ...  252-1104  https://www.meiko-elec.com
#
#                        youtube  \
#  0  https://www.meiko-elec.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Meiko Electronics Co., Ltd., #Electronic Comp...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                                name                         name_eng  \
#  0  Headway Advanced Materials Inc.  Headway Advanced Materials Inc.
#
#                                     description_short  \
#  0  Headway Advanced Materials Inc. manufactures a...
#
#                                           description founded_date    product  \
#  0  Headway Advanced Materials Inc. manufactures a...   2007-12-31  Chemicals
#
#                       homepage employee_cnt     revenue ceo_name  ...  \
#  0  https://www.headway.com.tw               1476066000       NA  ...
#
#    post_code                    facebook                     youtube  \
#  0       303  https://www.headway.com.tw  https://www.headway.com.tw
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Headway Advanced Materials Inc., #Chemicals, ...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                              name                       name_eng  \
#  0  Japan Post Holdings Co., Ltd.  Japan Post Holdings Co., Ltd.
#
#                                     description_short  \
#  0  Japan Post Holdings Co., Ltd. provides postal,...
#
#                                           description founded_date  \
#  0  Japan Post Holdings Co., Ltd. provides postal,...   2015-11-04
#
#            product                  homepage employee_cnt         revenue  \
#  0  Banks—Regional  https://www.japanpost.jp       243612  11720401000000
#
#    ceo_name  ... post_code                  facebook                   youtube  \
#  0       NA  ...  100-8791  https://www.japanpost.jp  https://www.japanpost.jp
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Japan Post Holdings Co., Ltd., #Banks—Regiona...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                        name                 name_eng  \
#  0  Gourmet Master Co. Ltd.  Gourmet Master Co. Ltd.
#
#                                     description_short  \
#  0  Gourmet Master Co. Ltd., an investment holding...
#
#                                           description founded_date  \
#  0  Gourmet Master Co. Ltd., an investment holding...   2021-09-08
#
#         product                homepage employee_cnt      revenue ceo_name  \
#  0  Restaurants  https://www.85cafe.com               19861133000       NA
#
#     ... post_code                facebook                 youtube  \
#  0  ...       408  https://www.85cafe.com  https://www.85cafe.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Gourmet Master Co. Ltd., #Restaurants, #Consu...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                 name          name_eng  \
#  0  LIFULL Co., Ltd.  LIFULL Co., Ltd.
#
#                                     description_short  \
#  0  LIFULL Co., Ltd. provides real estate informat...
#
#                                           description founded_date  \
#  0  LIFULL Co., Ltd. provides real estate informat...   2006-10-31
#
#                            product                homepage employee_cnt  \
#  0  Internet Content & Information  https://www.lifull.com         1300
#
#         revenue ceo_name  ... post_code                facebook  \
#  0  35857177000       NA  ...  102-0083  https://www.lifull.com
#
#                    youtube                                               logo  \
#  0  https://www.lifull.com  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #LIFULL Co., Ltd., #Internet Content & Informa...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#              name       name_eng  \
#  0  AI CROSS Inc.  AI CROSS Inc.
#
#                                     description_short  \
#  0  AI CROSS Inc. engages in the business communic...
#
#                                           description founded_date  \
#  0  AI CROSS Inc. engages in the business communic...   2019-10-08
#
#                  product                   homepage employee_cnt     revenue  \
#  0  Software—Application  https://www.aicross.co.jp           44  2422444000
#
#    ceo_name  ... post_code                   facebook  \
#  0       NA  ...  105-0003  https://www.aicross.co.jp
#
#                       youtube  \
#  0  https://www.aicross.co.jp
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #AI CROSS Inc., #Software—Application, #Techno...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                          name                   name_eng  \
#  0  Chun Yu Works & Co., Ltd.  Chun Yu Works & Co., Ltd.
#
#                                     description_short  \
#  0  Chun Yu Works & Co., Ltd. manufactures and sel...
#
#                                           description founded_date product  \
#  0  Chun Yu Works & Co., Ltd. manufactures and sel...   2000-01-04   Steel
#
#                      homepage employee_cnt      revenue ceo_name  ...  \
#  0  https://www.chunyu.com.tw               11810242000       NA  ...
#
#    post_code                   facebook                    youtube  \
#  0       820  https://www.chunyu.com.tw  https://www.chunyu.com.tw
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Chun Yu Works & Co., Ltd., #Steel, #Basic Mat...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                               name                        name_eng  \
#  0  Uniform Industrial Corporation  Uniform Industrial Corporation
#
#                                     description_short  \
#  0  Uniform Industrial Corporation provides variou...
#
#                                           description founded_date  \
#  0  Uniform Industrial Corporation provides variou...   2000-01-04
#
#                           product                 homepage employee_cnt  \
#  0  Business Equipment & Supplies  https://uicpayworld.com
#
#       revenue ceo_name  ... post_code                 facebook  \
#  0  827205000       NA  ...       236  https://uicpayworld.com
#
#                     youtube                                               logo  \
#  0  https://uicpayworld.com  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Uniform Industrial Corporation, #Business Equ...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns]]

# %%
#Convert to CSV
master_df.to_csv(r"C:\Users\DT\Desktop\자료\TestData.csv")

# %% [markdown]
# # Testing and Samples

# %%
#Testing Example 1
is_url = url_generator('CA.PA', 'is', 2, 'annual')
bs_url = url_generator('CA.PA', 'bs', 2, 'annual')
cf_url = url_generator('CA.PA', 'cf', 2, 'annual')

# extractor 함수를 이용하여 API를 통한 데이터를 판다스 데이터프레임으로 갖고옴. 
extractor(is_url)
# Out:
#          date symbol reportedCurrency   cik fillingDate acceptedDate  \
# 0  2020-12-31  CA.PA              EUR  None  2020-12-31   2020-12-31
# 1  2019-12-31  CA.PA              EUR  None  2019-12-31   2019-12-31
#
#   calendarYear period      revenue  costOfRevenue  ...  incomeBeforeTaxRatio  \
# 0         2020     FY  72150000000    56705000000  ...              0.018725
# 1         2019     FY  74142000000    58054000000  ...              0.009738
#
#    incomeTaxExpense   netIncome  netIncomeRatio   eps  epsdiluted  \
# 0         498000000   641000000        0.008884  0.80        0.79
# 1         504000000  1129000000        0.015228  1.43        1.42
#
#    weightedAverageShsOut  weightedAverageShsOutDil  \
# 0              805713713                 807587891
# 1              791473793                 792378702
#
#                                                 link  \
# 0  https://www.infogreffe.com/recherche-entrepris...
# 1  https://www.infogreffe.com/recherche-entrepris...
#
#                                            finalLink
# 0  https://www.infogreffe.com/recherche-entrepris...
# 1  https://www.infogreffe.com/recherche-entrepris...
#
# [2 rows x 38 columns]

# %%
#Testing Example 1
extractor(bs_url)
# Out:
#          date symbol reportedCurrency   cik fillingDate acceptedDate  \
# 0  2020-12-31  CA.PA              EUR  None  2020-12-31   2020-12-31
# 1  2019-12-31  CA.PA              EUR  None  2019-12-31   2019-12-31
#
#   calendarYear period  cashAndCashEquivalents  shortTermInvestments  ...  \
# 0         2020     FY              4439000000             179000000  ...
# 1         2019     FY              4466000000              82000000  ...
#
#    totalStockholdersEquity  totalLiabilitiesAndStockholdersEquity  \
# 0               9795000000                            46086000000
# 1               9940000000                            49066000000
#
#    minorityInterest  totalEquity  totalLiabilitiesAndTotalEquity  \
# 0        1502000000  11297000000                     47588000000
# 1        1736000000  11676000000                     50802000000
#
#    totalInvestments    totalDebt     netDebt  \
# 0        1757000000  12112000000  7673000000
# 1        1809000000  11872000000  7406000000
#
#                                                 link  \
# 0  https://www.infogreffe.com/recherche-entrepris...
# 1  https://www.infogreffe.com/recherche-entrepris...
#
#                                            finalLink
# 0  https://www.infogreffe.com/recherche-entrepris...
# 1  https://www.infogreffe.com/recherche-entrepris...
#
# [2 rows x 54 columns]

# %%
#Testing Example 1
extractor(cf_url)
# Out:
#          date symbol reportedCurrency   cik fillingDate acceptedDate  \
# 0  2020-12-31  CA.PA              EUR  None  2020-12-31   2020-12-31
# 1  2019-12-31  CA.PA              EUR  None  2019-12-31   2019-12-31
#
#   calendarYear period   netIncome  depreciationAndAmortization  ...  \
# 0         2020     FY   641000000                   2292000000  ...
# 1         2019     FY  1129000000                   2328000000  ...
#
#    netCashUsedProvidedByFinancingActivities  effectOfForexChangesOnCash  \
# 0                               -1126000000                  -455000000
# 1                               -1987000000                   -81000000
#
#    netChangeInCash  cashAtEndOfPeriod  cashAtBeginningOfPeriod  \
# 0        -27000000         4439000000               4466000000
# 1        166000000         4466000000               4300000000
#
#    operatingCashFlow  capitalExpenditure  freeCashFlow  \
# 0         3395000000         -1614000000    1781000000
# 1         3247000000         -1725000000    1522000000
#
#                                                 link  \
# 0  https://www.infogreffe.com/recherche-entrepris...
# 1  https://www.infogreffe.com/recherche-entrepris...
#
#                                            finalLink
# 0  https://www.infogreffe.com/recherche-entrepris...
# 1  https://www.infogreffe.com/recherche-entrepris...
#
# [2 rows x 40 columns]

# %%
#Testing Example 1
extractor(is_url)
# Out:
#          date symbol reportedCurrency   cik fillingDate acceptedDate  \
# 0  2020-12-31  CA.PA              EUR  None  2020-12-31   2020-12-31
# 1  2019-12-31  CA.PA              EUR  None  2019-12-31   2019-12-31
#
#   calendarYear period      revenue  costOfRevenue  ...  incomeBeforeTaxRatio  \
# 0         2020     FY  72150000000    56705000000  ...              0.018725
# 1         2019     FY  74142000000    58054000000  ...              0.009738
#
#    incomeTaxExpense   netIncome  netIncomeRatio   eps  epsdiluted  \
# 0         498000000   641000000        0.008884  0.80        0.79
# 1         504000000  1129000000        0.015228  1.43        1.42
#
#    weightedAverageShsOut  weightedAverageShsOutDil  \
# 0              805713713                 807587891
# 1              791473793                 792378702
#
#                                                 link  \
# 0  https://www.infogreffe.com/recherche-entrepris...
# 1  https://www.infogreffe.com/recherche-entrepris...
#
#                                            finalLink
# 0  https://www.infogreffe.com/recherche-entrepris...
# 1  https://www.infogreffe.com/recherche-entrepris...
#
# [2 rows x 38 columns]
