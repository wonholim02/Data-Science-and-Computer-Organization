# %% [markdown]
# # Using Financial Modeling Prep to Collect General & Financial Information

# %% [markdown]
# ## Setup Local Environment

# %%
import time
from platform import python_version
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
import csv 
try:
    from urllib.request import urlopen
except ImportError:
    from urllib2 import urlopen
import certifi
from tqdm import tqdm

# %%
print(python_version())
print(pd.__version__)
# Out:
# 3.10.4
# 1.4.2

# %%
#check the local address
cover = open('TestData.csv','w', newline='', encoding='UTF-8')
writing = csv.writer(cover)
writing.writerow(['name','name_eng','description_short','description','founded_date','product','homepage','employee_cnt','revenue','ceo_name','email','tel','fax','address1','address2','post_code','facebook','youtube','logo','hash_tag','nation_id','industry_id','is_active','created_at','updated_at'])
# Out:
# 232

# %% [markdown]
# ## Setup API Environment

# %%
def get_jsonparsed_data(url):
    """
    Receive the content of ``url``, parse it as JSON and return the object.

    Parameters
    ----------
    url : str

    Returns
    -------
    dict
    """
    response = urlopen(url, cafile=certifi.where())
    data = response.read().decode("utf-8")
    return json.loads(data)

# %%
url = ("https://financialmodelingprep.com/api/v3/financial-statement-symbol-lists?apikey=33d67d9c5e5ed94ff134e9bf93f9d818")
Symbols = get_jsonparsed_data(url)
# Out:
# C:\Users\DT\AppData\Local\Temp\ipykernel_10120\3606349989.py:13: DeprecationWarning: cafile, capath and cadefault are deprecated, use a custom context instead.
#   response = urlopen(url, cafile=certifi.where())

# %% [markdown]
# ## Check Availability

# %%
Symbols
# Out:
# ['ETH',
#  'GOGN',
#  '000540.SZ',
#  '603931.SS',
#  'JMG.L',
#  '067900.KS',
#  'BSP.AX',
#  'ERM.L',
#  'LVCLY',
#  'SBFMW',
#  'CPAH',
#  'JGLE.JK',
#  'SMWN.DE',
#  '0729.HK',
#  'CYBN',
#  'PLUGD',
#  '0440.HK',
#  'FVTID',
#  '1930.HK',
#  'CDTI',
#  'PRCX',
#  '688133.SS',
#  'SCRM',
#  'SHALPAINTS.NS',
#  'ATZ.TO',
#  '8187.HK',
#  '1210.HK',
#  'AMST',
#  '603023.SS',
#  'VRSN',
#  'DFRG',
#  'EMHTF',
#  'ALO',
#  'MEC',
#  'CTAQU',
#  'WFT.TO',
#  'NFG',
#  '300050.SZ',
#  'BT-A.L',
#  '8395.HK',
#  'KLTR',
#  '1815.T',
#  'VSVS.L',
#  '0771.HK',
#  'LEAT',
#  'PRO',
#  'GZF.DE',
#  'BDXA',
#  'HRB',
#  '002042.SZ',
#  'AURCU',
#  'AHNR',
#  'TCT.ST',
#  '7816.T',
#  'GUL.AX',
#  'UIHCU',
#  'SRTS',
#  'AQ',
#  'ALAQU.PA',
#  'THYCY',
#  'GRX',
#  'AUC.AX',
#  'EC.PA',
#  'BCI.TO',
#  'MARUY',
#  'TPVG',
#  'MLIA.JK',
#  'ORIA',
#  '688767.SS',
#  'BAYERCROP.NS',
#  '002123.SZ',
#  'WSR',
#  'BWCXP',
#  'XAM.AX',
#  '601877.SS',
#  'SRBANK.OL',
#  'FFHL',
#  'PRU.TO',
#  'OBTC',
#  'CLN.SW',
#  'SLT.DE',
#  'VLD',
#  'EMR.AX',
#  'CAP.PA',
#  'QRMLF',
#  'ZEV-WT',
#  'LSYN',
#  'VWAPY',
#  'RVLV',
#  '4100.T',
#  '3924.T',
#  '7606.T',
#  'AXAC-RI',
#  'GE.SW',
#  'MIGI',
#  'EQT.AX',
#  'ARIES.NS',
#  'DHCNL',
#  'BLUECHIP.NS',
#  '8616.T',
#  'VII',
#  '000972.SZ',
#  'BONAS.ST',
#  '600486.SS',
#  'ADDERA.ST',
#  'SYX',
#  'TRVN',
#  'DBL.NS',
#  '1201.SR',
#  'FRONW',
#  'WINT',
#  'CHI',
#  '3032.TW',
#  'ATC.AX',
#  'CLBR',
#  '6506.T',
#  'CGEM',
#  'NM',
#  'SPG',
#  'AI.TO',
#  '603444.SS',
#  'KYN',
#  '2220.SR',
#  '603363.SS',
#  'MANAPPURAM.NS',
#  '5363.T',
#  'LTHM.L',
#  'ASPO.HE',
#  'TCRI',
#  'LGACW',
#  '0067.HK',
#  'CNV.PA',
#  'CAZ.AX',
#  'GRPAQ',
#  '6908.T',
#  'NTRSP',
#  'STRC',
#  'ISSDY',
#  'BEI.DE',
#  'ACT.L',
#  'GRCY',
#  'AEF',
#  'FULO',
#  '9067.T',
#  'TZPS',
#  '300073.SZ',
#  'GBRGR',
#  '1775.HK',
#  'SWN.DE',
#  'CII',
#  'KND',
#  'IVDN',
#  'PFX',
#  'CBKCQ',
#  '2155.HK',
#  'SIMP.JK',
#  '603896.SS',
#  'VPRB',
#  'IDZ.AX',
#  'MRM',
#  '2231.TW',
#  'WORK',
#  '6196.HK',
#  'LSI.WA',
#  'BOSCHLTD.NS',
#  'HTWS.L',
#  '4722.TW',
#  'KSL.NS',
#  'ACBA',
#  '603319.SS',
#  '2802.T',
#  'GET&D.NS',
#  'QVE.AX',
#  '4725.T',
#  'SLAC-WT',
#  'KMEZ.ME',
#  '002674.SZ',
#  'FERGY',
#  '3052.TW',
#  'HKHHY',
#  'PSA-PN',
#  '8135.HK',
#  'EVEPQ',
#  'A7A.DE',
#  'IGM.TO',
#  'KIRIINDUS.NS',
#  'DONKEY.CO',
#  'MCM.AX',
#  'NESTLEIND.NS',
#  'HON.L',
#  'MXL',
#  '051910.KS',
#  'VLX.L',
#  '0184.HK',
#  '002208.SZ',
#  'NS-PA',
#  '6633.KL',
#  '7100.KL',
#  'RMYHY',
#  'CRWS',
#  'SHIVATEX.NS',
#  '172580.KS',
#  'OPG.L',
#  'DRMAW',
#  'FGNV',
#  'ZMI.AX',
#  'PERI',
#  'RBG.L',
#  'ENDUR.OL',
#  'KINGFA.NS',
#  'VTNA',
#  'KAYS',
#  'SREINFRA.NS',
#  'FRGE',
#  '7532.T',
#  'BML.WA',
#  '4540.TW',
#  'HP3A.DE',
#  'MAGLE.ST',
#  'INAF.JK',
#  'CHWY',
#  'PACE-UN',
#  'CGI.L',
#  '1227.HK',
#  'CTU',
#  '5243.TW',
#  'GKOS',
#  'DYAN.JK',
#  'HMST',
#  'MAXD',
#  'ASB-PD',
#  '601868.SS',
#  'POAHY',
#  '688687.SS',
#  '3447.T',
#  'EJPRY',
#  '4336.HK',
#  'BAC-PN',
#  '0277.HK',
#  'RVIV',
#  '8406.TWO',
#  'FDX.DE',
#  'ASB-PC',
#  'MDEX',
#  'AGI',
#  '4553.T',
#  '6787.T',
#  '7201.SR',
#  'UNIT',
#  'KYK.AX',
#  '0581.HK',
#  '1776.TW',
#  'APLAPOLLO.NS',
#  'AIB',
#  'CVEO',
#  'MUTHOOTFIN.NS',
#  'TTB.AX',
#  '002022.SZ',
#  'FTSV',
#  'TIRT.JK',
#  'PGRE',
#  'VMX.AX',
#  'TYM.L',
#  'MYC',
#  '6178.T',
#  '3MINDIA.NS',
#  'FIX',
#  '000803.SZ',
#  'BZFDW',
#  'ELEC',
#  '4280.SR',
#  'PCF.WA',
#  'MGG.AX',
#  'CTP2.DE',
#  '2723.TW',
#  'FCRM.L',
#  'DLTA.PA',
#  '207940.KS',
#  'BMPG.L',
#  'GWH-WT',
#  '2120.T',
#  '600278.SS',
#  '001620.KS',
#  '688269.SS',
#  'HEAD.ST',
#  'GHY',
#  'MYL',
#  'SPR.L',
#  'SDIP-PREF.ST',
#  'AJX.TO',
#  'EXPCU',
#  'LZRFY',
#  'GMCR',
#  'ZEEL.NS',
#  '000011.SZ',
#  'NMM',
#  'DRVN',
#  'EVFM',
#  '300223.SZ',
#  '4476.T',
#  'BSN.DE',
#  'PIAI-UN',
#  'NDP',
#  'GFN.AX',
#  'EIX',
#  'AWX',
#  'ORGN',
#  'MLHR',
#  'ABEOW',
#  'TAKE.NS',
#  'INR.DE',
#  'IONI',
#  '0889.HK',
#  'IIIV',
#  '000721.SZ',
#  'ENZ',
#  'CU.TO',
#  'REACH.OL',
#  '2012.TW',
#  'JELD',
#  'EDC.AX',
#  'HTAQ-UN',
#  'RAMCOCEM.NS',
#  '2482.TW',
#  'SKIN.SW',
#  'CAMS.NS',
#  'GHH.L',
#  'EXF.TO',
#  '4011.SR',
#  'CEA',
#  'MLECO.PA',
#  'TREAY',
#  'ARIA',
#  'IMU.DE',
#  '000809.SZ',
#  'LUNG',
#  'BKY.AX',
#  'ANGO',
#  '7480.T',
#  '605116.SS',
#  'INGERRAND.NS',
#  'CLRMW',
#  'HNST',
#  'FNOX.ST',
#  'EMKR',
#  'ODY.AX',
#  '4746.T',
#  'ALPC',
#  'NBST',
#  'FSI.AX',
#  'FMTX',
#  '002837.SZ',
#  '600285.SS',
#  'VOLV-B.ST',
#  'CPTK',
#  'SHH.L',
#  'LFAC',
#  'AGRPY',
#  'ACR-PD',
#  'FEET.L',
#  'DEH-WT',
#  'CLA-B.ST',
#  'TSTL.L',
#  'BVA.L',
#  'ECII.JK',
#  '5099.KL',
#  'NTIC',
#  'BELFB',
#  'ALL.WA',
#  '0918.HK',
#  '023000.KS',
#  '000561.SZ',
#  'TJX',
#  'CLNY-PH',
#  'ORISSAMINE.NS',
#  'TWNK',
#  'TETC',
#  '7943.T',
#  'DTG.L',
#  'VTH.AX',
#  'YAKG.ME',
#  'WATT',
#  'OMINFRAL.NS',
#  '2225.HK',
#  'ALB.MC',
#  'RMX.AX',
#  'IGAS.L',
#  'PZS.DE',
#  'IBSU.L',
#  'PCN',
#  '600054.SS',
#  'ALTM',
#  'EXPE',
#  'YALA',
#  'CAA.AX',
#  'WE',
#  'ALOG',
#  'KCGI-WT',
#  'ATER',
#  'ASM.AX',
#  'DVL.NS',
#  'HXG.AX',
#  '3464.T',
#  '688793.SS',
#  'SWBI',
#  'IFIN-UN',
#  'ADALU',
#  'JOUL.L',
#  'FWONK',
#  'GRL.L',
#  '0434.HK',
#  'GTYHU',
#  '600260.SS',
#  '600731.SS',
#  'QTM.AX',
#  'MODN',
#  'ADVI.PA',
#  'HAVELLS.NS',
#  '4390.T',
#  'RVLP',
#  'BFUTILITIE.NS',
#  '601279.SS',
#  '0326.HK',
#  'TMPMW',
#  'TLKM.JK',
#  'HELIO.ST',
#  'ILU.DE',
#  'INDSWFTLTD.NS',
#  'PFND',
#  'AIB.AX',
#  'ALNN6.PA',
#  'IMAHF',
#  'GECCN',
#  '002977.SZ',
#  'EL',
#  '003075.KS',
#  'SHA.DE',
#  '8306.T',
#  '7277.T',
#  '600708.SS',
#  'UDG.L',
#  'KMT',
#  'EXPN.L',
#  'GRPN',
#  '5347.TWO',
#  'TIK',
#  '002170.SZ',
#  'PGR',
#  'PINE',
#  'ROC',
#  'IGNYU',
#  'UEEC',
#  'UVSP',
#  '2936.TW',
#  'AINC',
#  'MCT.L',
#  'PGLI.JK',
#  '600501.SS',
#  'EGL',
#  '1445.TW',
#  'NUM.L',
#  'RDW.L',
#  'VR1.AX',
#  'VISAKAIND.NS',
#  '002745.SZ',
#  'DBREALTY.NS',
#  'GSAQW',
#  'TDHOY',
#  'UCBJY',
#  '688561.SS',
#  'MGCI.L',
#  '000838.SZ',
#  'ORIENTELEC.NS',
#  'BROOKS.NS',
#  '9988.HK',
#  '1129.HK',
#  '1833.T',
#  'BORORENEW.NS',
#  '0295.HK',
#  '600273.SS',
#  'PMBC',
#  'JHY',
#  'BBZA.DE',
#  'BWF.AX',
#  '605289.SS',
#  'JFKKW',
#  'PBHC',
#  '002851.SZ',
#  'SECO',
#  'CSGS',
#  '9999.HK',
#  'ODA.AX',
#  '2098.HK',
#  'VUZ',
#  '003000.KS',
#  'FXCOW',
#  'SQZ',
#  'SKHSY',
#  '3004.SR',
#  'ARGO-PA',
#  '002803.SZ',
#  'RFX.AX',
#  'WHLM',
#  'JAGX',
#  '688707.SS',
#  '1722.TW',
#  'ZINGW',
#  'TEF',
#  'NORBTEAEXP.NS',
#  'TGP-PB',
#  '8137.HK',
#  'IGNYW',
#  '2889.TW',
#  'ELO.AX',
#  '688108.SS',
#  'HFUS',
#  'HHV.L',
#  '6358.T',
#  'AEVA-WT',
#  'GSCLCEMENT.NS',
#  'ALTIA.HE',
#  '3053.T',
#  'WKSP',
#  'SGKN.SW',
#  'FDML',
#  'PRPB-WT',
#  'CREATIVEYE.NS',
#  '002776.SZ',
#  'MORF',
#  'AESANDES.SN',
#  'DVD',
#  'CA.PA',
#  '1593.HK',
#  '2888.TW',
#  'OPN.PA',
#  'ARMP',
#  'AZIHY',
#  '0232.HK',
#  'IDEX.OL',
#  'ASTEC.NS',
#  '8310.HK',
#  '000820.SZ',
#  '2820.T',
#  '002984.SZ',
#  '002485.SZ',
#  'KMPR',
#  'JNP',
#  '1062.HK',
#  '002405.SZ',
#  '4137.TW',
#  'HYQ.DE',
#  'AFG.OL',
#  'HEINY',
#  'LYTWW',
#  'CHMT',
#  'GLIZ.L',
#  'APEN',
#  'CTCM',
#  'ETY.DE',
#  '002489.SZ',
#  'RIB.DE',
#  'BVS',
#  '011170.KS',
#  'FSEN',
#  'RSWM.NS',
#  '3419.TW',
#  '2343.HK',
#  'ETCK',
#  'LFTPP',
#  '1305.HK',
#  '603535.SS',
#  'PGND',
#  '6932.T',
#  '688333.SS',
#  'AURIONPRO.NS',
#  'FWRG',
#  'PRG',
#  'DMYS-UN',
#  '0659.HK',
#  'ALKT',
#  'VER',
#  'MON',
#  'NORBIT.OL',
#  'PCG.AX',
#  '1210.SR',
#  '1413.TW',
#  'LUMN',
#  '300636.SZ',
#  '4681.T',
#  'THCPU',
#  '600939.SS',
#  'SLB.PA',
#  'PUNJLLOYD.NS',
#  '000050.SZ',
#  'GHM',
#  'ECC',
#  'AUTO.V',
#  'SREDY',
#  'HLIO',
#  'PRLB',
#  'CEADW',
#  'GTCH',
#  '4674.T',
#  '8112.HK',
#  'WSI.AX',
#  'APCA',
#  'NSSC',
#  'PXEN.L',
#  'MFT.MI',
#  '300720.KS',
#  'VMAC',
#  '688308.SS',
#  '0769.HK',
#  'HLFFF',
#  'GOODP',
#  '4155.TW',
#  'RLS.ST',
#  '600123.SS',
#  'BAD.TO',
#  'MORE.L',
#  'DAMODARIND.NS',
#  'HEPA',
#  'CTZ.V',
#  '0496.HK',
#  'MCMJW',
#  'NEIK',
#  'VLVLY',
#  'ENGI.PA',
#  'HBSL.NS',
#  '002175.SZ',
#  '1455.TW',
#  'LEA',
#  'AP-WT',
#  'SLC.AX',
#  '688317.SS',
#  '002326.SZ',
#  'PRGO',
#  '603357.SS',
#  'DHCAU',
#  'GLOP',
#  'STRO',
#  '3421.T',
#  '8166.T',
#  '688006.SS',
#  'IDXX',
#  'DPA.AS',
#  'QTRX',
#  'USL',
#  'BROS',
#  'GVC.L',
#  '3316.HK',
#  'NAKD',
#  'CVM',
#  'VIV.PA',
#  'JBGS',
#  'NEW.AX',
#  'PFSI',
#  'MTAL-WT',
#  'CAY.AX',
#  '603722.SS',
#  'UCBIO',
#  '6328.T',
#  'NSI.L',
#  'ABST.TO',
#  'TGA',
#  'MKP.TO',
#  'OSE.PA',
#  '5521.TW',
#  'TCBS',
#  'B4B.SW',
#  'SCIN.L',
#  'PSH.L',
#  'ZSL',
#  'GMBLZ',
#  'PPP.L',
#  'FIACW',
#  '4496.T',
#  '002859.SZ',
#  'HONY.L',
#  '3031.TW',
#  '302440.KS',
#  '603926.SS',
#  'LMG.AX',
#  'MITT-PC',
#  'FJHLD',
#  '950130.KS',
#  '5464.T',
#  '2334.T',
#  '0305.HK',
#  'DRH-PA',
#  '001430.KS',
#  '4064.T',
#  '4762.T',
#  'CIXX',
#  'TIETO.HE',
#  'WELX',
#  'SOLV.BR',
#  'TMRR',
#  'TD.MI',
#  'RELIGARE.NS',
#  'MRRTY',
#  '153360.KS',
#  'MCF',
#  'AKUS',
#  'KO',
#  '6324.T',
#  'IFF.PA',
#  'CMS',
#  '300359.SZ',
#  'WBMD',
#  'GDL',
#  'HNIB.DE',
#  'MIXT',
#  'AZ2.DE',
#  'ASG.AX',
#  'IFNY',
#  'PEB-PD',
#  'QB7.DE',
#  '8361.T',
#  '5352.T',
#  'RGEN',
#  'GPORQ',
#  'MAU.AX',
#  'OMK.SI',
#  '5533.TW',
#  'MC.SW',
#  '0632.HK',
#  '8830.T',
#  'CTICD',
#  '1655.HK',
#  'DOLE',
#  'MAZDA.NS',
#  '002438.SZ',
#  '3275.T',
#  '7315.T',
#  '3923.T',
#  'TMRVL.NS',
#  'TST',
#  'NBB',
#  '002249.SZ',
#  'SOG.PA',
#  'CSSEP',
#  '600644.SS',
#  'CRTN',
#  '600426.SS',
#  '084695.KS',
#  '5484.TW',
#  '2210.SR',
#  'NEX',
#  'VNO',
#  'AC',
#  '2294.T',
#  '688309.SS',
#  'ITAQW',
#  '600551.SS',
#  '1907.HK',
#  '2266.T',
#  '001210.KS',
#  'VCISY',
#  'LB.TO',
#  'SCHP.SW',
#  '192080.KS',
#  '2636.TW',
#  'OXF.L',
#  'CMPO',
#  'MDLZ',
#  'GRBK',
#  '6473.T',
#  '002870.SZ',
#  'MRACU',
#  '9059.KL',
#  'DDD',
#  'DNMR',
#  '5226.KL',
#  'SUPRIYA.NS',
#  'ZEELEARN.NS',
#  'LGEN.L',
#  '600235.SS',
#  'XESP',
#  'LNKD',
#  'LOAK-WT',
#  'D13.AX',
#  '6616.T',
#  'MEND.CN',
#  'GSAQ',
#  '016360.KS',
#  '1260.HK',
#  'CLIG.L',
#  'WALDU',
#  'FEXD',
#  'FMAC-UN',
#  '03473K.KS',
#  'CAPMAN.HE',
#  'VTEX',
#  'DQ5.IR',
#  '6196.T',
#  'DCOM',
#  '601126.SS',
#  'ENI.DE',
#  '688663.SS',
#  'GGE.AX',
#  'OTEL',
#  'DRAY',
#  'WFC.SW',
#  '2867.TW',
#  '6176.TW',
#  '4440.T',
#  'APXI',
#  'ALKEM.PA',
#  '002349.SZ',
#  '003560.KS',
#  '688668.SS',
#  '004140.KS',
#  'FLEXM.ST',
#  'FRU.TO',
#  '603786.SS',
#  'EQE.AX',
#  '4536.TW',
#  'DBRG-PH',
#  '3853.T',
#  'OTGLY',
#  'RAM.LS',
#  '002439.SZ',
#  'ARTNB',
#  '4519.T',
#  '002789.SZ',
#  'GAZ.DE',
#  'MLFMV.LS',
#  'YEXT',
#  '3446.T',
#  '002386.SZ',
#  'NDVN',
#  'WHLR',
#  'TLIS',
#  'MPLS.L',
#  'CDFF.L',
#  'WELL.TO',
#  '0336.HK',
#  'AUDC',
#  'ANIOY',
#  'DQ7A.IR',
#  'PSA-PL',
#  '059090.KS',
#  'SST',
#  'PHOR.ME',
#  'BLUWU',
#  'MOSY',
#  'WPF-WT',
#  'RMAX',
#  '9045.T',
#  'ASHOKLEY.NS',
#  'TOT.TO',
#  'BG',
#  'VINE',
#  'LOGI-B.ST',
#  'ASGLY',
#  '3050.SR',
#  'RGP',
#  'ECHO',
#  'UNITECH.NS',
#  '688055.SS',
#  'NAVA.OL',
#  'N7G.DE',
#  'PWP',
#  'IQNT',
#  'SECARE.ST',
#  'RILY',
#  'WFTLF',
#  'PWOD',
#  'OUST',
#  'BIOS.ST',
#  'JINDALPOLY.NS',
#  'LENB',
#  '4030.SR',
#  'GPRO',
#  'EXO.MI',
#  'OTLK',
#  'KONI.JK',
#  'ALYA',
#  'BTQ.DE',
#  '600186.SS',
#  '0408.HK',
#  'LUMAXTECH.NS',
#  '9J4.F',
#  'GNRC',
#  'CNTWW',
#  'PSTVZ',
#  '002492.SZ',
#  'GROW',
#  'PPH.L',
#  '2169.T',
#  'OBE.TO',
#  'GSAT',
#  'BFC.AX',
#  'GFOR',
#  'GUID',
#  'JZCP.L',
#  '6387.T',
#  'VRNL.PA',
#  'SIVBP',
#  'TIBRU',
#  'NGACU',
#  '0116.HK',
#  'ATHM',
#  'UNVR',
#  'SWGAY',
#  'YCQH',
#  '1875.HK',
#  'SCL.TO',
#  'RUSI.ME',
#  '9992.HK',
#  'LPPS.JK',
#  'PREMIER.NS',
#  'AMOT',
#  '007110.KS',
#  'GUI.PA',
#  'AF.PA',
#  'FYI.AX',
#  'CLBR-UN',
#  'GLBLW',
#  '0011.HK',
#  'ETI-P',
#  'RWT',
#  'TNGNQ',
#  '8104.T',
#  'LBTYK',
#  'ACF.AX',
#  '002172.SZ',
#  '8351.HK',
#  '8061.T',
#  'ASHOKA.NS',
#  'FENC',
#  '002404.SZ',
#  '4488.T',
#  'TRLC',
#  '900140.KS',
#  '8219.HK',
#  'CPINV.BR',
#  '3296.TW',
#  'OTB.L',
#  '600676.SS',
#  'ARRW',
#  'BFIIW',
#  'ARGX.BR',
#  'STYLAMIND.NS',
#  'BTPS.JK',
#  'EXP',
#  'NOAV',
#  'EEP',
#  '603360.SS',
#  'ARTW',
#  'SUNS',
#  'AUUD',
#  'GLJ.DE',
#  'CASN.SW',
#  'PTICW',
#  'KWR.AX',
#  'KIRLOSENG.NS',
#  'HITECH.NS',
#  '600176.SS',
#  'CAS',
#  'GAMCU',
#  'NYMTO',
#  'ESI.TO',
#  'PHIL',
#  '4491.T',
#  'INFOMEDIA.NS',
#  'BHVN',
#  'DORM',
#  'SUNDARMFIN.NS',
#  'ESTER.NS',
#  '085620.KS',
#  'EFOI',
#  '002369.SZ',
#  'AIZN',
#  'BSP.DE',
#  'KRG',
#  '0833.HK',
#  'FBPRO',
#  'COY.AX',
#  'CCOI',
#  'TORO.L',
#  '3308.TW',
#  '6165.TW',
#  '9926.HK',
#  'MDXL',
#  '5192.T',
#  '7378.T',
#  'BXLT',
#  'MCRAA',
#  '002880.SZ',
#  '000885.SZ',
#  'ACKB.BR',
#  '6833.HK',
#  'CIT',
#  'GNTA',
#  '002561.SZ',
#  'VEDL',
#  '2208.TW',
#  '0558.HK',
#  ...]

# %%
US_symbols = []          # 
Canada_symbols = []      #TO
France_symbols = []      #PA ? 
Germany_symbols = []     #DE
India_symbols = []       #NS
London_symbols = []      #L
Hongkong_symbols = []    #HK
Austrailia_symbols = []  #AX
Swiss_symbols = []       #SW
Korea_symbols = []       #KR
Netherlands_symbols = []

for Symbol in Symbols : 
    if ".TO" in Symbol : 
        Canada_symbols.append(Symbol) 
    elif ".PA" in Symbol : 
        France_symbols.append(Symbol) 
    elif ".DE" in Symbol : 
        Germany_symbols.append(Symbol) 
    elif ".NS" in Symbol : 
        India_symbols.append(Symbol) 
    elif ".L" in Symbol : 
        London_symbols.append(Symbol) 
    elif ".HK" in Symbol : 
        Hongkong_symbols.append(Symbol) 
    elif ".AX" in Symbol : 
        Austrailia_symbols.append(Symbol) 
    elif ".SW" in Symbol : 
        Swiss_symbols.append(Symbol) 
    elif ".KS" in Symbol :
        Korea_symbols.append(Symbol)
    elif "." not in Symbol :
        US_symbols.append(Symbol) 
    elif ".EU" in Symbol : 
        Netherlands_symbols.append(Symbol)

# %%
# 국가별 재무정보 추출 기업 수 
print(f"US에서 뽑아낼 수 있는 상장기업 수 : {len(US_symbols)}")
print(f"Canada에서 뽑아낼 수 있는 상장기업 수 : {len(Canada_symbols)}")
print(f"France에서 뽑아낼 수 있는 상장기업 수 : {len(France_symbols)}")
print(f"Germany에서 뽑아낼 수 있는 상장기업 수 : {len(Germany_symbols)}")
print(f"India에서 뽑아낼 수 있는 상장기업 수 : {len(India_symbols)}")
print(f"London에서 뽑아낼 수 있는 상장기업 수 : {len(London_symbols)}")
print(f"Hongkong에서 뽑아낼 수 있는 상장기업 수 : {len(Hongkong_symbols)}")
print(f"Australia에서 뽑아낼 수 있는 상장기업 수 : {len(Austrailia_symbols)}")
print(f"Swiss에서 뽑아낼 수 있는 상장기업 수 : {len(Swiss_symbols)}")
print(f"Korea에서 뽑아낼 수 있는 상장기업 수 : {len(Korea_symbols)}")
# Out:
# US에서 뽑아낼 수 있는 상장기업 수 : 14959
# Canada에서 뽑아낼 수 있는 상장기업 수 : 845
# France에서 뽑아낼 수 있는 상장기업 수 : 711
# Germany에서 뽑아낼 수 있는 상장기업 수 : 957
# India에서 뽑아낼 수 있는 상장기업 수 : 1836
# London에서 뽑아낼 수 있는 상장기업 수 : 2068
# Hongkong에서 뽑아낼 수 있는 상장기업 수 : 2579
# Australia에서 뽑아낼 수 있는 상장기업 수 : 1899
# Swiss에서 뽑아낼 수 있는 상장기업 수 : 407
# Korea에서 뽑아낼 수 있는 상장기업 수 : 990

# %% [markdown]
# ## Function Setup

# %%
def extractor(url) : 
    try:
        from pandas import json_normalize
    except ImportError:
        from pandas.io.json import json_normalize
    # 데이터 갖고오기
    req=requests.get(url)
    # json load
    data = json.loads(req.text)
    # json to pandas
    preprocessed = json_normalize(data)
    return preprocessed

# %%
def url_generator(target_Symbol, filing_type, limit,period='quarter') : 
    base_url = 'https://financialmodelingprep.com/api/v3/income-statement/RY.TO?limit=5&period=quarter&apikey=89d4891348727c3950b79b9067127c3f'
    if period == 'annual' : 
        base_url = base_url.replace('&period=quarter','')
    
    is_url = base_url.replace('RY.TO', target_Symbol)
    is_url = is_url.replace('=5', '='+str(limit))
    bs_url = is_url.replace('income-statement','balance-sheet-statement')
    cf_url = is_url.replace('income-statement','cash-flow-statement')
    
    if filing_type == 'is' : 
        return is_url
    elif filing_type == 'bs' : 
        return bs_url
    elif filing_type == 'cf' : 
        return cf_url 
    else :
        return "Please input proper filing_type"

# %%
# 손익계산서에서 추출할 핵심정보 
is_cols = ['revenue','costOfRevenue','sellingGeneralAndAdministrativeExpenses','operatingIncome','interestIncome','interestExpense',
          'incomeBeforeTax','netIncome','operatingIncomeRatio'] 
# 대차대조표에서 추출할 핵심정보 
bs_cols = ['fillingDate','totalCurrentAssets','totalNonCurrentAssets','totalAssets', 'totalCurrentLiabilities','totalNonCurrentLiabilities',
           'totalLiabilities','totalEquity','totalLiabilitiesAndTotalEquity']
# 현금흐름표에서 추출할 핵심정보 
cf_cols = ['netCashProvidedByOperatingActivities','netCashUsedForInvestingActivites','netCashUsedProvidedByFinancingActivities',
          'cashAtBeginningOfPeriod','cashAtEndOfPeriod']

# %%
def url_generator(target_Symbol, filing_type, limit,period='quarter') : 
    base_url = 'https://financialmodelingprep.com/api/v3/income-statement/RY.TO?limit=5&period=quarter&apikey=89d4891348727c3950b79b9067127c3f'
    if period == 'annual' : 
        base_url = base_url.replace('&period=quarter','')
    
    is_url = base_url.replace('RY.TO', target_Symbol)
    is_url = is_url.replace('=5', '='+str(limit))
    bs_url = is_url.replace('income-statement','balance-sheet-statement')
    cf_url = is_url.replace('income-statement','cash-flow-statement')
    
    if filing_type == 'is' : 
        return is_url
    elif filing_type == 'bs' : 
        return bs_url
    elif filing_type == 'cf' : 
        return cf_url 
    else :
        return "Please input proper filing_type"

# %% [markdown]
# ## Testing

# %%
    # 기업별 URL 생성 
    is_url = url_generator(target_Symbol, 'is', 2, 'annual')
    bs_url = url_generator(target_Symbol, 'bs', 2, 'annual')
    cf_url = url_generator(target_Symbol, 'cf', 2, 'annual')
    
    # extractor 함수를 이용하여 API를 통한 데이터를 판다스 데이터프레임으로 갖고옴. 
    df_is = extractor(is_url)
    df_bs = extractor(bs_url)
    df_cf = extractor(cf_url)
    
    
    #revenue 만 받는 방법
    print(df_is['revenue'][0])
# Out:
# 0.0

# %% [markdown]
# ## Main Code for Collection

# %%
company_df_list = []
for target_Symbol in tqdm(US_symbols[0:27]) :  
    
    # 기업별 URL 생성 
    is_url = url_generator(target_Symbol, 'is', 2, 'annual')
    
    # extractor 함수를 이용하여 API를 통한 데이터를 판다스 데이터프레임으로 갖고옴. 
    df_is = extractor(is_url)

    # 오류 회피 
    # 간혹가다 손익 계산서, 대차대조표는 있는데 현금흐름표가 없는등의 문제가 있다. 
    # 모든 경우에 대한 오류 회피 
    # try : 만약 추출해 올 열들에 대한 정보가 존재한다면 불러온다
    # except : 만약 추출 해 올 열들에 대한 정보가 있으면, core_is()
      
        
    #company_df = pd.merge(company_df, df_cf)
    column_names = ['name','name_eng','description_short','description','founded_date','product','homepage','employee_cnt','revenue','ceo_name','email','tel','fax','address1','address2','post_code','facebook','youtube','logo','hash_tag','nation_id','industry_id','is_active','created_at','updated_at']
    df = pd.DataFrame(columns = column_names)
    
    # 숫자 데이터 이외에 필요한 기업 일반정보들을 추가한다. 
    # Financil Modeling Prep의 Company profile API를 이용한다. 
    base_url = 'https://financialmodelingprep.com/api/v3/profile/RY.TO?apikey=89d4891348727c3950b79b9067127c3f'
    target_url = base_url.replace('RY.TO', target_Symbol)
    
    # request로 데이터 갖고오기 
    req = requests.get(target_url)
    data = json.loads(req.text)
    
    # 데이터 명세서에 근거하여 필요한 일반정보 칼럼들만 추출하여 company_df에 추가한다. 
    
    try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
    except :df['name'] = "NA"
    try : df['name_eng'] = data[0]['companyName'] 
    except :df['name_eng'] = "NA"
    try : df['description_short'] = data[0]['description']
    except :df['description_short'] = "NA"
    try : df['description'] =data[0]['description']
    except : df['description'] = "NA"
    try : df['founded_date'] =data[0]['ipoDate']
    except : df['founded_date'] = "NA"
    try : df['product'] =data[0]['industry']
    except : df['product'] = "NA"
    try : df['homepage'] =data[0]['website']
    except : df['homepage'] = "NA"
    try : df['employee_cnt'] =data[0]['fullTimeEmployees']
    except : df['employee_cnt'] = "NA"
    try : 
        df['revenue'] = df_is['revenue'][0]
    except : df['revenue'] = "NA"
    try : 
        df['ceo_name'] = data[0]['ceo']
        if data[0]['ceo'] == "" or data[0]['ceo'] == None or data[0]['ceo'] == "NaN" :
            df['ceo_name'] = "NA"
    except : df['ceo_name'] = "NA"
    try : 
        df['email'] = data[0]['email']
        if data[0]['email'] == "" or data[0]['email'] == None or data[0]['fax'] == "email" :
            df['email'] = "NA"
    except : df['email'] = "NA"
    try : df['tel'] =data[0]['phone']
    except : df['tel'] = "NA"
    try :
        df['fax'] = data[0]['fax']
        if data[0]['fax'] == "" or data[0]['fax'] == None or data[0]['fax'] == "NaN" :
            df['fax'] ="NA"
    except : df['fax'] = "NA"
    try : df['address1'] =data[0]['address']
    except : df['address1'] = "NA"
    try : df['address2'] = data[0]['city'] + ", " + data[0]['state'] + ", " + data[0]['country']
    except : df['address2'] = "NA"
    try : 
        df['post_code'] = data[0]['zip']
        if data[0]['zip'] == "" or data[0]['zip'] == None or data[0]['zip'] == "NaN" :
            df['post_code'] = "NA"
    except : df['post_code'] = "NA"
    try : df['facebook'] = data[0]['website']
    except : df['facebook'] = "NA"
    try : df['youtube'] =data[0]['website']
    except : df['youtube'] = "NA"
    try : df['logo'] =data[0]['image']
    except : df['logo'] = "NA"    
    try : df['hash_tag'] = "#"+ data[0]['companyName'] + ", #" + data[0]['industry'] + ", #" + data[0]['sector']
    except : df['hash_tag'] = "NA"
    try : df['nation_id'] = "17"
    except : df['nation_id'] = "NA"
    try : df['industry_id'] = 1
    except : df['industry_id'] = "NA"
    try : df['is_active'] =data[0]['isActivelyTrading']
    except : df['is_active'] = "NA"
    try : df['created_at'] = '2022-05-23'
    except : df['created_at'] = "NA"
    try : df['updated_at'] = '2022-05-23'
    except : df['updated_at'] = "NA"
    
    company_df_list.append(df)
# Out:
#   0%|                                                                                           | 0/27 [00:00<?, ?it/s]C:\Users\DT\AppData\Local\Temp\ipykernel_10120\1788438745.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   4%|███                                                                                | 1/27 [00:01<00:45,  1.73s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_10120\1788438745.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#   7%|██████▏                                                                            | 2/27 [00:03<00:43,  1.72s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_10120\1788438745.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  11%|█████████▏                                                                         | 3/27 [00:05<00:41,  1.75s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_10120\1788438745.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  19%|███████████████▎                                                                   | 5/27 [00:08<00:37,  1.72s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_10120\1788438745.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  30%|████████████████████████▌                                                          | 8/27 [00:13<00:32,  1.70s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_10120\1788438745.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  33%|███████████████████████████▋                                                       | 9/27 [00:15<00:30,  1.71s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_10120\1788438745.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  37%|██████████████████████████████▎                                                   | 10/27 [00:17<00:29,  1.71s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_10120\1788438745.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  41%|█████████████████████████████████▍                                                | 11/27 [00:18<00:27,  1.73s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_10120\1788438745.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  44%|████████████████████████████████████▍                                             | 12/27 [00:20<00:25,  1.71s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_10120\1788438745.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  52%|██████████████████████████████████████████▌                                       | 14/27 [00:24<00:22,  1.76s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_10120\1788438745.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  59%|████████████████████████████████████████████████▌                                 | 16/27 [00:27<00:19,  1.73s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_10120\1788438745.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  63%|███████████████████████████████████████████████████▋                              | 17/27 [00:29<00:17,  1.73s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_10120\1788438745.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  67%|██████████████████████████████████████████████████████▋                           | 18/27 [00:31<00:15,  1.71s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_10120\1788438745.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  70%|█████████████████████████████████████████████████████████▋                        | 19/27 [00:32<00:13,  1.71s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_10120\1788438745.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  74%|████████████████████████████████████████████████████████████▋                     | 20/27 [00:34<00:12,  1.73s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_10120\1788438745.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  78%|███████████████████████████████████████████████████████████████▊                  | 21/27 [00:36<00:10,  1.74s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_10120\1788438745.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  85%|█████████████████████████████████████████████████████████████████████▊            | 23/27 [00:39<00:06,  1.72s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_10120\1788438745.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  89%|████████████████████████████████████████████████████████████████████████▉         | 24/27 [00:41<00:05,  1.74s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_10120\1788438745.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
#  93%|███████████████████████████████████████████████████████████████████████████▉      | 25/27 [00:43<00:03,  1.72s/it]C:\Users\DT\AppData\Local\Temp\ipykernel_10120\1788438745.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   try : df = df.append({'name':  data[0]['companyName']}, ignore_index=True)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 27/27 [00:46<00:00,  1.72s/it]

# %% [markdown]
# # Summary and Visualization

# %%
#Sum up
master_df = pd.concat(company_df_list, ignore_index = True)

# %%
#Visualization
master_df
# Out:
#                                       name  \
# 0               Ethan Allen Interiors Inc.
# 1          GoGreen Investments Corporation
# 2         Living Cell Technologies Limited
# 3                 Sunshine Biopharma, Inc.
# 4                               Cybin Inc.
# 5            CDTi Advanced Materials, Inc.
# 6                 Phoenix Rising Companies
# 7        Screaming Eagle Acquisition Corp.
# 8                             Amesite Inc.
# 9                           VeriSign, Inc.
# 10       Emerald Health Therapeutics, Inc.
# 11      Mayville Engineering Company, Inc.
# 12  Carney Technology Acquisition Corp. II
# 13               National Fuel Gas Company
# 14                           Kaltura, Inc.
# 15                       Leatt Corporation
# 16                     PROS Holdings, Inc.
# 17                         H&R Block, Inc.
# 18                Aurora Acquisition Corp.
# 19                 Athena Gold Corporation
#
#                                   name_eng  \
# 0               Ethan Allen Interiors Inc.
# 1          GoGreen Investments Corporation
# 2         Living Cell Technologies Limited
# 3                 Sunshine Biopharma, Inc.
# 4                               Cybin Inc.
# 5            CDTi Advanced Materials, Inc.
# 6                 Phoenix Rising Companies
# 7        Screaming Eagle Acquisition Corp.
# 8                             Amesite Inc.
# 9                           VeriSign, Inc.
# 10       Emerald Health Therapeutics, Inc.
# 11      Mayville Engineering Company, Inc.
# 12  Carney Technology Acquisition Corp. II
# 13               National Fuel Gas Company
# 14                           Kaltura, Inc.
# 15                       Leatt Corporation
# 16                     PROS Holdings, Inc.
# 17                         H&R Block, Inc.
# 18                Aurora Acquisition Corp.
# 19                 Athena Gold Corporation
#
#                                     description_short  \
# 0   Ethan Allen Interiors Inc. operates as an inte...
# 1   GoGreen Investments Corporation does not have ...
# 2   Living Cell Technologies Limited, a biotechnol...
# 3   Sunshine Biopharma, Inc., a pharmaceutical and...
# 4   Cybin Inc., a biopharmaceutical company, focus...
# 5   CDTi Advanced Materials, Inc. provides technol...
# 6   Phoenix Rising Companies, through its subsidia...
# 7   Screaming Eagle Acquisition Corp. focuses on e...
# 8   Amesite Inc., an artificial intelligence drive...
# 9   VeriSign, Inc., together with its subsidiaries...
# 10  Emerald Health Therapeutics, Inc., together wi...
# 11  Mayville Engineering Company, Inc., together w...
# 12  Carney Technology Acquisition Corp. II does no...
# 13  National Fuel Gas Company operates as a divers...
# 14  Kaltura, Inc. provides various Software-as-a-S...
# 15  Leatt Corporation designs, develops, markets, ...
# 16  PROS Holdings, Inc. provides solutions that op...
# 17  H&R Block, Inc., through its subsidiaries, pro...
# 18  Aurora Acquisition Corp. does not have signifi...
# 19  Athena Gold Corporation, an exploration stage ...
#
#                                           description founded_date  \
# 0   Ethan Allen Interiors Inc. operates as an inte...   1993-03-16
# 1   GoGreen Investments Corporation does not have ...
# 2   Living Cell Technologies Limited, a biotechnol...   2007-07-17
# 3   Sunshine Biopharma, Inc., a pharmaceutical and...
# 4   Cybin Inc., a biopharmaceutical company, focus...   2020-11-11
# 5   CDTi Advanced Materials, Inc. provides technol...   1995-12-26
# 6   Phoenix Rising Companies, through its subsidia...   2021-06-25
# 7   Screaming Eagle Acquisition Corp. focuses on e...   2022-02-28
# 8   Amesite Inc., an artificial intelligence drive...   2020-09-25
# 9   VeriSign, Inc., together with its subsidiaries...   1998-01-29
# 10  Emerald Health Therapeutics, Inc., together wi...   2015-01-02
# 11  Mayville Engineering Company, Inc., together w...   2019-05-09
# 12  Carney Technology Acquisition Corp. II does no...   2020-12-10
# 13  National Fuel Gas Company operates as a divers...   1955-07-25
# 14  Kaltura, Inc. provides various Software-as-a-S...   2021-07-21
# 15  Leatt Corporation designs, develops, markets, ...   2005-08-10
# 16  PROS Holdings, Inc. provides solutions that op...   2007-06-28
# 17  H&R Block, Inc., through its subsidiaries, pro...   1969-10-13
# 18  Aurora Acquisition Corp. does not have signifi...   2021-03-02
# 19  Athena Gold Corporation, an exploration stage ...   2006-12-08
#
#                                    product  \
# 0       Furnishings, Fixtures & Appliances
# 1                          Shell Companies
# 2                            Biotechnology
# 3   Drug Manufacturers—Specialty & Generic
# 4                            Biotechnology
# 5                               Auto Parts
# 6                         Asset Management
# 7                          Shell Companies
# 8                     Software—Application
# 9                  Software—Infrastructure
# 10  Drug Manufacturers—Specialty & Generic
# 11                       Metal Fabrication
# 12                         Shell Companies
# 13                    Oil & Gas Integrated
# 14                 Software—Infrastructure
# 15                              Auto Parts
# 16                    Software—Application
# 17                       Personal Services
# 18                         Shell Companies
# 19          Other Precious Metals & Mining
#
#                               homepage employee_cnt       revenue  \
# 0            http://www.ethanallen.com         3369  6.851690e+08
# 1   https://www.gogreeninvestments.com               0.000000e+00
# 2            https://www.lctglobal.com               0.000000e+00
# 3    https://www.sunshinebiopharma.com            3  2.284260e+05
# 4                https://www.cybin.com           38  8.640000e+05
# 5                 https://www.cdti.com           46  2.835300e+07
# 6          https://www.phoenix-cos.com           20  1.343099e+07
# 7                                                    0.000000e+00
# 8              https://www.amesite.com           22  6.745800e+05
# 9             https://www.verisign.com          902  1.327576e+09
# 10            https://emeraldhealth.ca          110  1.174000e+07
# 11              https://www.mecinc.com         2200  4.548260e+08
# 12                                                   0.000000e+00
# 13        https://www.nationalfuel.com         2188  1.742659e+09
# 14             https://www.kaltura.com          758  1.650160e+08
# 15               https://www.leatt.com           57  7.247581e+07
# 16                https://www.pros.com         1545  2.514230e+08
# 17             https://www.hrblock.com         3600  3.413987e+09
# 18      https://aurora-acquisition.com               0.000000e+00
# 19          https://athenagoldcorp.com               0.000000e+00
#
#                        ceo_name  ... post_code  \
# 0           Mr. Farooq Kathwari  ...     06811
# 1                            NA  ...     77002
# 2                            NA  ...      2000
# 3                            NA  ...   H9R 0A5
# 4                            NA  ...   M5X 1C9
# 5             Mr. Matthew Beale  ...     93033
# 6                            NA  ...     30125
# 7                            NA  ...     10075
# 8    Dr. Ann Marie Sastry Ph.D.  ...     48226
# 9                 Mr. D. Bidzos  ...     20190
# 10                           NA  ...   V6C 1J8
# 11       Mr. Robert D. Kamphuis  ...     53050
# 12                           NA  ...     94301
# 13              Mr. David Bauer  ...     14221
# 14                           NA  ...     10003
# 15  Dr. Christopher James Leatt  ...      7550
# 16            Mr. Andres Reiner  ...     77098
# 17            Mr. Jeffrey Jones  ...     64105
# 18         Mr. Arnaud  Massenet  ...   W1K 6LX
# 19            Mr. John C. Power  ...     95687
#
#                               facebook                             youtube  \
# 0            http://www.ethanallen.com           http://www.ethanallen.com
# 1   https://www.gogreeninvestments.com  https://www.gogreeninvestments.com
# 2            https://www.lctglobal.com           https://www.lctglobal.com
# 3    https://www.sunshinebiopharma.com   https://www.sunshinebiopharma.com
# 4                https://www.cybin.com               https://www.cybin.com
# 5                 https://www.cdti.com                https://www.cdti.com
# 6          https://www.phoenix-cos.com         https://www.phoenix-cos.com
# 7
# 8              https://www.amesite.com             https://www.amesite.com
# 9             https://www.verisign.com            https://www.verisign.com
# 10            https://emeraldhealth.ca            https://emeraldhealth.ca
# 11              https://www.mecinc.com              https://www.mecinc.com
# 12
# 13        https://www.nationalfuel.com        https://www.nationalfuel.com
# 14             https://www.kaltura.com             https://www.kaltura.com
# 15               https://www.leatt.com               https://www.leatt.com
# 16                https://www.pros.com                https://www.pros.com
# 17             https://www.hrblock.com             https://www.hrblock.com
# 18      https://aurora-acquisition.com      https://aurora-acquisition.com
# 19          https://athenagoldcorp.com          https://athenagoldcorp.com
#
#                                                  logo  \
# 0   https://financialmodelingprep.com/image-stock/...
# 1   https://financialmodelingprep.com/image-stock/...
# 2   https://financialmodelingprep.com/image-stock/...
# 3   https://financialmodelingprep.com/image-stock/...
# 4   https://financialmodelingprep.com/image-stock/...
# 5   https://financialmodelingprep.com/image-stock/...
# 6   https://financialmodelingprep.com/image-stock/...
# 7   https://financialmodelingprep.com/image-stock/...
# 8   https://financialmodelingprep.com/image-stock/...
# 9   https://financialmodelingprep.com/image-stock/...
# 10  https://financialmodelingprep.com/image-stock/...
# 11  https://financialmodelingprep.com/image-stock/...
# 12  https://financialmodelingprep.com/image-stock/...
# 13  https://financialmodelingprep.com/image-stock/...
# 14  https://financialmodelingprep.com/image-stock/...
# 15  https://financialmodelingprep.com/image-stock/...
# 16  https://financialmodelingprep.com/image-stock/...
# 17  https://financialmodelingprep.com/image-stock/...
# 18  https://financialmodelingprep.com/image-stock/...
# 19  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
# 0   #Ethan Allen Interiors Inc., #Furnishings, Fix...        17           1
# 1   #GoGreen Investments Corporation, #Shell Compa...        17           1
# 2   #Living Cell Technologies Limited, #Biotechnol...        17           1
# 3   #Sunshine Biopharma, Inc., #Drug Manufacturers...        17           1
# 4            #Cybin Inc., #Biotechnology, #Healthcare        17           1
# 5   #CDTi Advanced Materials, Inc., #Auto Parts, #...        17           1
# 6   #Phoenix Rising Companies, #Asset Management, ...        17           1
# 7   #Screaming Eagle Acquisition Corp., #Shell Com...        17           1
# 8   #Amesite Inc., #Software—Application, #Technology        17           1
# 9   #VeriSign, Inc., #Software—Infrastructure, #Te...        17           1
# 10  #Emerald Health Therapeutics, Inc., #Drug Manu...        17           1
# 11  #Mayville Engineering Company, Inc., #Metal Fa...        17           1
# 12  #Carney Technology Acquisition Corp. II, #Shel...        17           1
# 13  #National Fuel Gas Company, #Oil & Gas Integra...        17           1
# 14  #Kaltura, Inc., #Software—Infrastructure, #Tec...        17           1
# 15  #Leatt Corporation, #Auto Parts, #Consumer Cyc...        17           1
# 16  #PROS Holdings, Inc., #Software—Application, #...        17           1
# 17  #H&R Block, Inc., #Personal Services, #Consume...        17           1
# 18  #Aurora Acquisition Corp., #Shell Companies, #...        17           1
# 19  #Athena Gold Corporation, #Other Precious Meta...        17           1
#
#    is_active  created_at  updated_at
# 0      False  2022-05-23  2022-05-23
# 1       True  2022-05-23  2022-05-23
# 2       True  2022-05-23  2022-05-23
# 3       True  2022-05-23  2022-05-23
# 4       True  2022-05-23  2022-05-23
# 5       True  2022-05-23  2022-05-23
# 6       True  2022-05-23  2022-05-23
# 7       True  2022-05-23  2022-05-23
# 8       True  2022-05-23  2022-05-23
# 9       True  2022-05-23  2022-05-23
# 10      True  2022-05-23  2022-05-23
# 11      True  2022-05-23  2022-05-23
# 12      True  2022-05-23  2022-05-23
# 13      True  2022-05-23  2022-05-23
# 14      True  2022-05-23  2022-05-23
# 15      True  2022-05-23  2022-05-23
# 16      True  2022-05-23  2022-05-23
# 17      True  2022-05-23  2022-05-23
# 18      True  2022-05-23  2022-05-23
# 19      True  2022-05-23  2022-05-23
#
# [20 rows x 25 columns]

# %%
#Visualization2
company_df_list
# Out:
# [                         name                    name_eng  \
#  0  Ethan Allen Interiors Inc.  Ethan Allen Interiors Inc.
#
#                                     description_short  \
#  0  Ethan Allen Interiors Inc. operates as an inte...
#
#                                           description founded_date  \
#  0  Ethan Allen Interiors Inc. operates as an inte...   1993-03-16
#
#                                product                   homepage employee_cnt  \
#  0  Furnishings, Fixtures & Appliances  http://www.ethanallen.com         3369
#
#       revenue             ceo_name  ... post_code                   facebook  \
#  0  685169000  Mr. Farooq Kathwari  ...     06811  http://www.ethanallen.com
#
#                       youtube  \
#  0  http://www.ethanallen.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Ethan Allen Interiors Inc., #Furnishings, Fix...        17           1
#
#    is_active  created_at  updated_at
#  0     False  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                                name                         name_eng  \
#  0  GoGreen Investments Corporation  GoGreen Investments Corporation
#
#                                     description_short  \
#  0  GoGreen Investments Corporation does not have ...
#
#                                           description founded_date  \
#  0  GoGreen Investments Corporation does not have ...
#
#             product                            homepage employee_cnt  revenue  \
#  0  Shell Companies  https://www.gogreeninvestments.com                   0.0
#
#    ceo_name  ... post_code                            facebook  \
#  0       NA  ...     77002  https://www.gogreeninvestments.com
#
#                                youtube  \
#  0  https://www.gogreeninvestments.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #GoGreen Investments Corporation, #Shell Compa...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                                 name                          name_eng  \
#  0  Living Cell Technologies Limited  Living Cell Technologies Limited
#
#                                     description_short  \
#  0  Living Cell Technologies Limited, a biotechnol...
#
#                                           description founded_date  \
#  0  Living Cell Technologies Limited, a biotechnol...   2007-07-17
#
#           product                   homepage employee_cnt  revenue ceo_name  \
#  0  Biotechnology  https://www.lctglobal.com                   0.0       NA
#
#     ... post_code                   facebook                    youtube  \
#  0  ...      2000  https://www.lctglobal.com  https://www.lctglobal.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Living Cell Technologies Limited, #Biotechnol...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                         name                  name_eng  \
#  0  Sunshine Biopharma, Inc.  Sunshine Biopharma, Inc.
#
#                                     description_short  \
#  0  Sunshine Biopharma, Inc., a pharmaceutical and...
#
#                                           description founded_date  \
#  0  Sunshine Biopharma, Inc., a pharmaceutical and...
#
#                                    product                           homepage  \
#  0  Drug Manufacturers—Specialty & Generic  https://www.sunshinebiopharma.com
#
#    employee_cnt   revenue ceo_name  ... post_code  \
#  0            3  228426.0       NA  ...   H9R 0A5
#
#                              facebook                            youtube  \
#  0  https://www.sunshinebiopharma.com  https://www.sunshinebiopharma.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Sunshine Biopharma, Inc., #Drug Manufacturers...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#  Empty DataFrame
#  Columns: [name, name_eng, description_short, description, founded_date, product, homepage, employee_cnt, revenue, ceo_name, email, tel, fax, address1, address2, post_code, facebook, youtube, logo, hash_tag, nation_id, industry_id, is_active, created_at, updated_at]
#  Index: []
#
#  [0 rows x 25 columns],
#           name    name_eng                                  description_short  \
#  0  Cybin Inc.  Cybin Inc.  Cybin Inc., a biopharmaceutical company, focus...
#
#                                           description founded_date  \
#  0  Cybin Inc., a biopharmaceutical company, focus...   2020-11-11
#
#           product               homepage employee_cnt   revenue ceo_name  ...  \
#  0  Biotechnology  https://www.cybin.com           38  864000.0       NA  ...
#
#    post_code               facebook                youtube  \
#  0   M5X 1C9  https://www.cybin.com  https://www.cybin.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                     hash_tag nation_id industry_id is_active  \
#  0  #Cybin Inc., #Biotechnology, #Healthcare        17           1      True
#
#     created_at  updated_at
#  0  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#  Empty DataFrame
#  Columns: [name, name_eng, description_short, description, founded_date, product, homepage, employee_cnt, revenue, ceo_name, email, tel, fax, address1, address2, post_code, facebook, youtube, logo, hash_tag, nation_id, industry_id, is_active, created_at, updated_at]
#  Index: []
#
#  [0 rows x 25 columns],
#  Empty DataFrame
#  Columns: [name, name_eng, description_short, description, founded_date, product, homepage, employee_cnt, revenue, ceo_name, email, tel, fax, address1, address2, post_code, facebook, youtube, logo, hash_tag, nation_id, industry_id, is_active, created_at, updated_at]
#  Index: []
#
#  [0 rows x 25 columns],
#                              name                       name_eng  \
#  0  CDTi Advanced Materials, Inc.  CDTi Advanced Materials, Inc.
#
#                                     description_short  \
#  0  CDTi Advanced Materials, Inc. provides technol...
#
#                                           description founded_date     product  \
#  0  CDTi Advanced Materials, Inc. provides technol...   1995-12-26  Auto Parts
#
#                 homepage employee_cnt   revenue           ceo_name  ...  \
#  0  https://www.cdti.com           46  28353000  Mr. Matthew Beale  ...
#
#    post_code              facebook               youtube  \
#  0     93033  https://www.cdti.com  https://www.cdti.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #CDTi Advanced Materials, Inc., #Auto Parts, #...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                         name                  name_eng  \
#  0  Phoenix Rising Companies  Phoenix Rising Companies
#
#                                     description_short  \
#  0  Phoenix Rising Companies, through its subsidia...
#
#                                           description founded_date  \
#  0  Phoenix Rising Companies, through its subsidia...   2021-06-25
#
#              product                     homepage employee_cnt   revenue  \
#  0  Asset Management  https://www.phoenix-cos.com           20  13430991
#
#    ceo_name  ... post_code                     facebook  \
#  0       NA  ...     30125  https://www.phoenix-cos.com
#
#                         youtube  \
#  0  https://www.phoenix-cos.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Phoenix Rising Companies, #Asset Management, ...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                                  name                           name_eng  \
#  0  Screaming Eagle Acquisition Corp.  Screaming Eagle Acquisition Corp.
#
#                                     description_short  \
#  0  Screaming Eagle Acquisition Corp. focuses on e...
#
#                                           description founded_date  \
#  0  Screaming Eagle Acquisition Corp. focuses on e...   2022-02-28
#
#             product homepage employee_cnt  revenue ceo_name  ... post_code  \
#  0  Shell Companies                            0.0       NA  ...     10075
#
#    facebook youtube                                               logo  \
#  0                   https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Screaming Eagle Acquisition Corp., #Shell Com...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#             name      name_eng  \
#  0  Amesite Inc.  Amesite Inc.
#
#                                     description_short  \
#  0  Amesite Inc., an artificial intelligence drive...
#
#                                           description founded_date  \
#  0  Amesite Inc., an artificial intelligence drive...   2020-09-25
#
#                  product                 homepage employee_cnt   revenue  \
#  0  Software—Application  https://www.amesite.com           22  674580.0
#
#                       ceo_name  ... post_code                 facebook  \
#  0  Dr. Ann Marie Sastry Ph.D.  ...     48226  https://www.amesite.com
#
#                     youtube                                               logo  \
#  0  https://www.amesite.com  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Amesite Inc., #Software—Application, #Technology        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#               name        name_eng  \
#  0  VeriSign, Inc.  VeriSign, Inc.
#
#                                     description_short  \
#  0  VeriSign, Inc., together with its subsidiaries...
#
#                                           description founded_date  \
#  0  VeriSign, Inc., together with its subsidiaries...   1998-01-29
#
#                     product                  homepage employee_cnt     revenue  \
#  0  Software—Infrastructure  https://www.verisign.com          902  1327576000
#
#          ceo_name  ... post_code                  facebook  \
#  0  Mr. D. Bidzos  ...     20190  https://www.verisign.com
#
#                      youtube  \
#  0  https://www.verisign.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #VeriSign, Inc., #Software—Infrastructure, #Te...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#  Empty DataFrame
#  Columns: [name, name_eng, description_short, description, founded_date, product, homepage, employee_cnt, revenue, ceo_name, email, tel, fax, address1, address2, post_code, facebook, youtube, logo, hash_tag, nation_id, industry_id, is_active, created_at, updated_at]
#  Index: []
#
#  [0 rows x 25 columns],
#                                  name                           name_eng  \
#  0  Emerald Health Therapeutics, Inc.  Emerald Health Therapeutics, Inc.
#
#                                     description_short  \
#  0  Emerald Health Therapeutics, Inc., together wi...
#
#                                           description founded_date  \
#  0  Emerald Health Therapeutics, Inc., together wi...   2015-01-02
#
#                                    product                  homepage  \
#  0  Drug Manufacturers—Specialty & Generic  https://emeraldhealth.ca
#
#    employee_cnt   revenue ceo_name  ... post_code                  facebook  \
#  0          110  11740000       NA  ...   V6C 1J8  https://emeraldhealth.ca
#
#                      youtube  \
#  0  https://emeraldhealth.ca
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Emerald Health Therapeutics, Inc., #Drug Manu...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#  Empty DataFrame
#  Columns: [name, name_eng, description_short, description, founded_date, product, homepage, employee_cnt, revenue, ceo_name, email, tel, fax, address1, address2, post_code, facebook, youtube, logo, hash_tag, nation_id, industry_id, is_active, created_at, updated_at]
#  Index: []
#
#  [0 rows x 25 columns],
#                                   name                            name_eng  \
#  0  Mayville Engineering Company, Inc.  Mayville Engineering Company, Inc.
#
#                                     description_short  \
#  0  Mayville Engineering Company, Inc., together w...
#
#                                           description founded_date  \
#  0  Mayville Engineering Company, Inc., together w...   2019-05-09
#
#               product                homepage employee_cnt    revenue  \
#  0  Metal Fabrication  https://www.mecinc.com         2200  454826000
#
#                   ceo_name  ... post_code                facebook  \
#  0  Mr. Robert D. Kamphuis  ...     53050  https://www.mecinc.com
#
#                    youtube                                               logo  \
#  0  https://www.mecinc.com  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Mayville Engineering Company, Inc., #Metal Fa...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                                       name  \
#  0  Carney Technology Acquisition Corp. II
#
#                                   name_eng  \
#  0  Carney Technology Acquisition Corp. II
#
#                                     description_short  \
#  0  Carney Technology Acquisition Corp. II does no...
#
#                                           description founded_date  \
#  0  Carney Technology Acquisition Corp. II does no...   2020-12-10
#
#             product homepage employee_cnt  revenue ceo_name  ... post_code  \
#  0  Shell Companies                              0       NA  ...     94301
#
#    facebook youtube                                               logo  \
#  0                   https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Carney Technology Acquisition Corp. II, #Shel...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                          name                   name_eng  \
#  0  National Fuel Gas Company  National Fuel Gas Company
#
#                                     description_short  \
#  0  National Fuel Gas Company operates as a divers...
#
#                                           description founded_date  \
#  0  National Fuel Gas Company operates as a divers...   1955-07-25
#
#                  product                      homepage employee_cnt  \
#  0  Oil & Gas Integrated  https://www.nationalfuel.com         2188
#
#        revenue         ceo_name  ... post_code                      facebook  \
#  0  1742659000  Mr. David Bauer  ...     14221  https://www.nationalfuel.com
#
#                          youtube  \
#  0  https://www.nationalfuel.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #National Fuel Gas Company, #Oil & Gas Integra...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#              name       name_eng  \
#  0  Kaltura, Inc.  Kaltura, Inc.
#
#                                     description_short  \
#  0  Kaltura, Inc. provides various Software-as-a-S...
#
#                                           description founded_date  \
#  0  Kaltura, Inc. provides various Software-as-a-S...   2021-07-21
#
#                     product                 homepage employee_cnt    revenue  \
#  0  Software—Infrastructure  https://www.kaltura.com          758  165016000
#
#    ceo_name  ... post_code                 facebook                  youtube  \
#  0       NA  ...     10003  https://www.kaltura.com  https://www.kaltura.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Kaltura, Inc., #Software—Infrastructure, #Tec...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                  name           name_eng  \
#  0  Leatt Corporation  Leatt Corporation
#
#                                     description_short  \
#  0  Leatt Corporation designs, develops, markets, ...
#
#                                           description founded_date     product  \
#  0  Leatt Corporation designs, develops, markets, ...   2005-08-10  Auto Parts
#
#                  homepage employee_cnt   revenue                     ceo_name  \
#  0  https://www.leatt.com           57  72475813  Dr. Christopher James Leatt
#
#     ... post_code               facebook                youtube  \
#  0  ...      7550  https://www.leatt.com  https://www.leatt.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Leatt Corporation, #Auto Parts, #Consumer Cyc...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                    name             name_eng  \
#  0  PROS Holdings, Inc.  PROS Holdings, Inc.
#
#                                     description_short  \
#  0  PROS Holdings, Inc. provides solutions that op...
#
#                                           description founded_date  \
#  0  PROS Holdings, Inc. provides solutions that op...   2007-06-28
#
#                  product              homepage employee_cnt    revenue  \
#  0  Software—Application  https://www.pros.com         1545  251423000
#
#              ceo_name  ... post_code              facebook  \
#  0  Mr. Andres Reiner  ...     77098  https://www.pros.com
#
#                  youtube                                               logo  \
#  0  https://www.pros.com  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #PROS Holdings, Inc., #Software—Application, #...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#  Empty DataFrame
#  Columns: [name, name_eng, description_short, description, founded_date, product, homepage, employee_cnt, revenue, ceo_name, email, tel, fax, address1, address2, post_code, facebook, youtube, logo, hash_tag, nation_id, industry_id, is_active, created_at, updated_at]
#  Index: []
#
#  [0 rows x 25 columns],
#                name         name_eng  \
#  0  H&R Block, Inc.  H&R Block, Inc.
#
#                                     description_short  \
#  0  H&R Block, Inc., through its subsidiaries, pro...
#
#                                           description founded_date  \
#  0  H&R Block, Inc., through its subsidiaries, pro...   1969-10-13
#
#               product                 homepage employee_cnt     revenue  \
#  0  Personal Services  https://www.hrblock.com         3600  3413987000
#
#              ceo_name  ... post_code                 facebook  \
#  0  Mr. Jeffrey Jones  ...     64105  https://www.hrblock.com
#
#                     youtube                                               logo  \
#  0  https://www.hrblock.com  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #H&R Block, Inc., #Personal Services, #Consume...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                         name                  name_eng  \
#  0  Aurora Acquisition Corp.  Aurora Acquisition Corp.
#
#                                     description_short  \
#  0  Aurora Acquisition Corp. does not have signifi...
#
#                                           description founded_date  \
#  0  Aurora Acquisition Corp. does not have signifi...   2021-03-02
#
#             product                        homepage employee_cnt  revenue  \
#  0  Shell Companies  https://aurora-acquisition.com                   0.0
#
#                 ceo_name  ... post_code                        facebook  \
#  0  Mr. Arnaud  Massenet  ...   W1K 6LX  https://aurora-acquisition.com
#
#                            youtube  \
#  0  https://aurora-acquisition.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Aurora Acquisition Corp., #Shell Companies, #...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#                        name                 name_eng  \
#  0  Athena Gold Corporation  Athena Gold Corporation
#
#                                     description_short  \
#  0  Athena Gold Corporation, an exploration stage ...
#
#                                           description founded_date  \
#  0  Athena Gold Corporation, an exploration stage ...   2006-12-08
#
#                            product                    homepage employee_cnt  \
#  0  Other Precious Metals & Mining  https://athenagoldcorp.com
#
#     revenue           ceo_name  ... post_code                    facebook  \
#  0      0.0  Mr. John C. Power  ...     95687  https://athenagoldcorp.com
#
#                        youtube  \
#  0  https://athenagoldcorp.com
#
#                                                  logo  \
#  0  https://financialmodelingprep.com/image-stock/...
#
#                                              hash_tag nation_id industry_id  \
#  0  #Athena Gold Corporation, #Other Precious Meta...        17           1
#
#    is_active  created_at  updated_at
#  0      True  2022-05-23  2022-05-23
#
#  [1 rows x 25 columns],
#  Empty DataFrame
#  Columns: [name, name_eng, description_short, description, founded_date, product, homepage, employee_cnt, revenue, ceo_name, email, tel, fax, address1, address2, post_code, facebook, youtube, logo, hash_tag, nation_id, industry_id, is_active, created_at, updated_at]
#  Index: []
#
#  [0 rows x 25 columns]]

# %%
#Convert to CSV
master_df.to_csv(r"C:\Users\DT\Desktop\자료\TestData.csv")

# %% [markdown]
# # Testing and Samples

# %%
#Testing Example 1
is_url = url_generator('CA.PA', 'is', 2, 'annual')
bs_url = url_generator('CA.PA', 'bs', 2, 'annual')
cf_url = url_generator('CA.PA', 'cf', 2, 'annual')

# extractor 함수를 이용하여 API를 통한 데이터를 판다스 데이터프레임으로 갖고옴. 
extractor(is_url)
# Out:
#          date symbol reportedCurrency   cik fillingDate acceptedDate  \
# 0  2020-12-31  CA.PA              EUR  None  2020-12-31   2020-12-31
# 1  2019-12-31  CA.PA              EUR  None  2019-12-31   2019-12-31
#
#   calendarYear period      revenue  costOfRevenue  ...  incomeBeforeTaxRatio  \
# 0         2020     FY  72150000000    56705000000  ...              0.018725
# 1         2019     FY  74142000000    58054000000  ...              0.009738
#
#    incomeTaxExpense   netIncome  netIncomeRatio   eps  epsdiluted  \
# 0         498000000   641000000        0.008884  0.80        0.79
# 1         504000000  1129000000        0.015228  1.43        1.42
#
#    weightedAverageShsOut  weightedAverageShsOutDil  \
# 0              805713713                 807587891
# 1              791473793                 792378702
#
#                                                 link  \
# 0  https://www.infogreffe.com/recherche-entrepris...
# 1  https://www.infogreffe.com/recherche-entrepris...
#
#                                            finalLink
# 0  https://www.infogreffe.com/recherche-entrepris...
# 1  https://www.infogreffe.com/recherche-entrepris...
#
# [2 rows x 38 columns]

# %%
#Testing Example 1
extractor(bs_url)
# Out:
#          date symbol reportedCurrency   cik fillingDate acceptedDate  \
# 0  2020-12-31  CA.PA              EUR  None  2020-12-31   2020-12-31
# 1  2019-12-31  CA.PA              EUR  None  2019-12-31   2019-12-31
#
#   calendarYear period  cashAndCashEquivalents  shortTermInvestments  ...  \
# 0         2020     FY              4439000000             179000000  ...
# 1         2019     FY              4466000000              82000000  ...
#
#    totalStockholdersEquity  totalLiabilitiesAndStockholdersEquity  \
# 0               9795000000                            46086000000
# 1               9940000000                            49066000000
#
#    minorityInterest  totalEquity  totalLiabilitiesAndTotalEquity  \
# 0        1502000000  11297000000                     47588000000
# 1        1736000000  11676000000                     50802000000
#
#    totalInvestments    totalDebt     netDebt  \
# 0        1757000000  12112000000  7673000000
# 1        1809000000  11872000000  7406000000
#
#                                                 link  \
# 0  https://www.infogreffe.com/recherche-entrepris...
# 1  https://www.infogreffe.com/recherche-entrepris...
#
#                                            finalLink
# 0  https://www.infogreffe.com/recherche-entrepris...
# 1  https://www.infogreffe.com/recherche-entrepris...
#
# [2 rows x 54 columns]

# %%
#Testing Example 1
extractor(cf_url)
# Out:
#          date symbol reportedCurrency   cik fillingDate acceptedDate  \
# 0  2020-12-31  CA.PA              EUR  None  2020-12-31   2020-12-31
# 1  2019-12-31  CA.PA              EUR  None  2019-12-31   2019-12-31
#
#   calendarYear period   netIncome  depreciationAndAmortization  ...  \
# 0         2020     FY   641000000                   2292000000  ...
# 1         2019     FY  1129000000                   2328000000  ...
#
#    netCashUsedProvidedByFinancingActivities  effectOfForexChangesOnCash  \
# 0                               -1126000000                  -455000000
# 1                               -1987000000                   -81000000
#
#    netChangeInCash  cashAtEndOfPeriod  cashAtBeginningOfPeriod  \
# 0        -27000000         4439000000               4466000000
# 1        166000000         4466000000               4300000000
#
#    operatingCashFlow  capitalExpenditure  freeCashFlow  \
# 0         3395000000         -1614000000    1781000000
# 1         3247000000         -1725000000    1522000000
#
#                                                 link  \
# 0  https://www.infogreffe.com/recherche-entrepris...
# 1  https://www.infogreffe.com/recherche-entrepris...
#
#                                            finalLink
# 0  https://www.infogreffe.com/recherche-entrepris...
# 1  https://www.infogreffe.com/recherche-entrepris...
#
# [2 rows x 40 columns]

# %%
#Testing Example 1
extractor(is_url)
# Out:
#          date symbol reportedCurrency   cik fillingDate acceptedDate  \
# 0  2020-12-31  CA.PA              EUR  None  2020-12-31   2020-12-31
# 1  2019-12-31  CA.PA              EUR  None  2019-12-31   2019-12-31
#
#   calendarYear period      revenue  costOfRevenue  ...  incomeBeforeTaxRatio  \
# 0         2020     FY  72150000000    56705000000  ...              0.018725
# 1         2019     FY  74142000000    58054000000  ...              0.009738
#
#    incomeTaxExpense   netIncome  netIncomeRatio   eps  epsdiluted  \
# 0         498000000   641000000        0.008884  0.80        0.79
# 1         504000000  1129000000        0.015228  1.43        1.42
#
#    weightedAverageShsOut  weightedAverageShsOutDil  \
# 0              805713713                 807587891
# 1              791473793                 792378702
#
#                                                 link  \
# 0  https://www.infogreffe.com/recherche-entrepris...
# 1  https://www.infogreffe.com/recherche-entrepris...
#
#                                            finalLink
# 0  https://www.infogreffe.com/recherche-entrepris...
# 1  https://www.infogreffe.com/recherche-entrepris...
#
# [2 rows x 38 columns]
