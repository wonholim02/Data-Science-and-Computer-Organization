# %%
import bs4
import time
import csv 
import pandas as pd 
from platform import python_version
import requests
import lxml 
import xlrd
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.select import Select
from selenium.webdriver.common.by import By
import csv 
import pandas as pd 
from platform import python_version
import xlsxwriter
from bs4 import BeautifulSoup

# %%
path = r'C:\Users\user\Desktop\자료\chromedriver'

# %%
print(python_version())
print(pd.__version__)
# Out:
# 3.9.12
# 1.4.2

# %%
initial = 97514949

# %%
workbook = xlsxwriter.Workbook('USPTO_Crawling_Main.xlsx')
worksheet = workbook.add_worksheet()
a = 0
row = 0
column = 0

content = ['Serial Number','Legal Entity State','Legal Entity Type','Company Name','Mark Literal','Mark Type','Purpose','Class Status','Primary US Classes - 1','Primary US Classes - 2','Primary US Classes - 3','Primary US Classes - 4','Primary US Classes - 5','Primary US Classes - 6','Primary International Class','Primary International Class Description','Address','Source','Date']
for item in content :
    worksheet.write(row, column, item)
    column += 1
row += 1

base_url = "https://uspto.report/TM/"
driver = webdriver.Chrome(path)
driver.get(base_url)
time.sleep(2.5)
failList = []

for i in reversed(range(97500000,initial)):
    try:
        driver.get(base_url + str(i))
    except:
        driver.get(base_url)
    serial = i
    a = i
    column = 0
    info = []
    time.sleep(2.5)
    try:
        head = driver.find_element(By.XPATH, value='/html/body/div[2]/div/h1').text
    except:
        head = "Trademark Filing"
    if head == "Trademark Filing":
        
        print("NA")
    else:
        #serial number
        info.append(serial)

        #state
        try:
            state = driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[6]/div[2]/table/tbody/tr[4]/td[2]').text
        except:
            try:
                state = driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[6]/div[2]/table/tbody/tr[4]/td[2]').text
            except:
                try:
                    state = driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[6]/div[2]/table/tbody/tr[2]/td[2]').text
                except:
                    try:
                        state = driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[6]/div[2]/table/tbody/tr[4]/td[2]').text
                    except:
                        state = "NA"

        #legal entity state
        info.append(state)

        #legal entity type
        try:
            info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[6]/div[2]/table/tbody/tr[3]/td[2]').text)
        except:
            try:
                info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[6]/div[2]/table[1]/tbody/tr[3]/td[2]').text)
            except:
                try:
                    info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[6]/div[2]/table/tbody/tr[3]/td[2]').text)
                except:
                    info.append("Business")

        #Company Name
        try:
            info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[6]/div[2]/table/tbody/tr[1]/td[2]').text)
        except:
            try:
                info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/nav/ol/li[2]/a/span').text)
            except:
                try:
                    info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/h2').text)
                except:
                    try:
                        info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/nav/ol/li[2]/a/span').text)
                    except:
                        try:
                            info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[6]/div[2]/table/tbody/tr[1]/td[2]/a').text)
                        except:
                            info.append("Failed")

        #Mark Literal
        try:
            info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/h1').text)
        except:
            try:
                info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/nav/ol/li[3]/a/span').text)
            except:
                info.append("Failed")

        #Mark Type
        info.append("Trademark")

        #Purpose
        try:
            info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/p[2]/span').text)
        except:
            try:
                info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/p').text)
            except:
                info.append("Trademark")

        #status
        try:
            info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/div[2]/div[3]').text)
        except:
            try:
                info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/div[1]/div[3]').text)
            except:
                info.append("NA")

        #industry
        try:
            info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[9]/td[2]/ul/li[1]').text)
        except:
            try:
                info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[10]/td[2]/ul/li[1]').text)
            except:
                try:
                    info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[10]/div[2]/table[2]/tbody/tr[2]/td[2]').text)
                except:
                    try:
                        info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[11]/td[2]/ul/li[1]').text)
                    except:
                        try:
                            info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[9]/td[2]/ul/li[2]').text)
                        except:
                            try:
                                info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[10]/div[2]/table[2]/tbody/tr[2]/td[2]').text)
                            except:
                                info.append("NA")

        try:
            info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[9]/td[2]/ul/li[2]').text)
        except:
            try:
                info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[10]/td[2]/ul/li[1]').text)
            except:
                try:
                    info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[10]/div[2]/table[2]/tbody/tr[2]/td[2]').text)
                except:
                    try:
                        info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[9]/td[2]/ul/li[2]').text)
                    except:
                        try:
                            info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[11]/td[2]/ul/li[2]').text)
                        except:
                            try:
                                info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[10]/div[2]/table[2]/tbody/tr[2]/td[2]').text)
                            except:
                                info.append("NA")

        try:
            info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[9]/td[2]/ul/li[3]').text)
        except:
            try:
                info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[10]/td[2]/ul/li[2]').text)
            except:
                try:
                    info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[10]/div[2]/table[2]/tbody/tr[2]/td[2]').text)
                except:
                    try:
                        info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[9]/td[2]/ul/li[2]').text)
                    except:
                        try:
                            info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[11]/td[2]/ul/li[3]').text)
                        except:
                            try:
                                info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[10]/div[2]/table[2]/tbody/tr[2]/td[2]').text)
                            except:
                                info.append("NA")

        try:
            info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[9]/td[2]/ul/li[4]').text)
        except:
            try:
                info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[10]/td[2]/ul/li[2]').text)
            except:
                try:
                    info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[10]/div[2]/table[2]/tbody/tr[2]/td[2]').text)
                except:
                    try:
                        info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[9]/td[2]/ul/li[2]').text)
                    except:
                        try:
                            info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[11]/td[2]/ul/li[4]').text)
                        except:
                            try:
                                info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[10]/div[2]/table[2]/tbody/tr[2]/td[2]').text)
                            except:
                                info.append("NA")

        try:
            info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[9]/td[2]/ul/li[5]').text)
        except:
            try:
                info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[10]/td[2]/ul/li[3]').text)
            except:
                try:
                    info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[10]/div[2]/table[2]/tbody/tr[2]/td[2]').text)
                except:
                    try:
                        info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[9]/td[2]/ul/li[2]').text)
                    except:
                        try:
                            info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[11]/td[2]/ul/li[5]').text)
                        except:
                            try:
                                info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[10]/div[2]/table[2]/tbody/tr[2]/td[2]').text)
                            except:
                                try:
                                    info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[10]/td[2]/ul/li[1]').text)
                                except:
                                    info.append("NA")

        try:
            info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[9]/td[2]/ul/li[6]').text)
        except:
            try:
                info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[10]/td[2]/ul/li[3]').text)
            except:
                try:
                    info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[10]/div[2]/table[2]/tbody/tr[2]/td[2]').text)
                except:
                    try:
                        info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[9]/td[2]/ul/li[2]').text)
                    except:
                        try:
                            info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[11]/td[2]/ul/li[5]').text)
                        except:
                            try:
                                info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[10]/div[2]/table[2]/tbody/tr[2]/td[2]').text)
                            except:
                                try:
                                    info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[10]/td[2]/ul/li[1]').text)
                                except:
                                    info.append("NA")
        #international
        try:
            info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[10]/td[2]/ul/li[1]').text)
        except:
            try:
                info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[10]/div[2]/table[2]/tbody/tr[2]/td[2]').text)
            except:
                try:
                    info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[9]/td[2]/ul/li[2]').text)
                except:
                    try:
                        info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[11]/td[2]/ul/li[5]').text)
                    except:
                        try:
                            info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[10]/div[2]/table[2]/tbody/tr[2]/td[2]').text)
                        except:
                            info.append("NA")

        #international description
        try:
            info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[10]/td[2]/ul/li[2]').text)
        except:
            try:
                info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[10]/div[2]/table[2]/tbody/tr[2]/td[2]').text)
            except:
                try:
                    info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[9]/td[2]/ul/li[2]').text)
                except:
                    try:
                        info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[4]/div[2]/table[1]/tbody/tr[9]/td[2]/ul/li[2]').text)
                    except:
                        try:
                            info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[10]/div[2]/table[2]/tbody/tr[2]/td[2]').text)
                        except:
                            info.append("NA")

        #address
        try:
            info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[6]/div[2]/table/tbody/tr[2]/td[2]').text)
        except:
            try:
                info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[5]/div[2]/table[1]/tbody/tr[2]/td[2]').text)
            except:
                try:
                    info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[6]/div[2]/table/tbody/tr[2]/td[2]').text)
                except:
                    try:
                        info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[6]/div[2]/table/tbody/tr[3]/td[2]').text)
                    except:
                        try:
                            info.append(driver.find_element(By.XPATH, value='/html/body/div[2]/div/div[5]/div[2]/table/tbody/tr[2]/td[2]').text)
                        except:
                            info.append(state)

        info.append("USPTO")
        info.append("2022-07-26")
        print(info)
        for item in info :
            worksheet.write(row, column, item)
            column += 1
        row += 1
        print("End Point:")
        print(a)
workbook.close()
print("Finished")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14388\3918099423.py:14: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# [97514648, 'CHINA', 'Limited Company (ltd.?', 'Guangzhou Poolworld Environmental Technology Co., Ltd.', 'POOLWORLD', 'Trademark', 'Mark For: POOLWORLD™ trademark registration is intended to cover the categories of showers; Air-conditioning, air cooling and ventilation apparatus and instruments; Bathroom heaters; Desiccating units for producing dried fruits; Electric radiators; Hair driers; Heat pumps; Heating apparatus for vehicles; Heating installations; Hot water heaters; Refrigerating appliances and installations; Regulating accessories for water supply, namely, metered valves; Sauna bath installations; Solar thermal air systems for heating purposes; Space heating apparatus; Underfloor heating apparatus and installations; Water heaters.', 'LIVE APPLICATION Awaiting Examination', '013: Hardware, Plumbing and Steamfitting Supplies', '021: Electrical Apparatus, Machines and Supplies', '023: Cutlery, Machinery, Tools and Parts Thereof', '024: Laundry Appliances and Machines', '031: Filters and Refrigerators', '034: Heating, Lighting and Ventilating Apparatus', '011 - Primary Class', 'Environmental control apparatus) Apparatus for lighting, heating, steam generating, cooking, refrigerating, drying, ventilating, water supply and sanitary purposes.', 'Room 703, Building 11, No.684, Shibei Industrial Rd, Dashi Street, Panyu Dist. Guangzhou City CHINA 511430', 'USPTO', '2022-07-26']
# End Point:
# 97514648
# [97514647, 'VIRGINIA', 'Limited Liability Company', 'Pochedly Equity Group', 'MIDWEST RESERVE HOPS', 'Trademark', 'processed pelletized hops for use in making beer.', 'LIVE APPLICATION Awaiting Examination', '045: Soft Drinks and Carbonated Waters', '045: Soft Drinks and Carbonated Waters', '046: Foods and Ingredients of Foods', '046: Foods and Ingredients of Foods', '048: Malt Beverages and Liquors', '048: Malt Beverages and Liquors', '045: Soft Drinks and Carbonated Waters', '046: Foods and Ingredients of Foods', '2919 Somerset Lane Norfolk, VIRGINIA UNITED STATES 23518', 'USPTO', '2022-07-26']
# End Point:
# 97514647
# [97514646, 'DELAWARE', 'Limited Liability Company', 'Jeule Ranch Golf Club LLC', 'LADERA GOLF CLUB', 'Trademark', 'Mark For: LADERA GOLF CLUB™ trademark registration is intended to cover the categories of golf club services; Golf courses.', 'LIVE APPLICATION Awaiting Examination', '100: Miscellaneous', '101: Advertising and Business', '107: Education and Entertainment', '(Education and entertainment) Education; providing of training; entertainment; sporting and cultural activities.', '101: Advertising and Business', '101: Advertising and Business', '041 - Primary Class', '(Education and entertainment) Education; providing of training; entertainment; sporting and cultural activities.', '1100 Glendon Avenue, Suite 2000 Los Angeles, CALIFORNIA UNITED STATES 90024', 'USPTO', '2022-07-26']
# End Point:
# 97514646
# [97514645, 'DELAWARE', 'Limited Liability Company', 'Redgrave Strategic Data Solutions, LLC', 'REDGRAVE DATA', 'Trademark', 'Mark For: REDGRAVE DATA™ trademark registration is intended to cover the categories of downloadable and recorded computer?software?for use in the fields of legal operations, investigations, litigation support, electronic discovery, document processing, regulatory compliance, information governance, risk management, legal project management, information technology, data privacy and security, data analytics and visualization, metrics and reporting, statistical validation, machine learning, artificial intelligence, natural language processing, automation, robotic process automation, information technology, computer hardware and software, custom software development, and cloud-based services; downloadable and recorded computer software using artificial intelligence or machine learning models for legal operations, investigations, litigation support, legal project management, regulatory compliance, and information governance; computer software for locating, identifying, preserving, collecting, filtering, processing, storing, sharing, analyzing, organizing, reviewing, searching, retrieving, managing, categorizing, coding, presenting, archiving, deleting, and producing records, documents, emails, multimedia materials, and other electronically stored information, generating reports, conducting searches, analyzing and categorizing electronically stored information, creating machine learning models, and visualizing large datasets.', 'LIVE APPLICATION Awaiting Examination', '021: Electrical Apparatus, Machines and Supplies', '023: Cutlery, Machinery, Tools and Parts Thereof', '026: Measuring and Scientific Appliances', '036: Musical Instruments and Supplies', '038: Prints and Publications', '023: Cutlery, Machinery, Tools and Parts Thereof', '009 - Primary Class', '(Electrical and scientific apparatus) Scientific, nautical, surveying, electric, photographic, cinematographic, optical, weighing, measuring, signaling, checking (supervision), lifesaving and teaching apparatus and instruments; apparatus for recording, transmission or reproduction of sound or images; magnetic data carriers, recording discs; automatic vending machines and mechanisms for coin operated apparatus; cash registers, calculating machines, data processing equipment and computers; fire-extinguishing apparatus.', '14555 Avion Parkway, Suite 275 Chantilly, VIRGINIA UNITED STATES 20151', 'USPTO', '2022-07-26']
# End Point:
# 97514645
# [97514644, 'CHINA', 'Limited Company (ltd.)', 'POWER WORLD MACHINERY EQUIPMENT CO., LTD', 'POWERWORLD', 'Trademark', 'Mark For: POWERWORLD™ trademark registration is intended to cover the categories of showers; Air-conditioning, air cooling and ventilation apparatus and instruments; Bathroom heaters; Desiccating units for producing dried fruits; Electric radiators; Hair driers; Heat pumps; Heating apparatus for vehicles; Heating installations; Hot water heaters; Refrigerating appliances and installations; Regulating accessories for water supply, namely, metered valves; Sauna bath installations; Solar thermal air systems for heating purposes; Space heating apparatus; Underfloor heating apparatus and installations; Water heaters.', 'LIVE APPLICATION Awaiting Examination', '013: Hardware, Plumbing and Steamfitting Supplies', '021: Electrical Apparatus, Machines and Supplies', '023: Cutlery, Machinery, Tools and Parts Thereof', '024: Laundry Appliances and Machines', '031: Filters and Refrigerators', '034: Heating, Lighting and Ventilating Apparatus', '011 - Primary Class', 'Environmental control apparatus) Apparatus for lighting, heating, steam generating, cooking, refrigerating, drying, ventilating, water supply and sanitary purposes.', 'NO.24, The Fourth Industrial Zone, Shajing Town, HouTing Street, BaoAn Dist ShenZhen CHINA 518104', 'USPTO', '2022-07-26']
# End Point:
# 97514644
# [97514643, 'UTAH', 'Limited Liability Company', "Women's Health PharmD, LLC", 'HEALTHY INSIDE, HEALTHY OUTSIDE THE REAL PHARMD YOUR TRUSTED HEALTHCARE LIAISON', 'Trademark', 'cosmetics sold as an integral component of non-medicated skincare preparations; Facial washes; Non-medicated skin care preparations, namely, toner.', 'LIVE APPLICATION Awaiting Examination', '001: Raw or Partly Prepared Materials', '001: Raw or Partly Prepared Materials', '004: Abrasives and Polishing Materials', '004: Abrasives and Polishing Materials', '006: Chemicals and Chemical Compositions', '006: Chemicals and Chemical Compositions', '001: Raw or Partly Prepared Materials', '004: Abrasives and Polishing Materials', '3556 S 5600 W #1-753 Salt Lake City, UTAH UNITED STATES 84120', 'USPTO', '2022-07-26']
# End Point:
# 97514643
# [97514642, 'CALIFORNIA', 'Limited Liability Company', 'OUTLAND CREATIONS LLC', 'OUTLAND CREATIONS', 'Trademark', 'Mark For: OUTLAND CREATIONS™ trademark registration is intended to cover the categories of provision of an on-line marketplace for buyers and sellers of patented devices, systems, and methods; patent licenses; and patents.', 'LIVE APPLICATION Awaiting Examination', '100: Miscellaneous', '101: Advertising and Business', '102: Insurance and Financial', '(Advertising and business) Advertising; business management; business administration; office functions.', '101: Advertising and Business', '101: Advertising and Business', '035 - Primary Class', '(Advertising and business) Advertising; business management; business administration; office functions.', '1721 Broadway Ste 201 Oakland,, CALIFORNIA UNITED STATES 94612', 'USPTO', '2022-07-26']
# End Point:
# 97514642
# [97514641, 'CALIFORNIA', 'State University', 'The Board of Trustees of the California State University', 'STUDENT SUCCESS DASHBOARD', 'Trademark', 'Mark For: STUDENT SUCCESS DASHBOARD™ trademark registration is intended to cover the categories of software and software tools for assessing inequities in student graduation rates, increasing graduation rates, eliminating equity gaps in degree completion, and/or meeting workforce or employment needs.', 'LIVE APPLICATION Awaiting Examination', '021: Electrical Apparatus, Machines and Supplies', '021: Electrical Apparatus, Machines and Supplies', '023: Cutlery, Machinery, Tools and Parts Thereof', '023: Cutlery, Machinery, Tools and Parts Thereof', '026: Measuring and Scientific Appliances', '026: Measuring and Scientific Appliances', '021: Electrical Apparatus, Machines and Supplies', '023: Cutlery, Machinery, Tools and Parts Thereof', 'Office of the Chancellor 401 Golden Shore Long Beach, CALIFORNIA UNITED STATES 90802', 'USPTO', '2022-07-26']
# End Point:
# 97514641
# NA
# [97514639, 'DELAWARE', 'Corporation', 'Twentieth Century Fox Film Corporation', 'THE ANSWERS', 'Trademark', 'Mark For: THE ANSWERS™ trademark registration is intended to cover the categories of entertainment services in the nature of a television and multimedia program series featuring comedy and drama distributed via various platforms across multiple forms of transmission media; entertainment services, namely, providing podcasts featuring subjects of general human interest; providing online non-downloadable video clips and other multimedia digital content containing audio, video, artwork, and text from and related to a comedy and drama multimedia program.', 'LIVE APPLICATION Awaiting Examination', '100: Miscellaneous', '101: Advertising and Business', '107: Education and Entertainment', '(Education and entertainment) Education; providing of training; entertainment; sporting and cultural activities.', '101: Advertising and Business', '101: Advertising and Business', '041 - Primary Class', '(Education and entertainment) Education; providing of training; entertainment; sporting and cultural activities.', '10201 West Pico Boulevard Los Angeles, CALIFORNIA UNITED STATES 90035', 'USPTO', '2022-07-26']
# End Point:
# 97514639
# [97514638, 'DELAWARE', 'Limited Liability Company', 'Jeule Ranch Golf Club LLC', 'LADERA GOLF CLUB', 'Trademark', 'Mark For: LADERA GOLF CLUB™ trademark registration is intended to cover the categories of golf accessory pouches; Golf bag covers; Golf bag tags; Golf bags; Golf ball markers; Golf balls; Golf club covers; Golf clubs; Golf divot repair tools; Golf gloves; Golf tees; Golf towel clips for attachment to golf bags.', 'LIVE APPLICATION Awaiting Examination', '022: Games, Toys and Sporting Good', '023: Cutlery, Machinery, Tools and Parts Thereof', '038: Prints and Publications', '050: Merchandise Not Otherwise Classified', '023: Cutlery, Machinery, Tools and Parts Thereof', '023: Cutlery, Machinery, Tools and Parts Thereof', '028 - Primary Class', '(Toys and sporting goods) Games and playthings; gymnastic and sporting articles not included in other classes; decorations for Christmas trees.', '1100 Glendon Avenue, Suite 2000 Los Angeles, CALIFORNIA UNITED STATES 90024', 'USPTO', '2022-07-26']
# End Point:
# 97514638
# [97514637, 'SWITZERLAND', 'Aktiengesellschaft', 'Egon Zehnder International AG', 'EGON ZEHNDER', 'Trademark', 'Mark For: EGON ZEHNDER™ trademark registration is intended to cover the categories of personnel recruitment offices, employment agencies, personnel consultancy, personnel management, personnel management consultancy; personnel recruitment, namely, assessment and selection of executives and executive teams; business management consulting; services in the field of consultancy in business administration and management, in particular advice of executives in the organization and running of businesses.', 'LIVE APPLICATION Awaiting Examination', '100: Miscellaneous', '101: Advertising and Business', '102: Insurance and Financial', '(Advertising and business) Advertising; business management; business administration; office functions.', '101: Advertising and Business', '101: Advertising and Business', '035 - Primary Class', '(Advertising and business) Advertising; business management; business administration; office functions.', 'Wiesenstrasse 17 Zurich SWITZERLAND 8032', 'USPTO', '2022-07-26']
# End Point:
# 97514637
# [97514636, 'CHINA', 'Limited Company (ltd.)', 'Shandong Doubi Culture Media Co., Ltd.', 'J&S', 'Trademark', 'automobile bumper guards; Automotive door handle scratch guards; Brake lines for vehicles; Brake shoes for motor cars; Clips adapted for fastening automobile parts to automobile bodies; Fitted vehicle covers for motorcycles, automobiles for the purpose of protecting against harsh weather; Fuel line hoses for vehicles; Gear lever knobs for vehicles; Handlebar grips for motorcycles; Hooks specially designed for use in vehicles to hold vehicle accessories; Metal parts for vehicles, namely, automotive exterior and interior metal decorative and protective trim; Parts of motorcycles, namely, handle bar grips; Parts of motorcycles, namely, shift levers; Safety belts for vehicle seats.', 'LIVE APPLICATION Awaiting Examination', '019: Vehicles', '019: Vehicles', '021: Electrical Apparatus, Machines and Supplies', '021: Electrical Apparatus, Machines and Supplies', '023: Cutlery, Machinery, Tools and Parts Thereof', '023: Cutlery, Machinery, Tools and Parts Thereof', '019: Vehicles', '021: Electrical Apparatus, Machines and Supplies', 'South of East Street, Xiahe Village Houjia Town, Wendeng District Weihai Shandong CHINA 264409', 'USPTO', '2022-07-26']
# End Point:
# 97514636
# [97514635, 'CALIFORNIA', 'Limited Liability Company', 'Trio Cellars', 'CANIFORNICATION', 'Trademark', 'Mark For: CANIFORNICATION™ trademark registration is intended to cover the category of alcoholic beverages except beers.', 'LIVE APPLICATION Awaiting Examination', '047: Wines', '049: Distilled Alcoholic Liquors', '(Wine and spirits) Alcoholic beverages (except beers).', '(Wine and spirits) Alcoholic beverages (except beers).', '049: Distilled Alcoholic Liquors', '049: Distilled Alcoholic Liquors', '033 - Primary Class', '(Wine and spirits) Alcoholic beverages (except beers).', '1610 Spring Mountain Road Saint Helena, CALIFORNIA UNITED STATES 94574', 'USPTO', '2022-07-26']
# End Point:
# 97514635
# [97514634, "WANGXINZHUANG GROUP, FENGGANG VIL. GUZHEN TOWN, YU'AN DISTRICT LU'AN, ANHUI CHINA 237147", 'Individual', 'WANG, LIHONG', 'CHONGXIAO', 'Trademark', 'bridesmaid dresses; Evening gowns; Formalwear, namely, dresses, gowns, tuxedos, dinner jackets, trousers and footwear; Skirts and dresses; Wedding dresses; Wedding gowns; Yoga pants; Yoga shirts; Yoga tops.', 'LIVE APPLICATION Awaiting Examination', '022: Games, Toys and Sporting Good', '022: Games, Toys and Sporting Good', '039: Clothing', '039: Clothing', 'The mark consists of two parts, the former part is a girl wearing a stylish hat, followed by a stylized letter "ChongXiao".', 'The mark consists of two parts, the former part is a girl wearing a stylish hat, followed by a stylized letter "ChongXiao".', '022: Games, Toys and Sporting Good', '039: Clothing', "WANGXINZHUANG GROUP, FENGGANG VIL. GUZHEN TOWN, YU'AN DISTRICT LU'AN, ANHUI CHINA 237147", 'USPTO', '2022-07-26']
# End Point:
# 97514634
# [97514633, 'CHINA', 'Limited Company (ltd.)', 'Guangzhou Yuanqi Home Furnishing Co., Ltd.', 'KWPEQU', 'Trademark', "Mark For: KWPEQU™ trademark registration is intended to cover the categories of coats; Dresses; Hats; Jeans; Jeggings; Pants; Scarfs; Slippers; Sweaters; Sweatshirts; Bathing suits; Blouses; Cheongsams (Chinese gowns); Hooded pullovers; Leisure shoes; Men's suits, women's suits; Tee shirts.", 'LIVE APPLICATION Awaiting Examination', '022: Games, Toys and Sporting Good', '039: Clothing', '(Clothing) Clothing, footwear, headgear.', '(Clothing) Clothing, footwear, headgear.', '039: Clothing', '039: Clothing', '025 - Primary Class', '(Clothing) Clothing, footwear, headgear.', 'Room 02, Room 1001 No. 242, Tianhe Road, Tianhe District Guangzhou CHINA 510000', 'USPTO', '2022-07-26']
# End Point:
# 97514633
# [97514632, 'CHINA', 'Limited Company (ltd.)', 'Shenzhen Wanchanghe Industrial Co., Ltd.', 'WONCBLOM', 'Trademark', 'christmas tree decorations; Confetti; Hand-held party poppers; Kaleidoscopes; Novelty noisemaker toys for parties; Novelty toy item in the nature of a dispenser of stream material; Pull toys; Toy fireworks.', 'LIVE APPLICATION Awaiting Examination', '022: Games, Toys and Sporting Good', '022: Games, Toys and Sporting Good', '023: Cutlery, Machinery, Tools and Parts Thereof', '023: Cutlery, Machinery, Tools and Parts Thereof', '038: Prints and Publications', '038: Prints and Publications', '022: Games, Toys and Sporting Good', '023: Cutlery, Machinery, Tools and Parts Thereof', '601, No. 65, 67, Longxi Mid Rd, Longxi Comm, Longgang St, Longgang Dist Shenzhen CHINA 518000', 'USPTO', '2022-07-26']
# End Point:
# 97514632

# %%
workbook.close()
